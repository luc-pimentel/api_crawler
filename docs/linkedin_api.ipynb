# %% [markdown]
# ## **LinkedInAPI**
#
# The `LinkedInAPI` class is designed to extract data from LinkedIn website. It provides methods to construct job search endpoints, send requests, and parse job postings data from LinkedIn.
#
# This class class inherits from the `BaseRestfulAPI` class, which is an base class that provides basic methods for making GET and POST requests using the `requests` library.
#
#
# ### **get_job_postings_data**
#
# #### `get_job_postings_data(search_query: str, **kwargs)`
#
# Retrieves job postings data from LinkedIn based on the search query and additional parameters.
#
# #### Parameters
#
# - `search_query` : `str`
#   - The job role or title to search for.
# - `n_listings` : `int`, optional
#   - The number of job listings to retrieve. Default is 10.
#
# - `**kwargs` : optional
#   - Additional search parameters that will be passed to the linkedin api to make the search more specific. These include:
#     - `location` : `str`
#       - The location to search for jobs. Default is 'United States'.
#     - `days_ago` : `int`
#       - The number of days ago to filter job postings.
#     - `job_type` : `str`
#       - The type of job (e.g., 'full_time', 'part_time', 'temporary', 'contract', 'internship').
#     - `work_type` : `str`
#       - The work type (e.g., 'on_site', 'remote', 'hybrid').
#     - `exp_level` : `str`
#       - The experience level (e.g., 'internship', 'entry_level', 'associate', 'mid_senior_level', 'director').
#     - `min_salary` : `int`
#       - The minimum salary to filter job postings.
#
# #### Returns
#
# - `list of dict`
#   - A list of dictionaries containing job postings data. Each dictionary contains:
#     - `'title'` : `str`
#       - The job title.
#     - `'company'` : `str`
#       - The company name and/or job subtitle.
#     - `'location'` : `str`
#       - The job location.
#     - `'link'` : `str`
#       - The URL to the job posting.
#     - `'list_date'` : `str`
#       - The date the job was listed.
#
#
#
# **Notes:**
# - The function logs input and output data to JSON as part of its operation due to the `log_io_to_json` decorator.
#
#
# ## **Example**

# %%
from api_crawler import LinkedInAPI

linkedin_api = LinkedInAPI()

job_posting_data = linkedin_api.get_job_postings_data('Data Analyst', location='New York', n_listings = 30, days_ago=7)

job_posting_data
# Out:
# [{'title': 'Data Analyst',
#   'company': 'Stripe',
#   'location': 'New York, United States',
#   'time': '2024-06-12',
#   'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-stripe-3824634046?position=1&pageNum=0&refId=nQWZXoBlvrw%2F6UE2vLeE1w%3D%3D&trackingId=H349KLI8vXMsSw6xrfhZDg%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Data Analyst',
#   'company': 'New York Islanders',
#   'location': 'Floral Park, NY',
#   'time': '2024-06-12',
#   'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-new-york-islanders-3948895425?position=2&pageNum=0&refId=nQWZXoBlvrw%2F6UE2vLeE1w%3D%3D&trackingId=9zcv1vKoAOXmosQ8eI8Crw%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Data Analyst, Financial Efficiency Data Analytics',
#   'company': 'Meta',
#   'location': 'New York, NY',
#   'time': '2024-06-12',
#   'link': 'https://www.linkedin.com/jobs/view/data-analyst-financial-efficiency-data-analytics-at-meta-3932236812?position=3&pageNum=0&refId=nQWZXoBlvrw%2F6UE2vLeE1w%3D%3D&trackingId=UOnGKAxTId2%2Ft7SyKlfnzA%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Data Analyst, Go-Live',
#   'company': 'Riskified',
#   'location': 'New York, United States',
#   'time': '2024-06-10',
#   'link': 'https://www.linkedin.com/jobs/view/data-analyst-go-live-at-riskified-3947192962?position=4&pageNum=0&refId=nQWZXoBlvrw%2F6UE2vLeE1w%3D%3D&trackingId=tFt3gFm0E%2Bg6lrQqDC1nXg%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Data Analyst',
#   'company': 'Rose International',
#   'location': 'New York, NY',
#   'time': '2024-06-13',
#   'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-rose-international-3949464235?position=5&pageNum=0&refId=nQWZXoBlvrw%2F6UE2vLeE1w%3D%3D&trackingId=KTyW65Dw2S6dxIAYBGH0fw%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Data Analyst',
#   'company': 'Bernard Nickels & Associates',
#   'location': 'New York, NY',
#   'time': '2024-06-12',
#   'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-bernard-nickels-associates-3948086553?position=6&pageNum=0&refId=nQWZXoBlvrw%2F6UE2vLeE1w%3D%3D&trackingId=RYZt%2BQEwIB1vS%2FciT8XB3w%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Data Analys (HR)',
#   'company': 'ICONMA',
#   'location': 'New York, NY',
#   'time': '2024-06-11',
#   'link': 'https://www.linkedin.com/jobs/view/data-analys-hr-at-iconma-3943329787?position=7&pageNum=0&refId=nQWZXoBlvrw%2F6UE2vLeE1w%3D%3D&trackingId=bmLm66c0blOlkBK3L7kwzg%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Analyst, Data Outcomes & Attribution',
#   'company': 'The Walt Disney Company',
#   'location': 'New York, NY',
#   'time': '2024-06-11',
#   'link': 'https://www.linkedin.com/jobs/view/analyst-data-outcomes-attribution-at-the-walt-disney-company-3946480160?position=8&pageNum=0&refId=nQWZXoBlvrw%2F6UE2vLeE1w%3D%3D&trackingId=ORH%2BOokzp7zV%2BIahnR8niA%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'SQL Data Analyst',
#   'company': 'Velocity Search Group',
#   'location': 'New York, NY',
#   'time': '2024-06-12',
#   'link': 'https://www.linkedin.com/jobs/view/sql-data-analyst-at-velocity-search-group-3948809342?position=9&pageNum=0&refId=nQWZXoBlvrw%2F6UE2vLeE1w%3D%3D&trackingId=nNX0b%2BeJ%2FKs%2Bii7GziJeTQ%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Junior Data Analyst',
#   'company': 'Osmo',
#   'location': 'New York, NY',
#   'time': '2024-06-14',
#   'link': 'https://www.linkedin.com/jobs/view/junior-data-analyst-at-osmo-3949884181?position=10&pageNum=0&refId=nQWZXoBlvrw%2F6UE2vLeE1w%3D%3D&trackingId=xmfG85WFUSVHDmE4e%2B2HcQ%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Data Analyst Consultant',
#   'company': 'Artefact',
#   'location': 'New York, NY',
#   'time': '2024-06-11',
#   'link': 'https://www.linkedin.com/jobs/view/data-analyst-consultant-at-artefact-3931311684?position=1&pageNum=1&refId=WdRgJzu5lYKINknmRbIvVg%3D%3D&trackingId=X%2B2RdQ9ipHKb4AmTq2QB1A%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Data Analyst',
#   'company': 'Motion Recruitment',
#   'location': 'New York, NY',
#   'time': '2024-06-13',
#   'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-motion-recruitment-3949694505?position=2&pageNum=1&refId=WdRgJzu5lYKINknmRbIvVg%3D%3D&trackingId=c5iAHIqeshsr8QDMaHIJeA%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Business Intelligence Analyst',
#   'company': 'AKA',
#   'location': 'New York, NY',
#   'time': '2024-06-10',
#   'link': 'https://www.linkedin.com/jobs/view/business-intelligence-analyst-at-aka-3947423875?position=3&pageNum=1&refId=WdRgJzu5lYKINknmRbIvVg%3D%3D&trackingId=QK49nsNSkiN0keoudUq5yA%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Data Analyst',
#   'company': 'Arrow Search Partners',
#   'location': 'New York, NY',
#   'time': '2024-06-11',
#   'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-arrow-search-partners-3947662074?position=4&pageNum=1&refId=WdRgJzu5lYKINknmRbIvVg%3D%3D&trackingId=5K7W70fl0Ex7euqwxB4IvQ%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Data Analyst',
#   'company': 'Munich Re',
#   'location': 'New York, NY',
#   'time': '2024-06-12',
#   'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-munich-re-3930627792?position=5&pageNum=1&refId=WdRgJzu5lYKINknmRbIvVg%3D%3D&trackingId=CSdt44%2FoqoOlpBVtFil7%2Fw%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Senior Data Analyst, Lodging',
#   'company': 'Hopper',
#   'location': 'New York, NY',
#   'time': '2024-06-12',
#   'link': 'https://www.linkedin.com/jobs/view/senior-data-analyst-lodging-at-hopper-3856848913?position=6&pageNum=1&refId=WdRgJzu5lYKINknmRbIvVg%3D%3D&trackingId=FWuzIUzLHG2bi%2FJdaztkbQ%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Virtual Data Analyst / Entry level (Typist) - Remote | WFH',
#   'company': 'Get.It Recruit - Administrative',
#   'location': 'New York, NY',
#   'time': '2024-06-13',
#   'link': 'https://www.linkedin.com/jobs/view/virtual-data-analyst-entry-level-typist-remote-wfh-at-get-it-recruit-administrative-3945511047?position=7&pageNum=1&refId=WdRgJzu5lYKINknmRbIvVg%3D%3D&trackingId=zcR3IVxutM%2F60EGbTQhhyA%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Data Analyst',
#   'company': 'Munich Re',
#   'location': 'New York, NY',
#   'time': '2024-06-12',
#   'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-munich-re-3847292667?position=8&pageNum=1&refId=WdRgJzu5lYKINknmRbIvVg%3D%3D&trackingId=FMR4ikH%2FeEPd2sqdE7zpyw%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Marketing Data Analyst Internship',
#   'company': 'Legacy',
#   'location': 'New York, NY',
#   'time': '2024-06-14',
#   'link': 'https://www.linkedin.com/jobs/view/marketing-data-analyst-internship-at-legacy-3949323309?position=9&pageNum=1&refId=WdRgJzu5lYKINknmRbIvVg%3D%3D&trackingId=Fs5XV6SvVtX%2BEJd0AGERqA%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Operations Data Analyst (Budgeting/forecasting)',
#   'company': 'HireTalent - Diversity Staffing & Recruiting Firm',
#   'location': 'New York, NY',
#   'time': '2024-06-10',
#   'link': 'https://www.linkedin.com/jobs/view/operations-data-analyst-budgeting-forecasting-at-hiretalent-diversity-staffing-recruiting-firm-3947138095?position=10&pageNum=1&refId=WdRgJzu5lYKINknmRbIvVg%3D%3D&trackingId=ez%2B2KrwNuPekgRuPj24bLw%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Senior Data Analyst',
#   'company': 'Oakridge Staffing',
#   'location': 'Purchase, NY',
#   'time': '2024-06-10',
#   'link': 'https://www.linkedin.com/jobs/view/senior-data-analyst-at-oakridge-staffing-3947197149?position=1&pageNum=2&refId=2ZWTozM115xvtQAQ0S4dXw%3D%3D&trackingId=xxJhq0jxTf6KVMShfENMpg%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Data Analyst-NY',
#   'company': 'ATC',
#   'location': 'New York, United States',
#   'time': '2024-06-13',
#   'link': 'https://www.linkedin.com/jobs/view/data-analyst-ny-at-atc-3945520630?position=2&pageNum=2&refId=2ZWTozM115xvtQAQ0S4dXw%3D%3D&trackingId=0O5TLm95etpXc57bomk9Rw%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Data Analyst-NY',
#   'company': 'ATC',
#   'location': 'New York, United States',
#   'time': '2024-06-13',
#   'link': 'https://www.linkedin.com/jobs/view/data-analyst-ny-at-atc-3945518747?position=3&pageNum=2&refId=2ZWTozM115xvtQAQ0S4dXw%3D%3D&trackingId=BiG8YO%2FBArGCVGeS3eD4UQ%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Data Analyst, Go-Live',
#   'company': 'Riskified',
#   'location': 'New York, NY',
#   'time': '2024-06-10',
#   'link': 'https://www.linkedin.com/jobs/view/data-analyst-go-live-at-riskified-3945924630?position=4&pageNum=2&refId=2ZWTozM115xvtQAQ0S4dXw%3D%3D&trackingId=k9n3b7KqpoVxyzHVnwjc6w%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Data Entry Analyst',
#   'company': 'Green Key Resources',
#   'location': 'New York, NY',
#   'time': '2024-06-13',
#   'link': 'https://www.linkedin.com/jobs/view/data-entry-analyst-at-green-key-resources-3948505330?position=5&pageNum=2&refId=2ZWTozM115xvtQAQ0S4dXw%3D%3D&trackingId=5ivsxUe89a%2BsV8rt70YRTA%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Data Analyst',
#   'company': 'NYU Langone Health',
#   'location': 'New York, NY',
#   'time': '2024-06-12',
#   'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-nyu-langone-health-3856096276?position=6&pageNum=2&refId=2ZWTozM115xvtQAQ0S4dXw%3D%3D&trackingId=u028vgrFx8OdgNVmiPboIA%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Data Analyst',
#   'company': 'KellyMitchell Group',
#   'location': 'New York, NY',
#   'time': '2024-06-07',
#   'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-kellymitchell-group-3908019407?position=7&pageNum=2&refId=2ZWTozM115xvtQAQ0S4dXw%3D%3D&trackingId=roO0rQFoVdH972mcrKiQhw%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Data Analyst',
#   'company': 'DataAnnotation',
#   'location': 'Buffalo-Niagara Falls Area',
#   'time': '2024-06-13',
#   'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-dataannotation-3901391187?position=8&pageNum=2&refId=2ZWTozM115xvtQAQ0S4dXw%3D%3D&trackingId=YNso%2BQVA1ewzr9cB0DmYXg%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Data Analyst',
#   'company': 'City National Bank',
#   'location': 'New York, NY',
#   'time': '2024-06-10',
#   'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-city-national-bank-3947190067?position=9&pageNum=2&refId=2ZWTozM115xvtQAQ0S4dXw%3D%3D&trackingId=dW%2F7uAI%2F5UWYBeHiNB1UzA%3D%3D&trk=public_jobs_jserp-result_search-card'},
#  {'title': 'Data Analyst',
#   'company': 'DataAnnotation',
#   'location': 'Brooklyn, NY',
#   'time': '2024-06-13',
#   'link': 'https://www.linkedin.com/jobs/view/data-analyst-at-dataannotation-3901392159?position=10&pageNum=2&refId=2ZWTozM115xvtQAQ0S4dXw%3D%3D&trackingId=%2Fux2%2FwXwydIjJrIZgNeOVA%3D%3D&trk=public_jobs_jserp-result_search-card'}]
