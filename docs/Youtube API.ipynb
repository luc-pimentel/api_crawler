# %% [markdown]
# ## **Youtube API**
#
# The `YoutubeAPI` class is designed to interact with the YouTube Data API and the `youtubesearchpython` library. It provides methods to search for videos and channels, retrieve video transcripts, and fetch comments and replies.
#
# This class inherits from the `BaseRestfulAPI` and `BaseSearchAPI` classes, which provide methods for making RESTful API calls and handling search functionalities.
#
# It's important to note that this API uses searches from both Google's proprietary Youtube API and also third-party libraries.
#
# Some methods, especially those related to getting comments from videos, will only be available through the Google API, which requires an API key.
#
# The other methods don't need an API key and won't consume API credits. So, overall, you can use this object even if you don't have an API key, just note that some functionality might be limited.
#
# **NOTE**: The following methods will require API keys: `get_comments`, `get_all_comments`, `get_comment_replies`, and `get_all_comment_replies`. All other methods should work without an API key.
#
# ### **search**
#
# ##### `search(query: str, results: int = 10, **kwargs)`
#
# The `search` method searches for YouTube videos based on the query and other optional parameters.
#
# **Parameters:**
# - `query` (str): The search term for videos.
# - `results` (int, optional): The number of search results to retrieve. Defaults to 10.
# - `**kwargs`: Additional search parameters.
#
# **Returns:**
# - `dict`: A dictionary containing the search results.
#
# ##### **Example**

# %%
from api_crawler import YoutubeAPI

youtube = YoutubeAPI()

youtube.search('Best Python Courses')
# Out:
# {'result': [{'type': 'video',
#    'id': 'rwWCyXYwPhA',
#    'title': 'How I Would Learn Python FAST in 2023 (from zero)',
#    'publishedTime': '1 year ago',
#    'duration': '7:08',
#    'viewCount': {'text': '454,607 views', 'short': '454K views'},
#    'thumbnails': [{'url': 'https://i.ytimg.com/vi/rwWCyXYwPhA/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDTEhGQXfxle362eRaIPxF051IgRQ',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/rwWCyXYwPhA/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDurSKLb5pSuXwSDweNyUCnKKWzXQ',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/rwWCyXYwPhA/mqdefault_6s.webp?du=3000&sqp=CND0t7MG&rs=AOn4CLAXs6WESXInhCzJFQ3yWCjLLNfDvg',
#     'width': 320,
#     'height': 180},
#    'descriptionSnippet': [{'text': 'RESOURCES MENTIONED ZERO TO MASTERY - '},
#     {'text': 'BEST PYTHON COURSE', 'bold': True},
#     {'text': ' - (Use Code FRIENDS10 for 10% off)\xa0...'}],
#    'channel': {'name': 'Internet Made Coder',
#     'id': 'UCcJQ96WlEhJ0Ve0SLmU310Q',
#     'thumbnails': [{'url': 'https://yt3.ggpht.com/JCxw636VkW0aNDYa3CkTblvvmhEi1VTYdpMagq7Zj8trOizp2kINd74JpHR4FHckBU_vCIR7hQ=s68-c-k-c0x00ffffff-no-rj',
#       'width': 68,
#       'height': 68}],
#     'link': 'https://www.youtube.com/channel/UCcJQ96WlEhJ0Ve0SLmU310Q'},
#    'accessibility': {'title': 'How I Would Learn Python FAST in 2023 (from zero) by Internet Made Coder 454,607 views 1 year ago 7 minutes, 8 seconds',
#     'duration': '7 minutes, 8 seconds'},
#    'link': 'https://www.youtube.com/watch?v=rwWCyXYwPhA',
#    'shelfTitle': None},
#   {'type': 'video',
#    'id': 'dqlO6_5rZSQ',
#    'title': 'I tried 50 Programming Courses. Here are Top 5.',
#    'publishedTime': '10 months ago',
#    'duration': '7:09',
#    'viewCount': {'text': '2,013,700 views', 'short': '2M views'},
#    'thumbnails': [{'url': 'https://i.ytimg.com/vi/dqlO6_5rZSQ/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAer6YD2N4DnpWe4cKMVvipBewiLQ',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/dqlO6_5rZSQ/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLA0lckYqJaQsFj2XoeJsnOlXXO3cA',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/dqlO6_5rZSQ/mqdefault_6s.webp?du=3000&sqp=CIj8t7MG&rs=AOn4CLCjCJh1eD4yopoRPAKJs7si-T4akQ',
#     'width': 320,
#     'height': 180},
#    'descriptionSnippet': [{'text': '1. How to learn coding efficiently 2. How to become better at Programming? 3. How to become a Software Engineer? I will answer\xa0...'}],
#    'channel': {'name': 'Sahil & Sarra',
#     'id': 'UCkcqmxjMXaBb0kDWqqSEU1g',
#     'thumbnails': [{'url': 'https://yt3.ggpht.com/h_5EX_GD2dB4Ti3cQbQ1BjGkm_M-EN_z_mWSw7KG-kYzswbULF5bTogzGRm-KcawIqiXgcnJiOM=s68-c-k-c0x00ffffff-no-rj',
#       'width': 68,
#       'height': 68}],
#     'link': 'https://www.youtube.com/channel/UCkcqmxjMXaBb0kDWqqSEU1g'},
#    'accessibility': {'title': 'I tried 50 Programming Courses. Here are Top 5. by Sahil & Sarra 2,013,700 views 10 months ago 7 minutes, 9 seconds',
#     'duration': '7 minutes, 9 seconds'},
#    'link': 'https://www.youtube.com/watch?v=dqlO6_5rZSQ',
#    'shelfTitle': None},
#   {'type': 'video',
#    'id': 'AO8_52Lo3J0',
#    'title': 'CS50 from Harvard. Probably the best free python course you will find',
#    'publishedTime': '2 years ago',
#    'duration': '5:21',
#    'viewCount': {'text': '125,877 views', 'short': '125K views'},
#    'thumbnails': [{'url': 'https://i.ytimg.com/vi/AO8_52Lo3J0/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDY4qAbdnuT1dRT2A3RgcwtGtQLpA',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/AO8_52Lo3J0/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBlzKhgYt367yjTC4Hp5U-oxdsmNw',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/AO8_52Lo3J0/mqdefault_6s.webp?du=3000&sqp=CP_yt7MG&rs=AOn4CLA9dVzha9uSexgtNQmXYHSrJTY2EQ',
#     'width': 320,
#     'height': 180},
#    'descriptionSnippet': [{'text': 'Play Break the Code 2 from .Tech Domains for a chance to win a MacBook Pro https://go.tech/pp Enjoy the game! Watch my video\xa0...'}],
#    'channel': {'name': 'Python Programmer',
#     'id': 'UC68KSmHePPePCjW4v57VPQg',
#     'thumbnails': [{'url': 'https://yt3.ggpht.com/ytc/AIdro_nIRNdG4jBmhOnEvlrRrEsVe0uoIoSfLBOSGu70FzBUFyg=s68-c-k-c0x00ffffff-no-rj',
#       'width': 68,
#       'height': 68}],
#     'link': 'https://www.youtube.com/channel/UC68KSmHePPePCjW4v57VPQg'},
#    'accessibility': {'title': 'CS50 from Harvard. Probably the best free python course you will find by Python Programmer 125,877 views 2 years ago 5 minutes, 21 seconds',
#     'duration': '5 minutes, 21 seconds'},
#    'link': 'https://www.youtube.com/watch?v=AO8_52Lo3J0',
#    'shelfTitle': None},
#   {'type': 'video',
#    'id': 'Z9bmM9Ui_Lw',
#    'title': '5 BEST Udemy Courses on Python (2024) - Udemy Courses for Python (Make the Right Choice)',
#    'publishedTime': '7 months ago',
#    'duration': '20:24',
#    'viewCount': {'text': '36,332 views', 'short': '36K views'},
#    'thumbnails': [{'url': 'https://i.ytimg.com/vi/Z9bmM9Ui_Lw/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDFtZIxrYCGwbWAO24nLr2sX5G_xA',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/Z9bmM9Ui_Lw/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDLqVKIYLf2LFeX_TVMig_8cv8RbA',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/Z9bmM9Ui_Lw/mqdefault_6s.webp?du=3000&sqp=CKD9t7MG&rs=AOn4CLAtiuK21ra1zSsdHzZL7LA3uxKMQQ',
#     'width': 320,
#     'height': 180},
#    'descriptionSnippet': [{'text': "Today I'm going to share 5 Udemy "},
#     {'text': 'Courses', 'bold': True},
#     {'text': ' on '},
#     {'text': 'Python', 'bold': True},
#     {'text': '. I received many requests from my subscribers to suggest some of the '},
#     {'text': 'top', 'bold': True},
#     {'text': '\xa0...'}],
#    'channel': {'name': 'Daniel Dan | Tech & Data',
#     'id': 'UC3iyLcDyYxk2nN7M5DsYaYQ',
#     'thumbnails': [{'url': 'https://yt3.ggpht.com/Bs7h1I51tQ08DMr5rOE3CIvtTPxOwxYEZaGGm-bTAV8s3utvdqyunIbK3A11tnhtczol16gPkQ=s68-c-k-c0x00ffffff-no-rj',
#       'width': 68,
#       'height': 68}],
#     'link': 'https://www.youtube.com/channel/UC3iyLcDyYxk2nN7M5DsYaYQ'},
#    'accessibility': {'title': '5 BEST Udemy Courses on Python (2024) - Udemy Courses for Python (Make the Right Choice) by Daniel Dan | Tech & Data 36,332 views 7 months ago 20 minutes',
#     'duration': '20 minutes, 24 seconds'},
#    'link': 'https://www.youtube.com/watch?v=Z9bmM9Ui_Lw',
#    'shelfTitle': None},
#   {'type': 'video',
#    'id': 'bVRsboO0G_s',
#    'title': 'CS50P Python Review 2024 - PYTHON Course (from Harvard) - Is it Worth Your Time?',
#    'publishedTime': '11 months ago',
#    'duration': '5:03',
#    'viewCount': {'text': '31,951 views', 'short': '31K views'},
#    'thumbnails': [{'url': 'https://i.ytimg.com/vi/bVRsboO0G_s/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLA6zTTgZGuwUW2wqb6NowslYGO7yw',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/bVRsboO0G_s/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLA51fMrssb4Qi9whiYf-Ts-iXmYtQ',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/bVRsboO0G_s/mqdefault_6s.webp?du=3000&sqp=CPKCuLMG&rs=AOn4CLDLfGy5w_hZ2hhmfQWoHu4WLr01Xw',
#     'width': 320,
#     'height': 180},
#    'descriptionSnippet': [{'text': '(Discount Link) '},
#     {'text': 'Best Python Course', 'bold': True},
#     {'text': ' I Also Recommend: https://bit.ly/47w88PR Use Code for 10% OFF (FRIENDS10)\xa0...'}],
#    'channel': {'name': 'Daniel Dan | Tech & Data',
#     'id': 'UC3iyLcDyYxk2nN7M5DsYaYQ',
#     'thumbnails': [{'url': 'https://yt3.ggpht.com/Bs7h1I51tQ08DMr5rOE3CIvtTPxOwxYEZaGGm-bTAV8s3utvdqyunIbK3A11tnhtczol16gPkQ=s68-c-k-c0x00ffffff-no-rj',
#       'width': 68,
#       'height': 68}],
#     'link': 'https://www.youtube.com/channel/UC3iyLcDyYxk2nN7M5DsYaYQ'},
#    'accessibility': {'title': 'CS50P Python Review 2024 - PYTHON Course (from Harvard) - Is it Worth Your Time? by Daniel Dan | Tech & Data 31,951 views 11 months ago 5 minutes, 3 seconds',
#     'duration': '5 minutes, 3 seconds'},
#    'link': 'https://www.youtube.com/watch?v=bVRsboO0G_s',
#    'shelfTitle': None},
#   {'type': 'video',
#    'id': 'KBYN6_-YTFU',
#    'title': '100 Days of Code: The Complete Python Pro Bootcamp 2024 by Angela Yu (Udemy) - Course Review',
#    'publishedTime': '8 months ago',
#    'duration': '9:05',
#    'viewCount': {'text': '30,014 views', 'short': '30K views'},
#    'thumbnails': [{'url': 'https://i.ytimg.com/vi/KBYN6_-YTFU/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDURWh38sPHRehIWEVnlIwVnXOqpg',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/KBYN6_-YTFU/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCk4GDX16g7dM0VsBjIxpUftDU0iA',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/KBYN6_-YTFU/mqdefault_6s.webp?du=3000&sqp=CLCOuLMG&rs=AOn4CLDeufsJfqLJ_eBRgxeDiZypWPtnaw',
#     'width': 320,
#     'height': 180},
#    'descriptionSnippet': [{'text': "... The Complete Python Pro Bootcamp Course: https://bit.ly/45ksLMO Today I'm going to review one of the "},
#     {'text': 'best Python Courses', 'bold': True},
#     {'text': ' or\xa0...'}],
#    'channel': {'name': 'Daniel Dan | Tech & Data',
#     'id': 'UC3iyLcDyYxk2nN7M5DsYaYQ',
#     'thumbnails': [{'url': 'https://yt3.ggpht.com/Bs7h1I51tQ08DMr5rOE3CIvtTPxOwxYEZaGGm-bTAV8s3utvdqyunIbK3A11tnhtczol16gPkQ=s68-c-k-c0x00ffffff-no-rj',
#       'width': 68,
#       'height': 68}],
#     'link': 'https://www.youtube.com/channel/UC3iyLcDyYxk2nN7M5DsYaYQ'},
#    'accessibility': {'title': '100 Days of Code: The Complete Python Pro Bootcamp 2024 by Angela Yu (Udemy) - Course Review by Daniel Dan | Tech & Data 30,014 views 8 months ago 9 minutes, 5 seconds',
#     'duration': '9 minutes, 5 seconds'},
#    'link': 'https://www.youtube.com/watch?v=KBYN6_-YTFU',
#    'shelfTitle': None},
#   {'type': 'video',
#    'id': 'MqywbqLmjp4',
#    'title': "I've Read Over 100 Books on Python. Here are the Top 3",
#    'publishedTime': '4 months ago',
#    'duration': '9:26',
#    'viewCount': {'text': '289,231 views', 'short': '289K views'},
#    'thumbnails': [{'url': 'https://i.ytimg.com/vi/MqywbqLmjp4/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBQ9Mln9vYeim3eKmEKYpVmXlOQPA',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/MqywbqLmjp4/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLASYh0CKcMoDVc6AC05K4Sy6CV_Wg',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/MqywbqLmjp4/mqdefault_6s.webp?du=3000&sqp=CKbxt7MG&rs=AOn4CLAYFZ5OCZw-PcqRRy8DpGQhX4RzUQ',
#     'width': 320,
#     'height': 180},
#    'descriptionSnippet': [{'text': 'Over the last few years I have read more than 100 boos on '},
#     {'text': 'python', 'bold': True},
#     {'text': ', There are some books that stand out as the '},
#     {'text': 'best', 'bold': True},
#     {'text': '. I have a\xa0...'}],
#    'channel': {'name': 'Python Programmer',
#     'id': 'UC68KSmHePPePCjW4v57VPQg',
#     'thumbnails': [{'url': 'https://yt3.ggpht.com/ytc/AIdro_nIRNdG4jBmhOnEvlrRrEsVe0uoIoSfLBOSGu70FzBUFyg=s68-c-k-c0x00ffffff-no-rj',
#       'width': 68,
#       'height': 68}],
#     'link': 'https://www.youtube.com/channel/UC68KSmHePPePCjW4v57VPQg'},
#    'accessibility': {'title': "I've Read Over 100 Books on Python. Here are the Top 3 by Python Programmer 289,231 views 4 months ago 9 minutes, 26 seconds",
#     'duration': '9 minutes, 26 seconds'},
#    'link': 'https://www.youtube.com/watch?v=MqywbqLmjp4',
#    'shelfTitle': None},
#   {'type': 'video',
#    'id': 'zLJv37NKSx8',
#    'title': 'How I Would Learn Python FAST in 2024 (if I could start over)',
#    'publishedTime': '5 months ago',
#    'duration': '8:01',
#    'viewCount': {'text': '19,459 views', 'short': '19K views'},
#    'thumbnails': [{'url': 'https://i.ytimg.com/vi/zLJv37NKSx8/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAy--kJe4raXh3VeIQ8FcTqG1wO3w',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/zLJv37NKSx8/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDSiUJ8J_WkwPGiMnosgxFQ1UGA0g',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/zLJv37NKSx8/mqdefault_6s.webp?du=3000&sqp=CKaCuLMG&rs=AOn4CLBc1Iqu3UlRNgiSEPTKKd7EscCnIg',
#     'width': 320,
#     'height': 180},
#    'descriptionSnippet': [{'text': '--- Data & AI as a Service https://decisionforest.co.uk/ Databricks '},
#     {'text': 'Training', 'bold': True},
#     {'text': ' https://decisionforest.co.uk/databricks/\xa0...'}],
#    'channel': {'name': 'DecisionForest',
#     'id': 'UCHz35rvIKf2CMqj7oiMv9WQ',
#     'thumbnails': [{'url': 'https://yt3.ggpht.com/2rEEzNiEEHOSTSgSUZLHok39Qi_Kwm-nCVby1P00Q4E4vMu8vyx_ViMPXyoIPeqxlK0ue4Va=s68-c-k-c0x00ffffff-no-rj',
#       'width': 68,
#       'height': 68}],
#     'link': 'https://www.youtube.com/channel/UCHz35rvIKf2CMqj7oiMv9WQ'},
#    'accessibility': {'title': 'How I Would Learn Python FAST in 2024 (if I could start over) by DecisionForest 19,459 views 5 months ago 8 minutes, 1 second',
#     'duration': '8 minutes, 1 second'},
#    'link': 'https://www.youtube.com/watch?v=zLJv37NKSx8',
#    'shelfTitle': None},
#   {'type': 'video',
#    'id': 'N-wUphzx5p4',
#    'title': 'Essential Skills for Your B-Tech Journey  ||  C  & Python Programming',
#    'publishedTime': '1 day ago',
#    'duration': '0:31',
#    'viewCount': {'text': '406 views', 'short': '406 views'},
#    'thumbnails': [{'url': 'https://i.ytimg.com/vi/N-wUphzx5p4/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCuAxgZOKCepzrN4_OThwHhXetdPg',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/N-wUphzx5p4/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBN5tZnBrxV2TOrW_stU_lxZJtaSw',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/N-wUphzx5p4/mqdefault_6s.webp?du=3000&sqp=CNKPuLMG&rs=AOn4CLB0U8b8l5FaHotN0aPq_vw52WjCbw',
#     'width': 320,
#     'height': 180},
#    'descriptionSnippet': [{'text': 'Subscribe to our channel and hit the bell icon and never miss the update: https://bit.ly/SubscribeCodegnan\xa0...'}],
#    'channel': {'name': 'Codegnan Destination',
#     'id': 'UCEZAhBBmxvUHaYkWB8J4Ltg',
#     'thumbnails': [{'url': 'https://yt3.ggpht.com/YWj236F4oeZIZSiigAPA3ku2hVgs3riQCQWmQvFkDCZbYc-whyalIcdoNW5ox9xwbVCim2K_=s68-c-k-c0x00ffffff-no-rj',
#       'width': 68,
#       'height': 68}],
#     'link': 'https://www.youtube.com/channel/UCEZAhBBmxvUHaYkWB8J4Ltg'},
#    'accessibility': {'title': 'Essential Skills for Your B-Tech Journey  ||  C  & Python Programming by Codegnan Destination 406 views 1 day ago 31 seconds',
#     'duration': '31 seconds'},
#    'link': 'https://www.youtube.com/watch?v=N-wUphzx5p4',
#    'shelfTitle': None},
#   {'type': 'video',
#    'id': 'kqtD5dpn9C8',
#    'title': 'Python for Beginners - Learn Python in 1 Hour',
#    'publishedTime': '3 years ago',
#    'duration': '1:00:06',
#    'viewCount': {'text': '17,246,699 views', 'short': '17M views'},
#    'thumbnails': [{'url': 'https://i.ytimg.com/vi/kqtD5dpn9C8/hq720.jpg?sqp=-oaymwEcCOgCEMoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLD1iLVjsmE_gK2uZS887LgyThzx4Q',
#      'width': 360,
#      'height': 202},
#     {'url': 'https://i.ytimg.com/vi/kqtD5dpn9C8/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDoYD4sT1l-1w5fEUQt6pdtsKdfLQ',
#      'width': 720,
#      'height': 404}],
#    'richThumbnail': {'url': 'https://i.ytimg.com/an_webp/kqtD5dpn9C8/mqdefault_6s.webp?du=3000&sqp=CNSEuLMG&rs=AOn4CLBQMKlCMVmxlnV1gnVDuCrA8x-rGg',
#     'width': 320,
#     'height': 180},
#    'descriptionSnippet': [{'text': 'Learn '},
#     {'text': 'Python', 'bold': True},
#     {'text': ' basics in 1 hour! ⚡ This beginner-friendly tutorial will get you coding fast. Want to dive deeper? - Check out my\xa0...'}],
#    'channel': {'name': 'Programming with Mosh',
#     'id': 'UCWv7vMbMWH4-V0ZXdmDpPBA',
#     'thumbnails': [{'url': 'https://yt3.ggpht.com/ebu9ZksIXw0tUWBZd6rtk-It8VGSk8AdfSI_eGR-fl6WGet9LnVPngNQCmjdLJeGXpuylwYInQ=s68-c-k-c0x00ffffff-no-rj',
#       'width': 68,
#       'height': 68}],
#     'link': 'https://www.youtube.com/channel/UCWv7vMbMWH4-V0ZXdmDpPBA'},
#    'accessibility': {'title': 'Python for Beginners - Learn Python in 1 Hour by Programming with Mosh 17,246,699 views 3 years ago 1 hour',
#     'duration': '1 hour, 6 seconds'},
#    'link': 'https://www.youtube.com/watch?v=kqtD5dpn9C8',
#    'shelfTitle': None}]}

# %% [markdown]
# ### **search_channel**
#
# ##### `search_channel(query: str, limit: int = 10, region: str = None, **kwargs)`
#
# The `search_channel` method searches for YouTube channels based on the query and other optional parameters.
#
# **Parameters:**
# - `query` (str): The search term for channels.
# - `limit` (int, optional): The number of search results to retrieve. Defaults to 10.
# - `region` (str, optional): The region code to filter search results.
# - `**kwargs`: Additional search parameters.
#
# **Returns:**
# - `dict`: A dictionary containing the search results.
#
# ##### **Example**

# %%
youtube.search_channel('Python')
# Out:
# {'result': [{'type': 'channel',
#    'id': 'UCdu8D9NV9NP1iVPTYlenORw',
#    'title': 'Python',
#    'thumbnails': [{'url': '//yt3.ggpht.com/wBNnPosFKLIwA2fQoCNeIitiyudCf8LDqcjU6K1Zxams8bYQFOo1nomcOi2zkvbjY1WZ4putDiQ=s88-c-k-c0x00ffffff-no-rj-mo',
#      'width': 88,
#      'height': 88},
#     {'url': '//yt3.ggpht.com/wBNnPosFKLIwA2fQoCNeIitiyudCf8LDqcjU6K1Zxams8bYQFOo1nomcOi2zkvbjY1WZ4putDiQ=s176-c-k-c0x00ffffff-no-rj-mo',
#      'width': 176,
#      'height': 176}],
#    'videoCount': None,
#    'descriptionSnippet': None,
#    'subscribers': '@python7669',
#    'link': 'https://www.youtube.com/channel/UCdu8D9NV9NP1iVPTYlenORw'},
#   {'type': 'channel',
#    'id': 'UCI0vQvr9aFn27yR6Ej6n5UA',
#    'title': 'Real Python',
#    'thumbnails': [{'url': '//yt3.googleusercontent.com/ytc/AIdro_nzF12uuoHg0gD_rl6GKh3imllb_MI7Npr2B6tJpZp939U=s88-c-k-c0x00ffffff-no-rj-mo',
#      'width': 88,
#      'height': 88},
#     {'url': '//yt3.googleusercontent.com/ytc/AIdro_nzF12uuoHg0gD_rl6GKh3imllb_MI7Npr2B6tJpZp939U=s176-c-k-c0x00ffffff-no-rj-mo',
#      'width': 176,
#      'height': 176}],
#    'videoCount': None,
#    'descriptionSnippet': [{'text': 'Python', 'bold': True},
#     {'text': ' tutorials and training videos for Pythonistas that go beyond the basics. Get free '},
#     {'text': 'Python', 'bold': True},
#     {'text': ' tips and programming tutorials\xa0...'}],
#    'subscribers': '@realpython',
#    'link': 'https://www.youtube.com/channel/UCI0vQvr9aFn27yR6Ej6n5UA'},
#   {'type': 'channel',
#    'id': 'UC2liIKa5d4tvBiNzBng20PA',
#    'title': 'Python',
#    'thumbnails': [{'url': '//yt3.googleusercontent.com/ytc/AIdro_lGi4z3whNpPXs0ag2AaCVfMzcw1l-eqKIXD_zMnPlZ32Q=s88-c-k-c0x00ffffff-no-rj-mo',
#      'width': 88,
#      'height': 88},
#     {'url': '//yt3.googleusercontent.com/ytc/AIdro_lGi4z3whNpPXs0ag2AaCVfMzcw1l-eqKIXD_zMnPlZ32Q=s176-c-k-c0x00ffffff-no-rj-mo',
#      'width': 176,
#      'height': 176}],
#    'videoCount': None,
#    'descriptionSnippet': [{'text': 'Enjoy the POV video :)'}],
#    'subscribers': '@PythonJPN',
#    'link': 'https://www.youtube.com/channel/UC2liIKa5d4tvBiNzBng20PA'},
#   {'type': 'channel',
#    'id': 'UCCezIgC97PvUuR4_gbFUs5g',
#    'title': 'Corey Schafer',
#    'thumbnails': [{'url': '//yt3.googleusercontent.com/ytc/AIdro_lD6K9DGGqWttThktCDttOdlHIHWZQ7Gcdd9WRSEqYUxw=s88-c-k-c0x00ffffff-no-rj-mo',
#      'width': 88,
#      'height': 88},
#     {'url': '//yt3.googleusercontent.com/ytc/AIdro_lD6K9DGGqWttThktCDttOdlHIHWZQ7Gcdd9WRSEqYUxw=s176-c-k-c0x00ffffff-no-rj-mo',
#      'width': 176,
#      'height': 176}],
#    'videoCount': None,
#    'descriptionSnippet': [{'text': 'Welcome to my Channel. This channel is focused on creating tutorials and walkthroughs for software developers, programmers,\xa0...'}],
#    'subscribers': '@coreyms',
#    'link': 'https://www.youtube.com/channel/UCCezIgC97PvUuR4_gbFUs5g'},
#   {'type': 'channel',
#    'id': 'UCfzlCWGWYyIQ0aLC5w48gBQ',
#    'title': 'sentdex',
#    'thumbnails': [{'url': '//yt3.googleusercontent.com/ytc/AIdro_mWT-3HaBiihhDy3TGYNqjZt-OP8PivU_lMUjdhwntZ2LM=s88-c-k-c0x00ffffff-no-rj-mo',
#      'width': 88,
#      'height': 88},
#     {'url': '//yt3.googleusercontent.com/ytc/AIdro_mWT-3HaBiihhDy3TGYNqjZt-OP8PivU_lMUjdhwntZ2LM=s176-c-k-c0x00ffffff-no-rj-mo',
#      'width': 176,
#      'height': 176}],
#    'videoCount': None,
#    'descriptionSnippet': [{'text': 'Python', 'bold': True},
#     {'text': ' Programming tutorials, going further than just the basics. Learn about machine learning, finance, data analysis, robotics,\xa0...'}],
#    'subscribers': '@sentdex',
#    'link': 'https://www.youtube.com/channel/UCfzlCWGWYyIQ0aLC5w48gBQ'},
#   {'type': 'channel',
#    'id': 'UCKQdc0-Targ4nDIAUrlfKiA',
#    'title': 'Python Simplified',
#    'thumbnails': [{'url': '//yt3.googleusercontent.com/ytc/AIdro_ngt_N86CG1gQ576UmAbpFyxnCZddjPWzzKXzTfxljsZkM=s88-c-k-c0x00ffffff-no-rj-mo',
#      'width': 88,
#      'height': 88},
#     {'url': '//yt3.googleusercontent.com/ytc/AIdro_ngt_N86CG1gQ576UmAbpFyxnCZddjPWzzKXzTfxljsZkM=s176-c-k-c0x00ffffff-no-rj-mo',
#      'width': 176,
#      'height': 176}],
#    'videoCount': None,
#    'descriptionSnippet': [{'text': "Hi everyone! My name is Mariya and I'm a software developer from Vancouver, British Columbia. I film simple programming\xa0..."}],
#    'subscribers': '@PythonSimplified',
#    'link': 'https://www.youtube.com/channel/UCKQdc0-Targ4nDIAUrlfKiA'},
#   {'type': 'channel',
#    'id': 'UC5vr5PwcXiKX_-6NTteAlXw',
#    'title': 'Python Tutorials for Digital Humanities',
#    'thumbnails': [{'url': '//yt3.googleusercontent.com/ytc/AIdro_kXnlIZTUX2QFcfRSbvQjxZDFqj7EP03ojP3Xxr0dEmIdY=s88-c-k-c0x00ffffff-no-rj-mo',
#      'width': 88,
#      'height': 88},
#     {'url': '//yt3.googleusercontent.com/ytc/AIdro_kXnlIZTUX2QFcfRSbvQjxZDFqj7EP03ojP3Xxr0dEmIdY=s176-c-k-c0x00ffffff-no-rj-mo',
#      'width': 176,
#      'height': 176}],
#    'videoCount': None,
#    'descriptionSnippet': [{'text': 'On this channel, I provide tutorials for working with '},
#     {'text': 'Python', 'bold': True},
#     {'text': ' in a digital humanities project. I design my videos and tutorials for\xa0...'}],
#    'subscribers': '@python-programming',
#    'link': 'https://www.youtube.com/channel/UC5vr5PwcXiKX_-6NTteAlXw'},
#   {'type': 'channel',
#    'id': 'UC68KSmHePPePCjW4v57VPQg',
#    'title': 'Python Programmer',
#    'thumbnails': [{'url': '//yt3.googleusercontent.com/ytc/AIdro_nIRNdG4jBmhOnEvlrRrEsVe0uoIoSfLBOSGu70FzBUFyg=s88-c-k-c0x00ffffff-no-rj-mo',
#      'width': 88,
#      'height': 88},
#     {'url': '//yt3.googleusercontent.com/ytc/AIdro_nIRNdG4jBmhOnEvlrRrEsVe0uoIoSfLBOSGu70FzBUFyg=s176-c-k-c0x00ffffff-no-rj-mo',
#      'width': 176,
#      'height': 176}],
#    'videoCount': None,
#    'descriptionSnippet': [{'text': "Hi I'm Giles, I make videos about learning I have a degree in physics, a post graduate certificate in Data Science and am a\xa0..."}],
#    'subscribers': '@gilesmcmullen',
#    'link': 'https://www.youtube.com/channel/UC68KSmHePPePCjW4v57VPQg'},
#   {'type': 'channel',
#    'id': 'UC5Kgc_HNzx4GJ-w4QMeeKiQ',
#    'title': 'Pythonプログラミング VTuber サプー',
#    'thumbnails': [{'url': '//yt3.ggpht.com/jR1MUsEl_2S4ivGkG8zaHK131UEzWQldnO2uEiMa7qqvGg7ffZWdJ7RtjBzC8XnAZ-G4tw70vQ=s88-c-k-c0x00ffffff-no-rj-mo',
#      'width': 88,
#      'height': 88},
#     {'url': '//yt3.ggpht.com/jR1MUsEl_2S4ivGkG8zaHK131UEzWQldnO2uEiMa7qqvGg7ffZWdJ7RtjBzC8XnAZ-G4tw70vQ=s176-c-k-c0x00ffffff-no-rj-mo',
#      'width': 176,
#      'height': 176}],
#    'videoCount': None,
#    'descriptionSnippet': [{'text': 'Python', 'bold': True},
#     {'text': 'プログラミングについて解説するVTuber サプーです✨ 初心者でも分かりやすく、'},
#     {'text': 'Python', 'bold': True},
#     {'text': 'を学習できるような動画を\xa0...'}],
#    'subscribers': '@pythonvtuber9917',
#    'link': 'https://www.youtube.com/channel/UC5Kgc_HNzx4GJ-w4QMeeKiQ'},
#   {'type': 'channel',
#    'id': 'UCu28RVwAGnAfSSgeXNbVV0g',
#    'title': 'Python Cowboy',
#    'thumbnails': [{'url': '//yt3.googleusercontent.com/ytc/AIdro_ndzXN3E24CFS9nAbGagNAXmfaTScdQR-n7MGQFU6Joxh0=s88-c-k-c0x00ffffff-no-rj-mo',
#      'width': 88,
#      'height': 88},
#     {'url': '//yt3.googleusercontent.com/ytc/AIdro_ndzXN3E24CFS9nAbGagNAXmfaTScdQR-n7MGQFU6Joxh0=s176-c-k-c0x00ffffff-no-rj-mo',
#      'width': 176,
#      'height': 176}],
#    'videoCount': None,
#    'descriptionSnippet': [{'text': 'TrapperMike #PythonCowboy @pythoncowboy Owner/Operator of Martin County Trapping & Wildlife Rescue in swampy South\xa0...'}],
#    'subscribers': '@PythonCowboy',
#    'link': 'https://www.youtube.com/channel/UCu28RVwAGnAfSSgeXNbVV0g'}]}

# %% [markdown]
# ### **get_videos_from_channel**
#
# ##### `get_videos_from_channel(channel_id: str, n_videos: Union[int, str] = 'all')`
#
# The `get_videos_from_channel` method retrieves videos from a specified YouTube channel.
#
# **Parameters:**
# - `channel_id` (str): The ID of the YouTube channel.
# - `n_videos` (Union[int, str], optional): The number of videos to retrieve. Defaults to 'all'.
#
# **Returns:**
# - `list`: A list of dictionaries, each representing a video.
#
# ##### **Example**

# %%
youtube.get_videos_from_channel('UCdu8D9NV9NP1iVPTYlenORw', n_videos=5)
# Out:
# [{'id': 'pECkvBV-MB8',
#   'thumbnails': [{'url': 'https://i.ytimg.com/vi/pECkvBV-MB8/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLCMkz_EJswnEdq0APZG6ePOAK9nAw',
#     'width': 168,
#     'height': 94},
#    {'url': 'https://i.ytimg.com/vi/pECkvBV-MB8/hqdefault.jpg?sqp=-oaymwEbCMQBEG5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLBQ2Yqc5bZe-K9nLnZfquebNwNzIQ',
#     'width': 196,
#     'height': 110},
#    {'url': 'https://i.ytimg.com/vi/pECkvBV-MB8/hqdefault.jpg?sqp=-oaymwEcCPYBEIoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAnxe2rTyzHnvcMvJywNF2jLBl5Ng',
#     'width': 246,
#     'height': 138},
#    {'url': 'https://i.ytimg.com/vi/pECkvBV-MB8/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAP7YQ4NMH6Np7kKr3785EruiVIdA',
#     'width': 336,
#     'height': 188}],
#   'title': '.diedlonely, énouement - stellar (Slowed + Reverb) (1 Hour Loop) | Ambient Music',
#   'channel': {'name': 'Python',
#    'id': 'UCdu8D9NV9NP1iVPTYlenORw',
#    'link': '/@python7669'},
#   'duration': '1:30:40',
#   'accessibility': {'title': '.diedlonely, énouement - stellar (Slowed + Reverb) (1 Hour Loop) | Ambient Music by Python 115 views 5 days ago 1 hour, 30 minutes',
#    'duration': '1 hour, 30 minutes, 40 seconds'},
#   'link': 'https://www.youtube.com/watch?v=pECkvBV-MB8&list=UUdu8D9NV9NP1iVPTYlenORw&index=1&pp=iAQB',
#   'isPlayable': True},
#  {'id': 'sVTlVZ-htHU',
#   'thumbnails': [{'url': 'https://i.ytimg.com/vi/sVTlVZ-htHU/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLC1jjvbDUU6ZbJMP2LjQ8kMsyl8_w',
#     'width': 168,
#     'height': 94},
#    {'url': 'https://i.ytimg.com/vi/sVTlVZ-htHU/hqdefault.jpg?sqp=-oaymwEbCMQBEG5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLCZANTSsr9mMyCrOIEux9JCc_gZLg',
#     'width': 196,
#     'height': 110},
#    {'url': 'https://i.ytimg.com/vi/sVTlVZ-htHU/hqdefault.jpg?sqp=-oaymwEcCPYBEIoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBVu6EXKuuIxVxsuVopM2z7PrkfGQ',
#     'width': 246,
#     'height': 138},
#    {'url': 'https://i.ytimg.com/vi/sVTlVZ-htHU/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAOjuYf-88DcLaVMYhV1MsiQdJsDQ',
#     'width': 336,
#     'height': 188}],
#   'title': 'antent - hope to see you again (1 Hour Loop) | Ambient Music',
#   'channel': {'name': 'Python',
#    'id': 'UCdu8D9NV9NP1iVPTYlenORw',
#    'link': '/@python7669'},
#   'duration': '1:30:02',
#   'accessibility': {'title': 'antent - hope to see you again (1 Hour Loop) | Ambient Music by Python 508 views 6 days ago 1 hour, 30 minutes',
#    'duration': '1 hour, 30 minutes, 2 seconds'},
#   'link': 'https://www.youtube.com/watch?v=sVTlVZ-htHU&list=UUdu8D9NV9NP1iVPTYlenORw&index=2&pp=iAQB',
#   'isPlayable': True},
#  {'id': 'o8SQm95cjF8',
#   'thumbnails': [{'url': 'https://i.ytimg.com/vi/o8SQm95cjF8/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLCatr2RKQCWBgGLmYDg7-Vp1Z5IcQ',
#     'width': 168,
#     'height': 94},
#    {'url': 'https://i.ytimg.com/vi/o8SQm95cjF8/hqdefault.jpg?sqp=-oaymwEbCMQBEG5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLC03MakesdjNLzXqRhqpBmgVhWlFg',
#     'width': 196,
#     'height': 110},
#    {'url': 'https://i.ytimg.com/vi/o8SQm95cjF8/hqdefault.jpg?sqp=-oaymwEcCPYBEIoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCI6Sixa9Dvs8Q6ezFlbz7V1JfQJA',
#     'width': 246,
#     'height': 138},
#    {'url': 'https://i.ytimg.com/vi/o8SQm95cjF8/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBn0020sjqhLpUYFKqtVrlejqLLYQ',
#     'width': 336,
#     'height': 188}],
#   'title': 'lonnex - losing (1 Hour Loop) | Ambient Music',
#   'channel': {'name': 'Python',
#    'id': 'UCdu8D9NV9NP1iVPTYlenORw',
#    'link': '/@python7669'},
#   'duration': '1:30:09',
#   'accessibility': {'title': 'lonnex - losing (1 Hour Loop) | Ambient Music by Python 77 views 7 days ago 1 hour, 30 minutes',
#    'duration': '1 hour, 30 minutes, 9 seconds'},
#   'link': 'https://www.youtube.com/watch?v=o8SQm95cjF8&list=UUdu8D9NV9NP1iVPTYlenORw&index=3&pp=iAQB',
#   'isPlayable': True},
#  {'id': '-urXuwYTnnM',
#   'thumbnails': [{'url': 'https://i.ytimg.com/vi/-urXuwYTnnM/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLDylfCXBlFj1bQ78QwYspD81J4LGQ',
#     'width': 168,
#     'height': 94},
#    {'url': 'https://i.ytimg.com/vi/-urXuwYTnnM/hqdefault.jpg?sqp=-oaymwEbCMQBEG5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLB2Xz05CNqk7HOD-PdkZvwWvgutTg',
#     'width': 196,
#     'height': 110},
#    {'url': 'https://i.ytimg.com/vi/-urXuwYTnnM/hqdefault.jpg?sqp=-oaymwEcCPYBEIoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCksthkSLDtWqDo9_ThrNfKr09xKQ',
#     'width': 246,
#     'height': 138},
#    {'url': 'https://i.ytimg.com/vi/-urXuwYTnnM/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAcxZVWEHfVgGuPIfySRDDqPOYWsA',
#     'width': 336,
#     'height': 188}],
#   'title': 'alvedon - retire (final) (1 Hour Loop) | Analog Ambient Music',
#   'channel': {'name': 'Python',
#    'id': 'UCdu8D9NV9NP1iVPTYlenORw',
#    'link': '/@python7669'},
#   'duration': '1:35:51',
#   'accessibility': {'title': 'alvedon - retire (final) (1 Hour Loop) | Analog Ambient Music by Python 95 views 8 days ago 1 hour, 35 minutes',
#    'duration': '1 hour, 35 minutes, 51 seconds'},
#   'link': 'https://www.youtube.com/watch?v=-urXuwYTnnM&list=UUdu8D9NV9NP1iVPTYlenORw&index=4&pp=iAQB',
#   'isPlayable': True},
#  {'id': 'a91j5XlnZuo',
#   'thumbnails': [{'url': 'https://i.ytimg.com/vi/a91j5XlnZuo/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLA4ntJh-lr5C-5xgly0L3pLBmyIJA',
#     'width': 168,
#     'height': 94},
#    {'url': 'https://i.ytimg.com/vi/a91j5XlnZuo/hqdefault.jpg?sqp=-oaymwEbCMQBEG5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLCeSWSVBxcSO3VtrDjpS0wnhQVaGQ',
#     'width': 196,
#     'height': 110},
#    {'url': 'https://i.ytimg.com/vi/a91j5XlnZuo/hqdefault.jpg?sqp=-oaymwEcCPYBEIoBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCq4GRVVs2n0JYvRuIEK8t1OQAYpg',
#     'width': 246,
#     'height': 138},
#    {'url': 'https://i.ytimg.com/vi/a91j5XlnZuo/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLAGqGyWdvAc5sn2XIPtXHASQUn33Q',
#     'width': 336,
#     'height': 188}],
#   'title': '[1 Hour Loop] memories x distorted memories (Slowed + Reverb) | Ambient Backroom Music',
#   'channel': {'name': 'Python',
#    'id': 'UCdu8D9NV9NP1iVPTYlenORw',
#    'link': '/@python7669'},
#   'duration': '1:33:19',
#   'accessibility': {'title': '[1 Hour Loop] memories x distorted memories (Slowed + Reverb) | Ambient Backroom Music by Python 90 views 9 days ago 1 hour, 33 minutes',
#    'duration': '1 hour, 33 minutes, 19 seconds'},
#   'link': 'https://www.youtube.com/watch?v=a91j5XlnZuo&list=UUdu8D9NV9NP1iVPTYlenORw&index=5&pp=iAQB',
#   'isPlayable': True}]

# %% [markdown]
# ### **get_transcript**
#
# ##### `get_transcript(video_id: str) -> str`
#
# The `get_transcript` method retrieves the transcript of a specified YouTube video.
#
# **Parameters:**
# - `video_id` (str): The ID of the YouTube video.
#
# **Returns:**
# - `str`: The transcript of the video.
#
# ##### **Example**

# %%
youtube.get_transcript('GIRkQQHzsxI')
# Out:
# {'segments': [{'startMs': '160',
#    'endMs': '6720',
#    'text': 'productivity is how much money you get out for the time you put in I know this because I went from $0 at age 23 to $100',
#    'startTime': '0:00'},
#   {'startMs': '6720',
#    'endMs': '11759',
#    'text': "million plus net worth at age 31 simply by better investing my time and I'm",
#    'startTime': '0:06'},
#   {'startMs': '11759',
#    'endMs': '18119',
#    'text': "going to teach you how I do it so that hopefully you can do it and I'm even going to show you my calendar at the end of the video and walk you through step",
#    'startTime': '0:11'},
#   {'startMs': '18119',
#    'endMs': '26359',
#    'text': 'by step how I get good Returns on my time have you ever had someone reach out to you and say hey God minute hey got 10',
#    'startTime': '0:18'},
#   {'startMs': '26359',
#    'endMs': '31679',
#    'text': "hey let me introduce you to so and so they're going to be in town how does 10 a.m. work a normal exchange like that",
#    'startTime': '0:26'},
#   {'startMs': '31679',
#    'endMs': '37719',
#    'text': "you might say yeah I've Got 5 minutes or sure I can meet so and so for coffee the problem is that for one specific type of",
#    'startTime': '0:31'},
#   {'startMs': '37719',
#    'endMs': '43719',
#    'text': "worker that five-minute meeting blows their entire morning because they can't do the development work they need they",
#    'startTime': '0:37'},
#   {'startMs': '43719',
#    'endMs': '49280',
#    'text': "can't edit the video they can't write the book chapter because it disrupts their workflow on the other hand there's",
#    'startTime': '0:43'},
#   {'startMs': '49280',
#    'endMs': '55879',
#    'text': "another type of worker where for them it's actually very optimal for them to take that meeting the question is which",
#    'startTime': '0:49'},
#   {'startMs': '55879',
#    'endMs': '61280',
#    'text': 'one are you and at what times also special shout out to Paul Graham who wrote a tiny blog this 14 years ago so',
#    'startTime': '0:55'},
#   {'startMs': '61280',
#    'endMs': '67320',
#    'text': 'if time is what we invest and money is what we make from that investment then the people who are the best investors of',
#    'startTime': '1:01'},
#   {'startMs': '67320',
#    'endMs': '73720',
#    'text': 'time were the ones who make the most money and so it turns out there are two specific types of entrepreneurs and',
#    'startTime': '1:07'},
#   {'startMs': '73720',
#    'endMs': '80520',
#    'text': "you'll switch hats throughout your day or throughout your week the first and most common investor of time that people",
#    'startTime': '1:13'},
#   {'startMs': '80520',
#    'endMs': '86799',
#    'text': 'are familiar with is the manager schedule and these people have a very specific way of investing time and',
#    'startTime': '1:20'},
#   {'startMs': '86799',
#    'endMs': '93680',
#    'text': "getting Returns on it so they can make the most money so let's talk about that managers divide their time into the",
#    'startTime': '1:26'},
#   {'startMs': '93680',
#    'endMs': '99200',
#    'text': 'smallest chunk possible they often have 20 plus chunks per day from 15 minutes',
#    'startTime': '1:33'},
#   {'startMs': '99200',
#    'endMs': '106640',
#    'text': 'sometimes 5 minutes all the way to an hour or 90 minutes and for managers an empty time slot is a lost opportunity',
#    'startTime': '1:39'},
#   {'startMs': '106640',
#    'endMs': '113920',
#    'text': "that's time that did not get a return on investment for them and for that reason they treat time like currency and the",
#    'startTime': '1:46'},
#   {'startMs': '113920',
#    'endMs': '120280',
#    'text': "only real cost for them to fill is just the cost of coordinating with somebody else's calendar to find a mutually empty",
#    'startTime': '1:53'},
#   {'startMs': '120280',
#    'endMs': '125560',
#    'text': 'slot so that they can work together now on paper since work on meetings is a',
#    'startTime': '2:00'},
#   {'startMs': '125560',
#    'endMs': '131680',
#    'text': 'mutually filled slot it makes both people more productive and so when a manager interacts with another manager',
#    'startTime': '2:05'},
#   {'startMs': '131680',
#    'endMs': '137239',
#    'text': 'and they mutually fill a slot both of them make more money now they talk to',
#    'startTime': '2:11'},
#   {'startMs': '137239',
#    'endMs': '142879',
#    'text': 'lots of different people and do many different kinds of tasks all day long this is the nature of the manager they',
#    'startTime': '2:17'},
#   {'startMs': '142879',
#    'endMs': '148000',
#    'text': 'collect data they report data to persuade to lead to train and encourage',
#    'startTime': '2:22'},
#   {'startMs': '148000',
#    'endMs': '154280',
#    'text': 'and make other decisions one-on one and sometimes in groups of people for them they have a pretty clear beginning of',
#    'startTime': '2:28'},
#   {'startMs': '154280',
#    'endMs': '160159',
#    'text': 'the day and a pretty clear end of the day the day begins when they start preparing for their meetings maybe 30',
#    'startTime': '2:34'},
#   {'startMs': '160159',
#    'endMs': '165280',
#    'text': 'minutes or an hour beforehand and it ends at the end of their last meeting now if they prep for the next day then',
#    'startTime': '2:40'},
#   {'startMs': '165280',
#    'endMs': '171920',
#    'text': 'they could add that on top but more or less the duration of their day is directly proportional to the duration of the meetings they have they basically',
#    'startTime': '2:45'},
#   {'startMs': '171920',
#    'endMs': '177480',
#    'text': "work until their last calendar slot and that's how their day works and this is the key Point here the main objective of",
#    'startTime': '2:51'},
#   {'startMs': '177480',
#    'endMs': '183959',
#    'text': 'the manager is to use up all their chunks in the day day so that they maximize their time a fully booked day',
#    'startTime': '2:57'},
#   {'startMs': '183959',
#    'endMs': '190799',
#    'text': "is a maximally invested manager they've used up all of their time slots and so they are",
#    'startTime': '3:03'},
#   {'startMs': '190799',
#    'endMs': '198319',
#    'text': 'productive now the second type of time schedule management is something called the maker and this is one that the vast',
#    'startTime': '3:10'},
#   {'startMs': '198319',
#    'endMs': '205280',
#    'text': 'majority of people do not know this is where the creators this is where the entrepreneurs this is where people who',
#    'startTime': '3:18'},
#   {'startMs': '205280',
#    'endMs': '210519',
#    'text': 'have to make big things who build stuff get the highest returns on their time',
#    'startTime': '3:25'},
#   {'startMs': '210519',
#    'endMs': '217200',
#    'text': "the vast majority of entrepreneurs at some point have some or all of their time that's dedicated to making stuff",
#    'startTime': '3:30'},
#   {'startMs': '217200',
#    'endMs': '222959',
#    'text': 'this is the Deep work this is the stuff that moves the big ball forward there are often tasks that are not urgent but',
#    'startTime': '3:37'},
#   {'startMs': '222959',
#    'endMs': '228680',
#    'text': 'incredibly important and when you look back on your month or your quarter or your year the few things that you',
#    'startTime': '3:42'},
#   {'startMs': '228680',
#    'endMs': '235120',
#    'text': 'remember that actually move the ball forward that actually move your business forward in the long term were these',
#    'startTime': '3:48'},
#   {'startMs': '235120',
#    'endMs': '240480',
#    'text': 'chunks of work now the problem is most entrepreneurs do not have the time and',
#    'startTime': '3:55'},
#   {'startMs': '240480',
#    'endMs': '247760',
#    'text': 'do not have the system for maximizing that time of important work because fundamentally if those are the footholds',
#    'startTime': '4:00'},
#   {'startMs': '247760',
#    'endMs': '253239',
#    'text': 'that allow you to push yourself forward towards your goal then you want as many of those as possible the difficulty is',
#    'startTime': '4:07'},
#   {'startMs': '253239',
#    'endMs': '258479',
#    'text': "that it's never urgent this is like if you're a coder and you need to develop software obviously if that software is",
#    'startTime': '4:13'},
#   {'startMs': '258479',
#    'endMs': '265160',
#    'text': "developed that's the most valuable thing you can do if you're an editor and you make videos then actually editing the video so that it can get out in media is",
#    'startTime': '4:18'},
#   {'startMs': '265160',
#    'endMs': '270560',
#    'text': "the most important thing that you can do if you write copy for emails or you're an author and you write books you",
#    'startTime': '4:25'},
#   {'startMs': '270560',
#    'endMs': '277360',
#    'text': 'actually writing the book and actually doing the work of the book is the most important thing that you can do all of those things are maker work you create',
#    'startTime': '4:30'},
#   {'startMs': '277360',
#    'endMs': '283919',
#    'text': "something that before this did not exist although this work is important it's incredibly expensive in terms of time",
#    'startTime': '4:37'},
#   {'startMs': '283919',
#    'endMs': '289440',
#    'text': 'and the problem is the vast majority of the world works on manager time not on maker time so let me explain the',
#    'startTime': '4:43'},
#   {'startMs': '289440',
#    'endMs': '296639',
#    'text': 'difference so for the maker when you get into maker mode instead of many small slivers like the manager has you have',
#    'startTime': '4:49'},
#   {'startMs': '296639',
#    'endMs': '305120',
#    'text': 'only a few large chunks and the reason for that is because if you put a meeting or you interrupt a 4-Hour long block',
#    'startTime': '4:56'},
#   {'startMs': '305120',
#    'endMs': '310759',
#    'text': "then you often can't get back to the work that you were doing before also if you know that you have a block that's",
#    'startTime': '5:05'},
#   {'startMs': '310759',
#    'endMs': '316120',
#    'text': "coming you can't get into the flow because you know that you're going to have to get out of the flow and so this",
#    'startTime': '5:10'},
#   {'startMs': '316120',
#    'endMs': '321639',
#    'text': "is like the end of day meeting that kills you this is called the zernick effect it's that we tend to remember",
#    'startTime': '5:16'},
#   {'startMs': '321639',
#    'endMs': '328280',
#    'text': "open loops and meetings are open Loops because you have to set timers so you don't forget it you have to start setting a timer before the timer to",
#    'startTime': '5:21'},
#   {'startMs': '328280',
#    'endMs': '334199',
#    'text': "start wrapping up even if you're using right now then you start thinking about the meeting and what you have to prepare for that meeting and now you're not",
#    'startTime': '5:28'},
#   {'startMs': '334199',
#    'endMs': '341000',
#    'text': 'thinking about your own work and this eats up your brain power and saps your ability to make unlike the manager where',
#    'startTime': '5:34'},
#   {'startMs': '341000',
#    'endMs': '347680',
#    'text': 'the decisions the direction and the coordination is the output of their work for the maker the stuff the things they',
#    'startTime': '5:41'},
#   {'startMs': '347680',
#    'endMs': '353280',
#    'text': 'build the things they make is the output of their time and so instead of working',
#    'startTime': '5:47'},
#   {'startMs': '353280',
#    'endMs': '359199',
#    'text': "on meetings they work off meetings they work on projects that can't get done in",
#    'startTime': '5:53'},
#   {'startMs': '359199',
#    'endMs': '366120',
#    'text': "30es minutes sometimes those projects last weeks months quarters until they're done and so the way that that work",
#    'startTime': '5:59'},
#   {'startMs': '366120',
#    'endMs': '372520',
#    'text': 'actually looks is that most makers have a set start time but variable end times so unlike the manager where they they',
#    'startTime': '6:06'},
#   {'startMs': '372520',
#    'endMs': '377759',
#    'text': "know when they start and they know when they finish most makers work open to goal if you've ever lost yourself in",
#    'startTime': '6:12'},
#   {'startMs': '377759',
#    'endMs': '383240',
#    'text': "your work and you're like man I just want to keep riding this this High I want to keep riding this flow that's",
#    'startTime': '6:17'},
#   {'startMs': '383240',
#    'endMs': '390000',
#    'text': "what it feels like to make you want to stay in there as long as you possibly can and that's why having no cap on the",
#    'startTime': '6:23'},
#   {'startMs': '390000',
#    'endMs': '396360',
#    'text': 'allows you to get lost in the work and produce more than you ever could so if you have only large time chunks that',
#    'startTime': '6:30'},
#   {'startMs': '396360',
#    'endMs': '401680',
#    'text': "means that you only have one or two per day sometimes three if you're working 18",
#    'startTime': '6:36'},
#   {'startMs': '401680',
#    'endMs': '406840',
#    'text': "hours and so that means you usually have a morning block and a post lunch block now if you're somebody who likes to also",
#    'startTime': '6:41'},
#   {'startMs': '406840',
#    'endMs': '413720',
#    'text': "work after dinner then you have a post dinner block so you basically have three four to six hour chunks per day that's",
#    'startTime': '6:46'},
#   {'startMs': '413720',
#    'endMs': '420479',
#    'text': 'it and on a sustainable basis most people just have two per day and so if someone takes one meeting in the morning',
#    'startTime': '6:53'},
#   {'startMs': '420479',
#    'endMs': '425879',
#    'text': 'they blew one of your 10 work blocks per week if you only work 5 days a week and',
#    'startTime': '7:00'},
#   {'startMs': '425879',
#    'endMs': '430919',
#    'text': "so someone's taking 10% of your total output by having one meeting the issue",
#    'startTime': '7:05'},
#   {'startMs': '430919',
#    'endMs': '436960',
#    'text': "is that that manager who's working on manager time puts that thing in and for them they're becoming more productive",
#    'startTime': '7:10'},
#   {'startMs': '436960',
#    'endMs': '444319',
#    'text': "but they're destroying your productivity when this happens is when you finish your day feel like you look back and",
#    'startTime': '7:16'},
#   {'startMs': '444319',
#    'endMs': '449840',
#    'text': 'know that all your time was spent but you got no return on it you have nothing to show for it and if you feel like you',
#    'startTime': '7:24'},
#   {'startMs': '449840',
#    'endMs': '456440',
#    'text': 'have that happen again and again and again this is how businesses stay small this is how entrepreneurs fail to grow',
#    'startTime': '7:29'},
#   {'startMs': '456440',
#    'endMs': '462800',
#    'text': 'This Is How They relive the same 6 months same 12 months same two years over and over and over again because',
#    'startTime': '7:36'},
#   {'startMs': '462800',
#    'endMs': '468440',
#    'text': 'they do not know how to invest their time for the maker an empty time slot is',
#    'startTime': '7:42'},
#   {'startMs': '468440',
#    'endMs': '473800',
#    'text': 'not a lost opportunity the empty time block is the opportunity to get the',
#    'startTime': '7:48'},
#   {'startMs': '473800',
#    'endMs': '479080',
#    'text': "return if you're a maker you understand what I'm about to share with you if you look at your calendar and see that you",
#    'startTime': '7:53'},
#   {'startMs': '479080',
#    'endMs': '484879',
#    'text': "have literally nothing on there you have no meetings you have no nothing it's just empty until the end of the day how",
#    'startTime': '7:59'},
#   {'startMs': '484879',
#    'endMs': '490919',
#    'text': "much energy are you filled with you're like oh my God I'm going to crush this day there's all this this big project I want to sink my teeth into it I'm going",
#    'startTime': '8:04'},
#   {'startMs': '490919',
#    'endMs': '497240',
#    'text': 'to be able to take a huge chunk out of it that energy that you get is because that is a maximally productive day is an',
#    'startTime': '8:10'},
#   {'startMs': '497240',
#    'endMs': '504919',
#    'text': 'empty calendar rather than a filled calendar and so for context when I was writing my book my days every day were',
#    'startTime': '8:17'},
#   {'startMs': '504919',
#    'endMs': '510759',
#    'text': "just writing the book and I told my team that that's all I was going to be doing you're like but don't you run this",
#    'startTime': '8:24'},
#   {'startMs': '510759',
#    'endMs': '516120',
#    'text': "portfolio of all these companies and there's all this money and these deals and decisions that have to happen and the answer is yes and when I show you my",
#    'startTime': '8:30'},
#   {'startMs': '516120',
#    'endMs': '524039',
#    'text': "calendar it'll all Mak sense so literally diametrically opposed calendars are both maximally allocated",
#    'startTime': '8:36'},
#   {'startMs': '524039',
#    'endMs': '530800',
#    'text': 'to invest time to get the highest Returns on it in terms of money the big problem is when the two need to interact',
#    'startTime': '8:44'},
#   {'startMs': '530800',
#    'endMs': '538320',
#    'text': 'because if you just had makers making and you just had managers managing everyone would be happy the problem is when managers manage makers and they',
#    'startTime': '8:50'},
#   {'startMs': '538320',
#    'endMs': '543880',
#    'text': "have to meet so when a manager doesn't know how makers work they kill the productivity",
#    'startTime': '8:58'},
#   {'startMs': '543880',
#    'endMs': '548959',
#    'text': 'of their team managers often assume that makers can work like they do on demand',
#    'startTime': '9:03'},
#   {'startMs': '548959',
#    'endMs': '554200',
#    'text': "they think it's hey it's just 30 minutes and you've got free time what's the big deal I looked at your calendar you have",
#    'startTime': '9:08'},
#   {'startMs': '554200',
#    'endMs': '559279',
#    'text': "nothing all day you're barely even working because they're using their measuring stick of work their way a",
#    'startTime': '9:14'},
#   {'startMs': '559279',
#    'endMs': '565480',
#    'text': "calendar looks when they're maximally effective and then transposing that on top of the Maker's calendar and thinking",
#    'startTime': '9:19'},
#   {'startMs': '565480',
#    'endMs': '571120',
#    'text': "these two are the same when they couldn't be more different for a manager a short meeting costs one work unit",
#    'startTime': '9:25'},
#   {'startMs': '571120',
#    'endMs': '577519',
#    'text': "which is maybe 15 minutes and for them they've got 20 plus per day so they can easily spare one whereas if they take",
#    'startTime': '9:31'},
#   {'startMs': '577519',
#    'endMs': '583279',
#    'text': 'one from a maker they take one of the two time slots you have per day and sometimes you take both based on what',
#    'startTime': '9:37'},
#   {'startMs': '583279',
#    'endMs': '589000',
#    'text': "the topic of the meeting is if you say hey we're going to do your quarterly performance as an employee at 2:00 in",
#    'startTime': '9:43'},
#   {'startMs': '589000',
#    'endMs': '594760',
#    'text': "the afternoon the likelihood that the employee leading up to that is going to be able to think about the work that they're going to do when they're worried",
#    'startTime': '9:49'},
#   {'startMs': '594760',
#    'endMs': '599920',
#    'text': "about their job or they're worried about their performance all day long and then afterwards they thinking about what they said and they could have said",
#    'startTime': '9:54'},
#   {'startMs': '599920',
#    'endMs': '605920',
#    'text': "differently that day shot to make matters worse if a maker is falling behind the manager's solution is to",
#    'startTime': '9:59'},
#   {'startMs': '605920',
#    'endMs': '611279',
#    'text': 'interrupt them more which creates a vicious cycle this means managers prevent the work that they check in on',
#    'startTime': '10:05'},
#   {'startMs': '611279',
#    'endMs': '616600',
#    'text': "so by checking in on them they disrupt the Maker's work so that they can't actually make during the time slot to",
#    'startTime': '10:11'},
#   {'startMs': '616600',
#    'endMs': '623120',
#    'text': "check in if they're actually working because the manager Works while on meetings where the Maker Works when they're off meetings and when this",
#    'startTime': '10:16'},
#   {'startMs': '623120',
#    'endMs': '629480',
#    'text': 'happens and it happens often both parties lose and this is the main point the manager loses because the maker is',
#    'startTime': '10:23'},
#   {'startMs': '629480',
#    'endMs': '634720',
#    'text': "not making what they need to be making and the manager is responsible for some level of output so both people aren't",
#    'startTime': '10:29'},
#   {'startMs': '634720',
#    'endMs': '641920',
#    'text': 'making the best Returns on their time this is why this is important for managers and important for makers so if you are on a team share this with your',
#    'startTime': '10:34'},
#   {'startMs': '641920',
#    'endMs': '648120',
#    'text': 'boss share this with your teammates so that this become like this can become more common in the Lexicon all my companies understand and use this',
#    'startTime': '10:41'},
#   {'startMs': '648120',
#    'endMs': '655519',
#    'text': 'language if you ask as a manager for a maker to make time for you they either',
#    'startTime': '10:48'},
#   {'startMs': '655519',
#    'endMs': '660760',
#    'text': "one offend the manager by saying no I can't do that because I'm working and",
#    'startTime': '10:55'},
#   {'startMs': '660760',
#    'endMs': '666920',
#    'text': "the M manager's like well I see that you have an empty time block and I outrank you or even if your peers it's like what",
#    'startTime': '11:00'},
#   {'startMs': '666920',
#    'endMs': '672040',
#    'text': "do you mean you're not going to give me that time I see that it's empty by refusing them they offend and they can",
#    'startTime': '11:06'},
#   {'startMs': '672040',
#    'endMs': '678279',
#    'text': 'incur other risks by making that you know offense and declining the invitation this often time damages the',
#    'startTime': '11:12'},
#   {'startMs': '678279',
#    'endMs': '683440',
#    'text': 'relationship and decreases the likelihood of collaboration in the future which they might need you as a',
#    'startTime': '11:18'},
#   {'startMs': '683440',
#    'endMs': '689680',
#    'text': 'maker might need the buying of that manager and so you risk losing that Goodwill by declining the invitation but',
#    'startTime': '11:23'},
#   {'startMs': '689680',
#    'endMs': '697360',
#    'text': 'by doing so if you accept the invitation you destroy the morning right and so option one piss someone off option two',
#    'startTime': '11:29'},
#   {'startMs': '697360',
#    'endMs': '704720',
#    'text': 'destroy half your day a very terrible proposition and the crazy part is that even if you accept that meeting often',
#    'startTime': '11:37'},
#   {'startMs': '704720',
#    'endMs': '710720',
#    'text': "times the yield from that meeting is nothing because the person who had the do you have five minutes didn't really",
#    'startTime': '11:44'},
#   {'startMs': '710720',
#    'endMs': '715920',
#    'text': "have an agenda didn't really have a plan and just basically said I'm just going to steal your morning from you and give",
#    'startTime': '11:50'},
#   {'startMs': '715920',
#    'endMs': '721120',
#    'text': "you nothing back by the way this totally applies to networking stuff too if you're like hey let me ince you to John",
#    'startTime': '11:55'},
#   {'startMs': '721120',
#    'endMs': '727760',
#    'text': "he's in the area you guys should meet for coffee does 10:00 a.m. work I'm like yeah let's just destroy everything right",
#    'startTime': '12:01'},
#   {'startMs': '727760',
#    'endMs': '733320',
#    'text': "let's just light my whole day on fire so that I can meet John who you think I have synergies with maybe there's",
#    'startTime': '12:07'},
#   {'startMs': '733320',
#    'endMs': '739240',
#    'text': "potential for collaboration let's explore opportunities together you know what's crazy I know what I need to do to",
#    'startTime': '12:13'},
#   {'startMs': '739240',
#    'endMs': '744800',
#    'text': 'make more money and I just need to do that I get asked all the time about',
#    'startTime': '12:19'},
#   {'startMs': '744800',
#    'endMs': '754920',
#    'text': "what's the one habit that you have that has been the highest you know predictor of your success and I really genuinely",
#    'startTime': '12:24'},
#   {'startMs': '754920',
#    'endMs': '760839',
#    'text': 'believe that it has been this is that I have been ruthless with my time everyone',
#    'startTime': '12:34'},
#   {'startMs': '760839',
#    'endMs': '766240',
#    'text': "who knows me knows that I am a dick with my time and the thing is is that I've",
#    'startTime': '12:40'},
#   {'startMs': '766240',
#    'endMs': '772240',
#    'text': 'been able to maintain relationships because during that maker time where I say no to everyone else I keep moving',
#    'startTime': '12:46'},
#   {'startMs': '772240',
#    'endMs': '777720',
#    'text': ' forward because I have a fundamental belief that as long as I continue to achieve and I continue to',
#    'startTime': '12:52'},
#   {'startMs': '777720',
#    'endMs': '784600',
#    'text': 'make things that are valuable for the World those meetings those connections those synergies that friend dinner will',
#    'startTime': '12:57'},
#   {'startMs': '784600',
#    'endMs': '790880',
#    'text': "always be there and that has proven right in my life and in the beginning it was the hardest because I didn't have",
#    'startTime': '13:04'},
#   {'startMs': '790880',
#    'endMs': '797040',
#    'text': 'the accomplishments to show for it but I truly believed I was like I know that if I can get this stuff done and I do it',
#    'startTime': '13:10'},
#   {'startMs': '797040',
#    'endMs': '803240',
#    'text': "every single day for a year two years three years five years if every day I move the ball forward that's the thing",
#    'startTime': '13:17'},
#   {'startMs': '803240',
#    'endMs': '808279',
#    'text': 'at the end of the month when I look back on what I actually accomplished 100% of it is stuff I accomplished during maker',
#    'startTime': '13:23'},
#   {'startMs': '808279',
#    'endMs': '815000',
#    'text': 'time not manager time and so once I realized that the maker time was where everything all the speed of me moving',
#    'startTime': '13:28'},
#   {'startMs': '815000',
#    'endMs': '820639',
#    'text': 'towards my goal was getting accomplished then I spent the rest of my time trying to optimize my life and create a system',
#    'startTime': '13:35'},
#   {'startMs': '820639',
#    'endMs': '825800',
#    'text': 'around this that allowed me to do as much of that as I possibly could and to',
#    'startTime': '13:40'},
#   {'startMs': '825800',
#    'endMs': '831079',
#    'text': "be clear there are roles in the business like if you're CEO or coo from an",
#    'startTime': '13:45'},
#   {'startMs': '831079',
#    'endMs': '837160',
#    'text': "operator perspective you're going to have more one-on ones you're going to have more team trainings you're going to have more coordination and",
#    'startTime': '13:51'},
#   {'startMs': '837160',
#    'endMs': '843000',
#    'text': "decision-making that's required but you just have to be clear that you're not not doing your job by not having maker",
#    'startTime': '13:57'},
#   {'startMs': '843000',
#    'endMs': '849040',
#    'text': "time it's just that your job is the manager stuff and then the maker time you have is to get more leverage on the",
#    'startTime': '14:03'},
#   {'startMs': '849040',
#    'endMs': '855680',
#    'text': "remainder of your manager time and so ilila has a different schedule than I do she still has maker time but it's",
#    'startTime': '14:09'},
#   {'startMs': '855680',
#    'endMs': '862160',
#    'text': 'probably inverted in terms of her schedule for her she has probably one maker day per week and four manager days',
#    'startTime': '14:15'},
#   {'startMs': '862160',
#    'endMs': '868680',
#    'text': 'where I have four maker days per week and one manager day and so you can have an inverted schedule but the important',
#    'startTime': '14:22'},
#   {'startMs': '868680',
#    'endMs': '874720',
#    'text': "thing is is that she has to have that makeer day because it's what gets her leverage gets her higher Returns on the",
#    'startTime': '14:28'},
#   {'startMs': '874720',
#    'endMs': '879839',
#    'text': 'other four days of the week and then for me I have to still do that manager day',
#    'startTime': '14:34'},
#   {'startMs': '879839',
#    'endMs': '885000',
#    'text': 'because it gives me leverage on all the organizational decisions that have to happen throughout the whole portfolio',
#    'startTime': '14:39'},
#   {'startMs': '885000',
#    'endMs': '891560',
#    'text': 'you have to get out of the either or thinking and think which of these Styles is best for me in this particular moment',
#    'startTime': '14:45'},
#   {'startMs': '891560',
#    'endMs': '897120',
#    'text': 'but I can promise you that you do have elements of both when most people have elements of neither which is why they',
#    'startTime': '14:51'},
#   {'startMs': '897120',
#    'endMs': '902399',
#    'text': "never move forward so I think I've accurately described the problem here makers and managers work differently",
#    'startTime': '14:57'},
#   {'startMs': '902399',
#    'endMs': '908519',
#    'text': "these guys want empty calendars these guys want filled calendars when they interact one person destroys the other person time and it's a disproportionate",
#    'startTime': '15:02'},
#   {'startMs': '908519',
#    'endMs': '914199',
#    'text': 'trade and when things get bad they get even worse because the managers interrupt the makers even more and the',
#    'startTime': '15:08'},
#   {'startMs': '914199',
#    'endMs': '920320',
#    'text': "makers trying to be polite because they don't want to turn down invitations just make their lives worse and worse and they have to work longer and longer",
#    'startTime': '15:14'},
#   {'startMs': '920320',
#    'endMs': '925880',
#    'text': 'hours lose sleep lose family time lose their weekend so that they can just keep up with their work without pissing',
#    'startTime': '15:20'},
#   {'startMs': '925880',
#    'endMs': '930959',
#    'text': "anyone off and so let's talk about a different way way to do this so I use",
#    'startTime': '15:25'},
#   {'startMs': '930959',
#    'endMs': '936279',
#    'text': "something called a three-pronged approach for the solutions and that's because you have to address it from all",
#    'startTime': '15:30'},
#   {'startMs': '936279',
#    'endMs': '943199',
#    'text': "angles it's not just saying hey makers deal with it hey managers do something different hey organizations you have to",
#    'startTime': '15:36'},
#   {'startMs': '943199',
#    'endMs': '948959',
#    'text': "attack it from all three directions you've got the managers you've got what the makers should do differently and",
#    'startTime': '15:43'},
#   {'startMs': '948959',
#    'endMs': '955319',
#    'text': "then you've got the organization overall so you've got all three of these parties that you have to",
#    'startTime': '15:48'},
#   {'startMs': '955319',
#    'endMs': '960839',
#    'text': 'accommodate to the managers step one under understand both the costs that you',
#    'startTime': '15:55'},
#   {'startMs': '960839',
#    'endMs': '968120',
#    'text': "put on the maker the first cost is the cost of coordinating times while they work so they're trying to work right now",
#    'startTime': '16:00'},
#   {'startMs': '968120',
#    'endMs': '973480',
#    'text': "before you coordinate the time that you're also going to disrupt them so you disrupt them while they're working and",
#    'startTime': '16:08'},
#   {'startMs': '973480',
#    'endMs': '980360',
#    'text': "then you disrupt them at the meeting that you're trying to plan so you disrupt them twice secondly and once you have that",
#    'startTime': '16:13'},
#   {'startMs': '980360',
#    'endMs': '985839',
#    'text': 'time set aside understand that the time itself eats an entire work block itself and you have to know the difference',
#    'startTime': '16:20'},
#   {'startMs': '985839',
#    'endMs': '992279',
#    'text': "between your work and the Maker's work and when you ask for a meeting it costs them 10 times more you use up one of",
#    'startTime': '16:25'},
#   {'startMs': '992279',
#    'endMs': '999800',
#    'text': 'their 10 time slots per week whereas you use up only one of your hundred or more time slots so when you choose to make an',
#    'startTime': '16:32'},
#   {'startMs': '999800',
#    'endMs': '1006800',
#    'text': "appointment or choose to make a meeting be sure that it's worth it especially if it's an ad hoc or impromptu if you have",
#    'startTime': '16:39'},
#   {'startMs': '1006800',
#    'endMs': '1013440',
#    'text': 'a set Cadence of communication if it can wait until that time and you got to be really real with yourself can it wait is',
#    'startTime': '16:46'},
#   {'startMs': '1013440',
#    'endMs': '1020079',
#    'text': "this just a convenience thing for me or a preference if it is then don't destroy the poor man or poor woman's time step",
#    'startTime': '16:53'},
#   {'startMs': '1020079',
#    'endMs': '1026000',
#    'text': 'two understand the value of the makers no and this is something that I hopefully becomes incorporate in your',
#    'startTime': '17:00'},
#   {'startMs': '1026000',
#    'endMs': '1032520',
#    'text': "Lexicon at your business is that this is a maker's no not a not a real world no it's a maker's no is that if a maker",
#    'startTime': '17:06'},
#   {'startMs': '1032520',
#    'endMs': '1038959',
#    'text': "declines a meeting don't take offense see it as them actually trying to keep their larger commitment to you the",
#    'startTime': '17:12'},
#   {'startMs': '1038959',
#    'endMs': '1044480',
#    'text': "company and other people to get the meaningful work they need to get done done and so this means you don't get",
#    'startTime': '17:18'},
#   {'startMs': '1044480',
#    'endMs': '1050360',
#    'text': "offended this means you don't you know hold back the the promotion or say that they're not being productive because",
#    'startTime': '17:24'},
#   {'startMs': '1050360',
#    'endMs': '1056039',
#    'text': "they keep turning down meetings if someone turns down the meeting it's because they're doing something that they can accurately say this is more",
#    'startTime': '17:30'},
#   {'startMs': '1056039',
#    'endMs': '1061559',
#    'text': 'important than that now if you as a manager say I know that you have this is going to destroy the morning in terms of',
#    'startTime': '17:36'},
#   {'startMs': '1061559',
#    'endMs': '1067440',
#    'text': 'your productivity but I think it is worth your time to be on this because we need your Insight then you can frame it',
#    'startTime': '17:41'},
#   {'startMs': '1067440',
#    'endMs': '1072480',
#    'text': 'that way and then you can give the maker the time to prep for that meeting if it is literally of that importance step',
#    'startTime': '17:47'},
#   {'startMs': '1072480',
#    'endMs': '1077919',
#    'text': "three for managers is actually ask your team what an ideal day would look like for them like what's a maximum",
#    'startTime': '17:52'},
#   {'startMs': '1077919',
#    'endMs': '1083640',
#    'text': 'productive day look like like and allow them the time to give you the response and I suggest following that to the',
#    'startTime': '17:57'},
#   {'startMs': '1083640',
#    'endMs': '1089679',
#    'text': 'greatest degree possible so that you can actually help them be the most productive and so for example for us uh',
#    'startTime': '18:03'},
#   {'startMs': '1089679',
#    'endMs': '1095480',
#    'text': "our media team leaders asked the editing team underneath of them hey what's the",
#    'startTime': '18:09'},
#   {'startMs': '1095480',
#    'endMs': '1101679',
#    'text': "perfect day for you guys what's a perfect weekly calendar look like and as a team they were like well if we could just Bunch all the meetings here and we",
#    'startTime': '18:15'},
#   {'startMs': '1101679',
#    'endMs': '1107600',
#    'text': "could have all the rest of the days free that would be awesome and then if we had it was like okay well how do what about when we coordinate it's okay well we'll",
#    'startTime': '18:21'},
#   {'startMs': '1107600',
#    'endMs': '1113200',
#    'text': 'have specific coordination times that we keep four brainstorming sessions and things like that but beyond that we keep',
#    'startTime': '18:27'},
#   {'startMs': '1113200',
#    'endMs': '1118720',
#    'text': "everyone's calendars empty and so that way as a team you as a as a manager also",
#    'startTime': '18:33'},
#   {'startMs': '1118720',
#    'endMs': '1124840',
#    'text': "can have fewer meetings so that you can fill out with other meetings that aren't makers right so you can do more leading more directing more encouraging more",
#    'startTime': '18:38'},
#   {'startMs': '1124840',
#    'endMs': '1130360',
#    'text': "persuading more training and then let the makers make and we've also realized and I think you will break your own",
#    'startTime': '18:44'},
#   {'startMs': '1130360',
#    'endMs': '1136640',
#    'text': "belief around this as soon as you start doing this that a lot of work doesn't have to be done at the same time everyone doesn't need to work on the",
#    'startTime': '18:50'},
#   {'startMs': '1136640',
#    'endMs': '1142840',
#    'text': 'same thing at the same moment to get the most done as long as everything gets done by this period of time now this',
#    'startTime': '18:56'},
#   {'startMs': '1142840',
#    'endMs': '1148960',
#    'text': "video isn't the protect the makers video this is for all businesses and all business owners so let's talk to the",
#    'startTime': '19:02'},
#   {'startMs': '1148960',
#    'endMs': '1154480',
#    'text': 'makers now step one good managers want to help',
#    'startTime': '19:08'},
#   {'startMs': '1154480',
#    'endMs': '1159799',
#    'text': 'you so let them tell them how you work this is you communicating to them send',
#    'startTime': '19:14'},
#   {'startMs': '1159799',
#    'endMs': '1165039',
#    'text': 'this piece of content to them to help them help you and yes you will have to',
#    'startTime': '19:19'},
#   {'startMs': '1165039',
#    'endMs': '1170080',
#    'text': "take meetings that eat your entire day sometimes it's part of the job you have have to work with other people because",
#    'startTime': '19:25'},
#   {'startMs': '1170080',
#    'endMs': '1175840',
#    'text': 'your project would never see the light of day without marketing marketing it sales selling it product delivering it',
#    'startTime': '19:30'},
#   {'startMs': '1175840',
#    'endMs': '1181960',
#    'text': "and everything else that happens in between it's a team and so if your manager is going to choose to put a Time",
#    'startTime': '19:35'},
#   {'startMs': '1181960',
#    'endMs': '1188080',
#    'text': 'Block in the middle of your morning or the middle of your afternoon then switch that whole block into a manager schedule',
#    'startTime': '19:41'},
#   {'startMs': '1188080',
#    'endMs': '1195240',
#    'text': 'Fight Fire with Fire and try to knock out as many meetings as you can in that formally free time so that means that',
#    'startTime': '19:48'},
#   {'startMs': '1195240',
#    'endMs': '1200520',
#    'text': "okay if I know that I'm going to have this one time slot that's killed my big chunk well then let's slice that baby",
#    'startTime': '19:55'},
#   {'startMs': '1200520',
#    'endMs': '1206440',
#    'text': 'into as many chunks as I can and get all the other ad hoc impromptu meetings done that morning so that I now switch to a',
#    'startTime': '20:00'},
#   {'startMs': '1206440',
#    'endMs': '1211880',
#    'text': "maximally productive manager and so the thing is is that you don't want to identify as one or the other you just",
#    'startTime': '20:06'},
#   {'startMs': '1211880',
#    'endMs': '1219039',
#    'text': "want your calendar to reflect the nature of the work and so the point here isn't to have two camps of makers and managers",
#    'startTime': '20:11'},
#   {'startMs': '1219039',
#    'endMs': '1225000',
#    'text': "is to understand what type of productivity system you're installing for that period of time on your calendar",
#    'startTime': '20:19'},
#   {'startMs': '1225000',
#    'endMs': '1230640',
#    'text': "because especially if you're an entrepreneur you've got to wear both step two for makers have standard",
#    'startTime': '20:25'},
#   {'startMs': '1230640',
#    'endMs': '1236640',
#    'text': 'meeting times where you accept meetings so you say Hey you know Monday and uh',
#    'startTime': '20:30'},
#   {'startMs': '1236640',
#    'endMs': '1242640',
#    'text': 'Thursday afternoons is when I have all of my meeting times open so whenever someone requests a meeting ask them if',
#    'startTime': '20:36'},
#   {'startMs': '1242640',
#    'endMs': '1249200',
#    'text': "they can make it in those times and this is where when you get into the organization if everyone has those times then everyone's on maker schedules for",
#    'startTime': '20:42'},
#   {'startMs': '1249200',
#    'endMs': '1255960',
#    'text': "those time blocks and then it becomes more efficient at an organizational level which I'll get to in a second it's rare that a meeting is truly urgent so",
#    'startTime': '20:49'},
#   {'startMs': '1255960',
#    'endMs': '1262679',
#    'text': 'if you can push them off to those designated blocks that you said ahead of time you will make a lot more money with the time that you have remaining and you',
#    'startTime': '20:55'},
#   {'startMs': '1262679',
#    'endMs': '1268960',
#    'text': 'want to make this time available to anyone who meets with you on a regular basis and add some empty time slots or',
#    'startTime': '21:02'},
#   {'startMs': '1268960',
#    'endMs': '1275760',
#    'text': "leave some empty time slots in that maker meetings for the ad hoc meetings that inevitably come up I would say I've gone through three distinct periods of",
#    'startTime': '21:08'},
#   {'startMs': '1275760',
#    'endMs': '1281159',
#    'text': 'understanding this maker manager concept and using it to great success the first',
#    'startTime': '21:15'},
#   {'startMs': '1281159',
#    'endMs': '1286600',
#    'text': 'one is you basically have to do nights and weekends uh in Early Mornings in order to get your maker time in but you',
#    'startTime': '21:21'},
#   {'startMs': '1286600',
#    'endMs': '1292400',
#    'text': 'have to do it and so when I was doing this as a gym owner so a small business owner I would wake up and I would like',
#    'startTime': '21:26'},
#   {'startMs': '1292400',
#    'endMs': '1298640',
#    'text': "work on ad copy and work on ads which was like deep work that I'd have to do and then I'd step into the gym at 9:00",
#    'startTime': '21:32'},
#   {'startMs': '1298640',
#    'endMs': '1304400',
#    'text': 'a.m. and start taking sales calls or uh take training sessions or have to have',
#    'startTime': '21:38'},
#   {'startMs': '1304400',
#    'endMs': '1310960',
#    'text': 'one on- ones with my trainers like I worked like a regular person with fires and people interrupting me all day because I was running a small business',
#    'startTime': '21:44'},
#   {'startMs': '1310960',
#    'endMs': '1317080',
#    'text': "and so if you need to make sure that that maker work gets done then you need to find one block that's usually at the",
#    'startTime': '21:50'},
#   {'startMs': '1317080',
#    'endMs': '1323080',
#    'text': "very beginning of the day or the very end of the day if you're the entrepreneur and no one cares about your time in the beginning if I had not done",
#    'startTime': '21:57'},
#   {'startMs': '1323080',
#    'endMs': '1329240',
#    'text': "that I don't think I ever would have gotten out of one location I would never have been able to build the systems that it takes like how do you build the",
#    'startTime': '22:03'},
#   {'startMs': '1329240',
#    'endMs': '1335279',
#    'text': "training system to get trainers on you do it in maker time how do you build the nutrition system that you're going to use for your whole location you do it",
#    'startTime': '22:09'},
#   {'startMs': '1335279',
#    'endMs': '1341799',
#    'text': 'during maker time how you going to run an advertising system for creating ads and writing copy on a regular basis you do that during maker time not during',
#    'startTime': '22:15'},
#   {'startMs': '1341799',
#    'endMs': '1348080',
#    'text': 'manager time and so to build the assets that I could build the business on top of to build the Enterprise I had to do',
#    'startTime': '22:21'},
#   {'startMs': '1348080',
#    'endMs': '1353120',
#    'text': 'that in uninterrupted time chunks and the problem was everybody want to interrupt my time and to be fair they',
#    'startTime': '22:28'},
#   {'startMs': '1353120',
#    'endMs': '1358159',
#    'text': "could because I didn't have my my time wasn't super valuable in the beginning over time you'll begin to have people",
#    'startTime': '22:33'},
#   {'startMs': '1358159',
#    'endMs': '1364200',
#    'text': 'who can start protecting your time for you so for a big chunk of my career as I started to make more and more money the',
#    'startTime': '22:38'},
#   {'startMs': '1364200',
#    'endMs': '1369320',
#    'text': 'first half of every day until noon or 1 p.m. was always wide open because I do',
#    'startTime': '22:44'},
#   {'startMs': '1369320',
#    'endMs': '1375799',
#    'text': "my best work in the morning and then once I've kind of used up my Creative Juice I can do the coordination and meetings and things like that now I'll",
#    'startTime': '22:49'},
#   {'startMs': '1375799',
#    'endMs': '1381159',
#    'text': "give you a second Pro tip on this which is if that is the way that you want to plan your calendar let's call yourself",
#    'startTime': '22:55'},
#   {'startMs': '1381159',
#    'endMs': '1386840',
#    'text': 'an intermediate entrepreneur start planning your day back to front so what',
#    'startTime': '23:01'},
#   {'startMs': '1386840',
#    'endMs': '1392679',
#    'text': 'I mean by that is someone wants a meeting you start at it ends at 5: and starts at 4: if someone else wants a',
#    'startTime': '23:06'},
#   {'startMs': '1392679',
#    'endMs': '1398679',
#    'text': 'meeting then you say it ends at it ends at 4 and starts at 3:30 and you work your calendar from Back to Front that',
#    'startTime': '23:12'},
#   {'startMs': '1398679',
#    'endMs': '1404360',
#    'text': 'way your front of the day is still the most open you possibly can have it now you still suffer from the quote zernick',
#    'startTime': '23:18'},
#   {'startMs': '1404360',
#    'endMs': '1411200',
#    'text': 'effect but you still have a very large chunk of uninterrupted time and by doing it this way you avoid those empty dead',
#    'startTime': '23:24'},
#   {'startMs': '1411200',
#    'endMs': '1417760',
#    'text': "times where you're like great I have 45 minutes between two meetings like what am I going to do now and you're like I guess I'll just have a snack so if you",
#    'startTime': '23:31'},
#   {'startMs': '1417760',
#    'endMs': '1423120',
#    'text': "have less means then you work double time you work on your client's time and then you do your work in off hours so",
#    'startTime': '23:37'},
#   {'startMs': '1423120',
#    'endMs': '1429960',
#    'text': 'like I was saying in my early days by doing that morning five days a week and then I would work both shifts on the',
#    'startTime': '23:43'},
#   {'startMs': '1429960',
#    'endMs': '1435880',
#    'text': 'weekends I would get four on the weekends I get a morning and an afternoon on Saturday and Sunday that I can put maker time in and then I get',
#    'startTime': '23:49'},
#   {'startMs': '1435880',
#    'endMs': '1441960',
#    'text': "five blocks during the week and so this still gave me nine makers blocks per week to move Big Stuff forward that's a",
#    'startTime': '23:55'},
#   {'startMs': '1441960',
#    'endMs': '1448120',
#    'text': "full-time job but the key here if you're noticing is that yes you work double because you have to work the job that",
#    'startTime': '24:01'},
# ...
#    'endMs': '1762679',
#    'text': 'kind of keep a pulse on yourself and also managers to extend the time trust where you allow makers to make now if',
#    'startTime': '29:14'},
#   {'startMs': '1762679',
#    'endMs': '1767880',
#    'text': 'they do not meet the deadlines and they are not meeting the output then you need to be very clear about this is the trust',
#    'startTime': '29:22'},
#   {'startMs': '1767880',
#    'endMs': '1772960',
#    'text': 'that extending to you so what is the reason that you have for not getting this done and real real a lot of times',
#    'startTime': '29:27'},
#   {'startMs': '1772960',
#    'endMs': '1779000',
#    'text': "you actually have to dig into their personal lives cuz that's usually the mess anyways as an entrepreneur you're often going to have times where you're a",
#    'startTime': '29:32'},
#   {'startMs': '1779000',
#    'endMs': '1786000',
#    'text': "maker and a times where you're a manager and being clear to your team about Which hat you're wearing so I literally say",
#    'startTime': '29:39'},
#   {'startMs': '1786000',
#    'endMs': '1792080',
#    'text': "hey I'm putting my maker hat on today hey manager hat before I step into something and that gives me and them a",
#    'startTime': '29:46'},
#   {'startMs': '1792080',
#    'endMs': '1797640',
#    'text': "mental cue to know how I'm operating for that day and kind of the Rules of Engagement and by doing it that way it",
#    'startTime': '29:52'},
#   {'startMs': '1797640',
#    'endMs': '1803039',
#    'text': "sets it's it sets all the expectations with one thing one change of hat rather than me have to re-explain the rules",
#    'startTime': '29:57'},
#   {'startMs': '1803039',
#    'endMs': '1809120',
#    'text': 'every time all right before the last and most important point for organizations let me',
#    'startTime': '30:03'},
#   {'startMs': '1809120',
#    'endMs': '1815519',
#    'text': 'show you my calendar and walk you through it so this is an actual time uh block I think today is the 31st of May',
#    'startTime': '30:09'},
#   {'startMs': '1815519',
#    'endMs': '1821559',
#    'text': "um as we're actually recording this and so this is my this is my actual calendar and so you'll notice that we had uh we",
#    'startTime': '30:15'},
#   {'startMs': '1821559',
#    'endMs': '1828200',
#    'text': 'had Labor Day weekend right so Monday um I actually took off on Monday um so this was a short week but Wednesday Thursday',
#    'startTime': '30:21'},
#   {'startMs': '1828200',
#    'endMs': '1834000',
#    'text': "Friday I have nothing on here except for maker time so you recording for me is maker time like I'm making these videos",
#    'startTime': '30:28'},
#   {'startMs': '1834000',
#    'endMs': '1841120',
#    'text': "I can't do this and then take a meeting and then come back and make this video right like I have to stay in it until it's done and so this whole day all",
#    'startTime': '30:34'},
#   {'startMs': '1841120',
#    'endMs': '1846840',
#    'text': 'three of these days are just straight up empty and you can see I have a gym meeting with myself uh in the afternoon',
#    'startTime': '30:41'},
#   {'startMs': '1846840',
#    'endMs': '1852559',
#    'text': "so I can get swole so I was telling you that on Wednesdays we have our quiet day for editors but it's actually",
#    'startTime': '30:46'},
#   {'startMs': '1852559',
#    'endMs': '1858399',
#    'text': "organization wide and we just separated people into are you a maker are you a manager and so if you're a manager you",
#    'startTime': '30:52'},
#   {'startMs': '1858399',
#    'endMs': '1864559',
#    'text': "deal with lots of time slots and this just doesn't apply to you but for everyone else in the organization which everyone else has transparency into all",
#    'startTime': '30:58'},
#   {'startMs': '1864559',
#    'endMs': '1870279',
#    'text': 'of Wednesday is an acquisition. comom quiet day and the reason that we put it on Wednesday was that way if you think',
#    'startTime': '31:04'},
#   {'startMs': '1870279',
#    'endMs': '1876240',
#    'text': "about how the week works out it's like you have two quiet days on the weekend no matter what and then you have two days that could potentially get",
#    'startTime': '31:10'},
#   {'startMs': '1876240',
#    'endMs': '1882799',
#    'text': 'interrupted with another day in between so basically the longest amount of time that you have to wait is two days before you can have a guaranteed quiet day now',
#    'startTime': '31:16'},
#   {'startMs': '1882799',
#    'endMs': '1888559',
#    'text': "you'll notice that Tuesday basically functioned as my Monday for this week I had a team meeting with my whole company",
#    'startTime': '31:22'},
#   {'startMs': '1888559',
#    'endMs': '1894840',
#    'text': "I had a one1 with my head of investment he's the one who runs our deals I had my executive meeting uh which is just uh",
#    'startTime': '31:28'},
#   {'startMs': '1894840',
#    'endMs': '1901639',
#    'text': 'all the leaders in my company at acquisition. comom I had a oneon-one with my book manager I had um meeting',
#    'startTime': '31:34'},
#   {'startMs': '1901639',
#    'endMs': '1908080',
#    'text': "with our Workshop manager because uh we wanted to touch base and after that meeting I said let's not have this meeting anymore immediately after the",
#    'startTime': '31:41'},
#   {'startMs': '1908080',
#    'endMs': '1913919',
#    'text': 'meeting so to be clear like I try to always audit like do I need to do this again or is there a processor a person',
#    'startTime': '31:48'},
#   {'startMs': '1913919',
#    'endMs': '1919639',
#    'text': 'who can do this instead of me and most times there is a processor person after after that I had my school games Q&A so',
#    'startTime': '31:53'},
#   {'startMs': '1919639',
#    'endMs': '1926240',
#    'text': 'I had once a week I take a call with the school games and notice I do these calls that I have with customers on my meeting',
#    'startTime': '31:59'},
#   {'startMs': '1926240',
#    'endMs': '1931919',
#    'text': "day because it's still an interruption and it to me it feels the same it's like I hop on I'm asking questions I'm answering questions I'm directing I'm",
#    'startTime': '32:06'},
#   {'startMs': '1931919',
#    'endMs': '1937200',
#    'text': 'doing whatever then I had my marketing meeting for our internal marketing stuff and that was it I had a hair trim and',
#    'startTime': '32:11'},
#   {'startMs': '1937200',
#    'endMs': '1942799',
#    'text': "then I had my gym all right and so you'll be like wait that's it I just saw Alex's whole week that's all the",
#    'startTime': '32:17'},
#   {'startMs': '1942799',
#    'endMs': '1948159',
#    'text': 'meetings he takes and the answer is yes now I think what might be more important',
#    'startTime': '32:22'},
#   {'startMs': '1948159',
#    'endMs': '1953639',
#    'text': "than the things that you saw or the things that you didn't see and so there's meetings that happen all the",
#    'startTime': '32:28'},
#   {'startMs': '1953639',
#    'endMs': '1960360',
#    'text': 'time with the leadership with my team and portfolio companies with you know my media buyer and their media buyer my you',
#    'startTime': '32:33'},
#   {'startMs': '1960360',
#    'endMs': '1966639',
#    'text': "know uh portfolio operating partner and the CEOs of the companies that we own right all of those meetings you'll note",
#    'startTime': '32:40'},
#   {'startMs': '1966639',
#    'endMs': '1972960',
#    'text': 'none of them were on my calendar at some point I see the entrepreneurial Journey as a relinquishing of control and at',
#    'startTime': '32:46'},
#   {'startMs': '1972960',
#    'endMs': '1978200',
#    'text': "every level of Entrepreneurship you need to learn a new level of giving up control and so it's interesting is that",
#    'startTime': '32:52'},
#   {'startMs': '1978200',
#    'endMs': '1984600',
#    'text': 'when we get into entrepreneurship we do it because we want freedom but as soon as we do it to get Freedom we actually have absolute control over everything',
#    'startTime': '32:58'},
#   {'startMs': '1984600',
#    'endMs': '1989639',
#    'text': "because you have control of you're a solo preneur now like you have no team it's just you but when you have control",
#    'startTime': '33:04'},
#   {'startMs': '1989639',
#    'endMs': '1996440',
#    'text': "over everything you actually don't have freedom so you cannot have both absolute control and absolute freedom at the same time and so if you want freedom you have",
#    'startTime': '33:09'},
#   {'startMs': '1996440',
#    'endMs': '2001840',
#    'text': 'to relinquish control you have to extend trust to people now those trusts can have guard rails and you can still have',
#    'startTime': '33:16'},
#   {'startMs': '2001840',
#    'endMs': '2007279',
#    'text': "outputs that you measure people on and then you basically tighten up the Reigns if things don't go to plan but as as",
#    'startTime': '33:21'},
#   {'startMs': '2007279',
#    'endMs': '2012720',
#    'text': "long as people are doing their job and meeting the outputs then you can continue to kind of extend the leash I don't really like the terminology but",
#    'startTime': '33:27'},
#   {'startMs': '2012720',
#    'endMs': '2018279',
#    'text': "you get the idea and so at the end of every one of these meetings I'm telling you like if you could just put a little",
#    'startTime': '33:32'},
#   {'startMs': '2018279',
#    'endMs': '2024679',
#    'text': 'reminder to yourself those do I need to do this again a like does this meeting even need to occur again and secondarily',
#    'startTime': '33:38'},
#   {'startMs': '2024679',
#    'endMs': '2030639',
#    'text': "is there somebody else or a system we can put in place to eliminate this all together Lila and I she's even better",
#    'startTime': '33:44'},
#   {'startMs': '2030639',
#    'endMs': '2036679',
#    'text': 'about this because she has more meetings as an operator than I do um every single week she starts her week by looking at',
#    'startTime': '33:50'},
#   {'startMs': '2036679',
#    'endMs': '2042919',
#    'text': 'all of her meetings and deletes she deletes first and then on a quarterly basis she looks at all recurring',
#    'startTime': '33:56'},
#   {'startMs': '2042919',
#    'endMs': '2048520',
#    'text': "meetings and says how do I how can I change the time that's being allocated across the whole company so she sees",
#    'startTime': '34:02'},
#   {'startMs': '2048520',
#    'endMs': '2054398',
#    'text': "everyone's calendars and everyone's meetings she does some Rainman stuff where she says I don't think we need to do this anymore I think we can combine",
#    'startTime': '34:08'},
#   {'startMs': '2054398',
#    'endMs': '2060878',
#    'text': "these two I think you don't need to attend the and she tells people I don't think you need to attend this anymore I don't think you need to attend this and I think that's where a culture of",
#    'startTime': '34:14'},
#   {'startMs': '2060878',
#    'endMs': '2067320',
#    'text': "meetings don't make you productive is a very important subline here for organizations in general and you'll",
#    'startTime': '34:20'},
#   {'startMs': '2067320',
#    'endMs': '2073839',
#    'text': 'notice this with Elon Musk and basos and some of these these great entrepreneurs they talk about this where they want to standardize like hey you can get up in',
#    'startTime': '34:27'},
#   {'startMs': '2073839',
#    'endMs': '2079960',
#    'text': "the middle of meeting and say hey I've just got stuff I need to do and I don't think I'm relevant here or I don't think I'm adding value that's you returning",
#    'startTime': '34:33'},
#   {'startMs': '2079960',
#    'endMs': '2086679',
#    'text': "time to the company because this is the thing that everyone forgets is that let's say let's say uh you make $50,000",
#    'startTime': '34:39'},
#   {'startMs': '2086679',
#    'endMs': '2093720',
#    'text': 'a year that means that you make around $25 per hour in general and so if you',
#    'startTime': '34:46'},
#   {'startMs': '2093720',
#    'endMs': '2100880',
#    'text': "have and let's say you've got some people are making $100,000 a year on the meeting so that's $50 per hour that means that if you have 10",
#    'startTime': '34:53'},
#   {'startMs': '2100880',
#    'endMs': '2106960',
#    'text': "people on that on a on a on a one-h hour call it's like that was a $500 call or a",
#    'startTime': '35:00'},
#   {'startMs': '2106960',
#    'endMs': '2113280',
#    'text': "$400 call now if we took the whole team out to Chili's and we spent $400 on",
#    'startTime': '35:06'},
#   {'startMs': '2113280',
#    'endMs': '2120560',
#    'text': "drinks and chips and whatever it'd be considered a major expense right but every day all the time you're taking the",
#    'startTime': '35:13'},
#   {'startMs': '2120560',
#    'endMs': '2126720',
#    'text': "whole team out to chilies 10 times a day this is why people stay poor because they don't know how to allocate time to",
#    'startTime': '35:20'},
#   {'startMs': '2126720',
#    'endMs': '2131800',
#    'text': "get the highest return so let's walk through the last step for",
#    'startTime': '35:26'},
#   {'startMs': '2131800',
#    'endMs': '2137599',
#    'text': 'organizations to make this real to get the most out of everyone spread this',
#    'startTime': '35:31'},
#   {'startMs': '2137599',
#    'endMs': '2145720',
#    'text': 'content to Makers and managers alike so that everyone can use the same language to describe this larger source of waste',
#    'startTime': '35:37'},
#   {'startMs': '2145720',
#    'endMs': '2151880',
#    'text': 'and prevent it because if you are working with a maker manager schedule where everyone understands where people',
#    'startTime': '35:45'},
#   {'startMs': '2151880',
#    'endMs': '2157400',
#    'text': 'can get the highest returns in their time and your comp competition is not working this way you will get higher',
#    'startTime': '35:51'},
#   {'startMs': '2157400',
#    'endMs': '2163040',
#    'text': 'returns Returns on human capital on the time you invest in people because they will be happier they will stay longer',
#    'startTime': '35:57'},
#   {'startMs': '2163040',
#    'endMs': '2168520',
#    'text': "they will have higher output and the quality of their work will go up so you'll both get higher quantity of work",
#    'startTime': '36:03'},
#   {'startMs': '2168520',
#    'endMs': '2175400',
#    'text': 'and higher quality of work both by changing how you allocate time and try and actively remove as many makers as',
#    'startTime': '36:08'},
#   {'startMs': '2175400',
#    'endMs': '2182079',
#    'text': "possible from meetings and also managers don't need to be there and my goal with this video is to increase the awareness",
#    'startTime': '36:15'},
#   {'startMs': '2182079',
#    'endMs': '2187920',
#    'text': "of these two types of working Styles and put words to something that plagued me for a very long time and so if you're",
#    'startTime': '36:22'},
#   {'startMs': '2187920',
#    'endMs': '2193800',
#    'text': "listening to this and you're like this is music to my ears this is what I've been trying to describe for such a long time and I have been able to put words",
#    'startTime': '36:27'},
#   {'startMs': '2193800',
#    'endMs': '2199560',
#    'text': 'to it I made this for you so that I could put words to something that hopefully everyone else can use and',
#    'startTime': '36:33'},
#   {'startMs': '2199560',
#    'endMs': '2205000',
#    'text': "distribute at a bargain on time is that you don't have to worry about making this thing you can just send it so that",
#    'startTime': '36:39'},
#   {'startMs': '2205000',
#    'endMs': '2212440',
#    'text': 'people can understand it for you and hopefully this gives words to the makers whose work moves the world and helps',
#    'startTime': '36:45'},
#   {'startMs': '2212440',
#    'endMs': '2218560',
#    'text': 'managers understand how expensive got a minute really is',
#    'startTime': '36:52'}],
#  'languages': [{'params': 'CgtHSVJrUVFIenN4SRISQ2dOaGMzSVNBbVZ1R2dBJTNEGAEqM2VuZ2FnZW1lbnQtcGFuZWwtc2VhcmNoYWJsZS10cmFuc2NyaXB0LXNlYXJjaC1wYW5lbDAAOAFAAA%3D%3D',
#    'selected': True,
#    'title': 'English (auto-generated)'}]}

# %% [markdown]
# ### **get_comments**
#
# ##### `get_comments(video_id: str, max_results: int = 20, include_replies: bool = True, order: str = 'relevance', text_format: str = 'plainText', search_terms: str = None, **kwargs)`
#
# The `get_comments` method retrieves comments from a specified YouTube video.
#
# **Parameters:**
# - `video_id` (str): The ID of the YouTube video.
# - `max_results` (int, optional): The maximum number of comments to retrieve. Defaults to 20.
# - `include_replies` (bool, optional): If True, includes replies to comments. Defaults to True.
# - `order` (str, optional): The order of comments ('relevance' or 'time'). Defaults to 'relevance'.
# - `text_format` (str, optional): The format of the comment text ('html' or 'plainText'). Defaults to 'plainText'.
# - `search_terms` (str, optional): Terms to filter comments.
# - `**kwargs`: Additional parameters.
#
# **Returns:**
# - `dict`: A dictionary containing the comments.
#
# ##### **Example**

# %%
youtube.get_comments('GIRkQQHzsxI')
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': '1hMAhEwa8kkzNzxsymxwFrey7-c',
#  'nextPageToken': '...',
#  'pageInfo': {'totalResults': 20, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': '863VnmLGSdJCz8tYyACkDufFQno',
#    'id': 'UgzmxQVvj6zVCjC4re54AaABAg',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'videoId': 'GIRkQQHzsxI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'jJ-YmFwQ76pxmEgRqvnvFhgYn7Y',
#      'id': 'UgzmxQVvj6zVCjC4re54AaABAg',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'Hope you get value from this framework ✊\n\nTo get this video in written form and signup for more articles like this: https://www.acquisition.com/mozi/money/minute',
#       'textOriginal': 'Hope you get value from this framework ✊\n\nTo get this video in written form and signup for more articles like this: https://www.acquisition.com/mozi/money/minute',
#       'authorDisplayName': '@AlexHormozi',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/7spVLsUWY48DEyACdgIMt8C_4v1QnAkhFtw40pl9c_ieUrQA-Q4gCw70Y2fvhyY707WX25WTyIo=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@AlexHormozi',
#       'authorChannelId': {'value': 'UCUyDOdBWhC1MCxEjC46d-zw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 114,
#       'publishedAt': '2024-06-12T18:11:21Z',
#       'updatedAt': '2024-06-12T18:11:21Z'}},
#     'canReply': True,
#     'totalReplyCount': 15,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'W_w6YEoHEzwjvuKd975hdvoICYA',
#       'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4acG0wSpUO',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': 'This may be the most valuable video I’ve ever watched. \n\nThank you.',
#        'textOriginal': 'This may be the most valuable video I’ve ever watched. \n\nThank you.',
#        'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#        'authorDisplayName': '@bt5588',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_ntrXOigPPxuI78qT-oLy1X53AygsGz1gWYpqe2imY=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@bt5588',
#        'authorChannelId': {'value': 'UCBYyOjQJQWJxvOe15_XLKvw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 12,
#        'publishedAt': '2024-06-12T19:07:38Z',
#        'updatedAt': '2024-06-12T19:07:38Z'}},
#      {'kind': 'youtube#comment',
#       'etag': '_ItWU_LqsgGoKk71D981L6cUSD0',
#       'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4aexbvMD1Z',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': 'If  you manage to see this comment...make the time to stop watching the video, go get a pen, paper, or device and use this video as a tutorial....This is not a casual video where you usually sit and just listen to Alex and his Godlike beard, go make it happen!',
#        'textOriginal': 'If  you manage to see this comment...make the time to stop watching the video, go get a pen, paper, or device and use this video as a tutorial....This is not a casual video where you usually sit and just listen to Alex and his Godlike beard, go make it happen!',
#        'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#        'authorDisplayName': '@triniguy88',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k2UHB5Kgp8WdOeExC-gMcUyjlSXIUfKAXidKyeIiUdpKE=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@triniguy88',
#        'authorChannelId': {'value': 'UCqtx5eYhNmJQvG5YhOUlbmg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 4,
#        'publishedAt': '2024-06-12T19:31:12Z',
#        'updatedAt': '2024-06-12T19:31:12Z'}},
#      {'kind': 'youtube#comment',
#       'etag': '1c2_4ShxVT6IEhnJjJGtbDq58Dc',
#       'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4amux-FaRa',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': "Thanks , finally someone understand me.. I'm a maker.. and this is so true not only about business but everyday life too... Very often people don't understand that I need my time... to plan, to think, to find inspiration and to make... Thank you so much for this ❤",
#        'textOriginal': "Thanks , finally someone understand me.. I'm a maker.. and this is so true not only about business but everyday life too... Very often people don't understand that I need my time... to plan, to think, to find inspiration and to make... Thank you so much for this ❤",
#        'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#        'authorDisplayName': '@daccaippi',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nqZqOFHVGYfnzVGkWi2QxRd0Iov_eujxRXwreIcfE=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@daccaippi',
#        'authorChannelId': {'value': 'UCI_2NCxjxPr3xm7rUHT-pqg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 3,
#        'publishedAt': '2024-06-12T20:40:44Z',
#        'updatedAt': '2024-06-12T20:40:44Z'}},
#      {'kind': 'youtube#comment',
#       'etag': '1rKbjgnvK_uFN7RJ_HgaOetNNbk',
#       'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4arPpkVwl3',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': 'Thanks for your mail. Now I am here and listening at the end of my day to go sleep with you with new thoughts in mind and letting them work over the nigh. Thanks',
#        'textOriginal': 'Thanks for your mail. Now I am here and listening at the end of my day to go sleep with you with new thoughts in mind and letting them work over the nigh. Thanks',
#        'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#        'authorDisplayName': '@KarlaKolumna123',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mHVAbxVNIer4xu73wuUj0tIF4VbO0UYe8qpEmiarmHcGDb95odGAbtojSVFHuMn71Lij8=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@KarlaKolumna123',
#        'authorChannelId': {'value': 'UC0Vltp32XYKBS4Jq0kaRYgQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2024-06-12T21:20:03Z',
#        'updatedAt': '2024-06-12T21:20:03Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'rG0x4X9I85f1TpEOFO3sNvtLGdg',
#       'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4atM65OTTT',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': '@@bt5588are you a maker or a manager😂?',
#        'textOriginal': '@@bt5588are you a maker or a manager😂?',
#        'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#        'authorDisplayName': '@spontaneousmovement',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/n5NmAX6zoeMaZz__n2iNejSm0GhZOqlsyFTxUBH3LTQJqA2879-TcdrYjFlUrkRGt06dEEr76Q=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@spontaneousmovement',
#        'authorChannelId': {'value': 'UC0WrZ9FAvUK1DQZ4DyclxEQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2024-06-12T21:37:01Z',
#        'updatedAt': '2024-06-12T21:37:01Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'K8yIoJiXo-c5aSIC3LDRGK0Wcuo',
#    'id': 'UgzsT1mCsG2QnpKHl-R4AaABAg',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'videoId': 'GIRkQQHzsxI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ZeBps-OlcEjgDxIY7CNf26__a1g',
#      'id': 'UgzsT1mCsG2QnpKHl-R4AaABAg',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'Alex …. bro, are you getting any sleep? \n\nIt’s the 50th upload this week, I’m all for it 😂',
#       'textOriginal': 'Alex …. bro, are you getting any sleep? \n\nIt’s the 50th upload this week, I’m all for it 😂',
#       'authorDisplayName': '@YasirKhanCoaching',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/KlQoDcwa91-jCa2-IOzXRlLP3VQO1YLKlXk_fudiDuzCdmS7QnLNWRrnA8U3kufGbGEx1y66FA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@YasirKhanCoaching',
#       'authorChannelId': {'value': 'UComhtcZ-SQ5rI3uwCk8JXmw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 751,
#       'publishedAt': '2024-06-12T15:36:32Z',
#       'updatedAt': '2024-06-12T15:37:01Z'}},
#     'canReply': True,
#     'totalReplyCount': 23,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'F-ivr0egapWtzl3nYcwXbZT8Ihw',
#       'id': 'UgzsT1mCsG2QnpKHl-R4AaABAg.A4aF5piAggaA4aGC-xAjg-',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': "It's all about productivity.",
#        'textOriginal': "It's all about productivity.",
#        'parentId': 'UgzsT1mCsG2QnpKHl-R4AaABAg',
#        'authorDisplayName': '@aexetan2769',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/8WDY7bjQAkSrfk7FNIaJaVvIq4UM8ST9cm04SjAcKWQmnnGcv6o1ioS_YQtNz7Rtl6XmzxsrgQ=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@aexetan2769',
#        'authorChannelId': {'value': 'UCfHnIrGCEn3Q8H9FKZ9CdJw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 37,
#        'publishedAt': '2024-06-12T15:46:06Z',
#        'updatedAt': '2024-06-12T15:46:06Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'm40ccDs1BWc0BFryJhQy4ft7lHI',
#       'id': 'UgzsT1mCsG2QnpKHl-R4AaABAg.A4aF5piAggaA4aGmB1rAcV',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': 'Too busy racing to $1B',
#        'textOriginal': 'Too busy racing to $1B',
#        'parentId': 'UgzsT1mCsG2QnpKHl-R4AaABAg',
#        'authorDisplayName': '@PerspicaciousMindset',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/D8RGxpaRRo0jNYOV4uFxQwOjAoqM8ZhTyjVsMNOyZ7LyidwqlO5Hm0gu9Vpk2CjQepwSMlGz-8g=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@PerspicaciousMindset',
#        'authorChannelId': {'value': 'UC9IVuuK5HaJAASdUQc6QkNA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 31,
#        'publishedAt': '2024-06-12T15:51:11Z',
#        'updatedAt': '2024-06-12T15:51:11Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'bI8Yo1cfzbYDJ8T6io1sYHjCf_w',
#       'id': 'UgzsT1mCsG2QnpKHl-R4AaABAg.A4aF5piAggaA4aHim9qiOh',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': "Bro he's sleeping 10 hours a day, he said it before",
#        'textOriginal': "Bro he's sleeping 10 hours a day, he said it before",
#        'parentId': 'UgzsT1mCsG2QnpKHl-R4AaABAg',
#        'authorDisplayName': '@RedaMouhib-uv3gf',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nBiBza47xrVI22HQqbI5vVMSjOKCrypMV0wpODLhDTVe4Nl2G7EKpFmagMA2FW4bucAg=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@RedaMouhib-uv3gf',
#        'authorChannelId': {'value': 'UCgidM-EiUJllqON0I3R10BA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 17,
#        'publishedAt': '2024-06-12T15:59:27Z',
#        'updatedAt': '2024-06-12T15:59:27Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'aMKndcoIedsMAydpJuYaLicNlPM',
#       'id': 'UgzsT1mCsG2QnpKHl-R4AaABAg.A4aF5piAggaA4aKZEQWPUg',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': 'A "I posted a gazillion videos on Youtube in a month and this is what happened" video coming soon probably.',
#        'textOriginal': 'A "I posted a gazillion videos on Youtube in a month and this is what happened" video coming soon probably.',
#        'parentId': 'UgzsT1mCsG2QnpKHl-R4AaABAg',
#        'authorDisplayName': '@aigarskluga7877',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lZSgtfj4tmKlAUx1LD8kldoDbh6RnR6vBJ5bUVhT8=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@aigarskluga7877',
#        'authorChannelId': {'value': 'UCZ-HGzfCseSi2nzjhwunX9A'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 54,
#        'publishedAt': '2024-06-12T16:24:14Z',
#        'updatedAt': '2024-06-12T16:24:14Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'aifNNojXBKhiRXxLjI3-hVvxon0',
#       'id': 'UgzsT1mCsG2QnpKHl-R4AaABAg.A4aF5piAggaA4aM1iwKrRK',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': 'Hahahaha',
#        'textOriginal': 'Hahahaha',
#        'parentId': 'UgzsT1mCsG2QnpKHl-R4AaABAg',
#        'authorDisplayName': '@AlexMcDaniels',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/HigK6A4TRQ9YkCIRrVWBzyLM5F12T1B2PABapmmTkLiBxoptydMFTyqZ2YDgIIaDNhwJKaVICQ=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@AlexMcDaniels',
#        'authorChannelId': {'value': 'UCz7iY_iPsCsUK9Mjrh0TlFA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2024-06-12T16:37:08Z',
#        'updatedAt': '2024-06-12T16:37:08Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'dMJ3L_t-J8WT_MGAnIiqDuATpEY',
#    'id': 'UgzMgQbfI2grmjg4bdZ4AaABAg',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'videoId': 'GIRkQQHzsxI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'mUDfrLsjOwcD8-LjcRhlovra8Wg',
#      'id': 'UgzMgQbfI2grmjg4bdZ4AaABAg',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': "the pace of these videos is insane, it's been a video per day for weeks and they're all gold",
#       'textOriginal': "the pace of these videos is insane, it's been a video per day for weeks and they're all gold",
#       'authorDisplayName': '@OrnaSwanson',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/t5FEot-rGEuyEQrPP5vZMazQgIxJpaK8qCkpK_7giFa5s6SX6IYXXeJcHaEt7K2wAlgQs8h1=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@OrnaSwanson',
#       'authorChannelId': {'value': 'UCyADn-aUo0XF8CSMQIoh83A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 115,
#       'publishedAt': '2024-06-14T11:27:36Z',
#       'updatedAt': '2024-06-14T11:27:36Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'y8H85x0tTHpFn2iYtV7KgJHy5Lo',
#       'id': 'UgzMgQbfI2grmjg4bdZ4AaABAg.A4exCLhySgJA4gfeAeC6Nk',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': 'Hello My digits should be displayed on your notifications bar😊😊😊😊',
#        'textOriginal': 'Hello My digits should be displayed on your notifications bar😊😊😊😊',
#        'parentId': 'UgzMgQbfI2grmjg4bdZ4AaABAg',
#        'authorDisplayName': '@alexhormozi16-gmail.......k',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/DCqGmpNpsUNOXuivxhoGx66JzwbDexZR2aJEejSxVuzR6bV9oPAOEw6Tkio3XEQbYLjI1m-qkQ=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@alexhormozi16-gmail.......k',
#        'authorChannelId': {'value': 'UC7s0z428jBk0M4go2UVCszw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2024-06-15T03:32:44Z',
#        'updatedAt': '2024-06-15T03:32:44Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'GiFmWhpJZB3yk1FJnbEN2YdMjis',
#    'id': 'UgxBoqA6OK8dZRkqweJ4AaABAg',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'videoId': 'GIRkQQHzsxI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'LAyoTMOQVzUDRzLrmLXQODtwtf4',
#      'id': 'UgxBoqA6OK8dZRkqweJ4AaABAg',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'Alex\'s productivity summary: Say "NO" often and start working asap while eliminating all possible distractions during your workflow.',
#       'textOriginal': 'Alex\'s productivity summary: Say "NO" often and start working asap while eliminating all possible distractions during your workflow.',
#       'authorDisplayName': '@gjorgjicvetkovski2560',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/OCsrSHxiNI0DeGVz3qNJvFd9puxqbX6HfPzlISV-a3uWTkB9fllzBEwIEgdjF760pLlS920fQQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@gjorgjicvetkovski2560',
#       'authorChannelId': {'value': 'UCwIfI5neF6LC-_o5fstAxpw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 266,
#       'publishedAt': '2024-06-12T15:37:23Z',
#       'updatedAt': '2024-06-12T15:37:23Z'}},
#     'canReply': True,
#     'totalReplyCount': 4,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'LH4G4DZWmHJq9xIk3iv92W2AAFc',
#       'id': 'UgxBoqA6OK8dZRkqweJ4AaABAg.A4aFC3MZsTQA4bQitq9G1-',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': 'No that is not the summary, you’re way too simplistic. You’re wrong.',
#        'textOriginal': 'No that is not the summary, you’re way too simplistic. You’re wrong.',
#        'parentId': 'UgxBoqA6OK8dZRkqweJ4AaABAg',
#        'authorDisplayName': '@SamuelGriffin',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kcM3xPL2DS19FGsi8h-hTJereuvUYFmluiSNDCJjo=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@SamuelGriffin',
#        'authorChannelId': {'value': 'UCQqDrp1gvDdDDFdN958f6gw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 3,
#        'publishedAt': '2024-06-13T02:37:22Z',
#        'updatedAt': '2024-06-13T02:37:22Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'qTF7PyO9qRvZ09-hwgED5elLdLE',
#       'id': 'UgxBoqA6OK8dZRkqweJ4AaABAg.A4aFC3MZsTQA4c82q7g5th',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': '@@SamuelGriffin Alex is wrong?',
#        'textOriginal': '@@SamuelGriffin Alex is wrong?',
#        'parentId': 'UgxBoqA6OK8dZRkqweJ4AaABAg',
#        'authorDisplayName': '@gjorgjicvetkovski2560',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/OCsrSHxiNI0DeGVz3qNJvFd9puxqbX6HfPzlISV-a3uWTkB9fllzBEwIEgdjF760pLlS920fQQ=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@gjorgjicvetkovski2560',
#        'authorChannelId': {'value': 'UCwIfI5neF6LC-_o5fstAxpw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2024-06-13T09:13:26Z',
#        'updatedAt': '2024-06-13T09:13:26Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'V8xBWygdXsKZv4G8MwgmGz0kW5w',
#       'id': 'UgxBoqA6OK8dZRkqweJ4AaABAg.A4aFC3MZsTQA4cZq35fjeb',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': 'These videos themselves could be a distraction haha',
#        'textOriginal': 'These videos themselves could be a distraction haha',
#        'parentId': 'UgxBoqA6OK8dZRkqweJ4AaABAg',
#        'authorDisplayName': '@williamjohnson1395',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mk3kd0o-3siBjeKwUDBHIZOVA-gJyZ_GVXVYPMEFQdwm4=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@williamjohnson1395',
#        'authorChannelId': {'value': 'UC-kzkJwzoCkNVbrmocP5Ngw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2024-06-13T13:16:13Z',
#        'updatedAt': '2024-06-13T13:16:13Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'gGHFYdVbp8v3Hwp22tuvsps-b98',
#       'id': 'UgxBoqA6OK8dZRkqweJ4AaABAg.A4aFC3MZsTQA4ce706JyWn',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': "@@williamjohnson1395 true... that's why I haven't watched the video yet. Maybe in my leisure time over the weekend.",
#        'textOriginal': "@@williamjohnson1395 true... that's why I haven't watched the video yet. Maybe in my leisure time over the weekend.",
#        'parentId': 'UgxBoqA6OK8dZRkqweJ4AaABAg',
#        'authorDisplayName': '@gjorgjicvetkovski2560',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/OCsrSHxiNI0DeGVz3qNJvFd9puxqbX6HfPzlISV-a3uWTkB9fllzBEwIEgdjF760pLlS920fQQ=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@gjorgjicvetkovski2560',
#        'authorChannelId': {'value': 'UCwIfI5neF6LC-_o5fstAxpw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2024-06-13T14:02:22Z',
#        'updatedAt': '2024-06-13T14:02:22Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'fG1vZtLkrdFrBNfC-lF20G3Rbow',
#    'id': 'UgzAHCdRbSSkzproJ1F4AaABAg',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'videoId': 'GIRkQQHzsxI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'pb-tGTqOx40K41EG26GtpayuUjg',
#      'id': 'UgzAHCdRbSSkzproJ1F4AaABAg',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'When I feel like I can’t keep on going I think to my self “ I can’t disappoint Alex”',
#       'textOriginal': 'When I feel like I can’t keep on going I think to my self “ I can’t disappoint Alex”',
#       'authorDisplayName': '@HDTRADING12',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/N51FEfk95VHl_uZ7VMUB18lypZkHMBGhlGPQWP5wcrnHTUen2oDw2V5sVKJQmjTutXMXOqahA5U=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@HDTRADING12',
#       'authorChannelId': {'value': 'UCHGbMn9SoQYf4ulJqfqw7EA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 164,
#       'publishedAt': '2024-06-12T17:16:34Z',
#       'updatedAt': '2024-06-12T17:16:34Z'}},
#     'canReply': True,
#     'totalReplyCount': 9,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': '6z_Q-tvfePQpiidVGtI51xrChcA',
#       'id': 'UgzAHCdRbSSkzproJ1F4AaABAg.A4aQYZBJmBXA4b6B9vXTOl',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': 'that’s so corny bro. He don’t even know you 😂',
#        'textOriginal': 'that’s so corny bro. He don’t even know you 😂',
#        'parentId': 'UgzAHCdRbSSkzproJ1F4AaABAg',
#        'authorDisplayName': '@zeyadmohamed6315',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mUGBlBejAYRycsdd-bbUoCDSCyqDJMWbKHrBrEieA=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@zeyadmohamed6315',
#        'authorChannelId': {'value': 'UCRWNg2DpQFYYaW4N0e2VDFg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 7,
#        'publishedAt': '2024-06-12T23:37:51Z',
#        'updatedAt': '2024-06-12T23:37:51Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'qYXzkVYqDYD81fq3cw5yrnEQhVQ',
#       'id': 'UgzAHCdRbSSkzproJ1F4AaABAg.A4aQYZBJmBXA4bCzgrvQzI',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': '\u200b@@zeyadmohamed6315 hey whatever works 💪 I used to imagine David Goggins screaming at me to get through my manual labor job sometimes 😅',
#        'textOriginal': '\u200b@@zeyadmohamed6315 hey whatever works 💪 I used to imagine David Goggins screaming at me to get through my manual labor job sometimes 😅',
#        'parentId': 'UgzAHCdRbSSkzproJ1F4AaABAg',
#        'authorDisplayName': '@Super_BeastGirl',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/Xhrr-0yBvkye1ffigkN7lwJehlVY61SClWO33_CepFHVlp8bTbygVhT8NSpg_1dP_eKKKI-s=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@Super_BeastGirl',
#        'authorChannelId': {'value': 'UCsmpUrMoXrIiDAxPQ1RPqhA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2024-06-13T00:37:19Z',
#        'updatedAt': '2024-06-13T00:37:19Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'O24flp7pvkjtBcYXSvvCgIl9Wqo',
#       'id': 'UgzAHCdRbSSkzproJ1F4AaABAg.A4aQYZBJmBXA4bcF9OMDis',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': '❤',
#        'textOriginal': '❤',
#        'parentId': 'UgzAHCdRbSSkzproJ1F4AaABAg',
#        'authorDisplayName': '@sarsoura8289',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k7fcWHyzDXUpBBqi2tEOOegKdWlnxljA6rhsrhMntfXm4=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@sarsoura8289',
#        'authorChannelId': {'value': 'UCvDv6kL2EHOoI1ZMSgeyg4g'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2024-06-13T04:26:45Z',
#        'updatedAt': '2024-06-13T04:26:45Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'ptSAPastJC2K7Sn6NGfDrRH7QAI',
#       'id': 'UgzAHCdRbSSkzproJ1F4AaABAg.A4aQYZBJmBXA4bwOJq_Dc6',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': "Don't disappoint yourself Son",
#        'textOriginal': "Don't disappoint yourself Son",
#        'parentId': 'UgzAHCdRbSSkzproJ1F4AaABAg',
#        'authorDisplayName': '@Michael-nf3vm',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/KfY_CNFm8pjGgWc8ZF3GN_I9KDUytjwZ18eoVfuwtjWH5BG8m_zGQCyen_d5CvLrXE2tieLJ=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@Michael-nf3vm',
#        'authorChannelId': {'value': 'UClVKwv3djmiZTDWNlffEXgg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 5,
#        'publishedAt': '2024-06-13T07:22:46Z',
#        'updatedAt': '2024-06-13T07:22:46Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'Ev9xKl0_uFBkhqwlmCQktghkkxU',
#       'id': 'UgzAHCdRbSSkzproJ1F4AaABAg.A4aQYZBJmBXA4c-WEtMKI7',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': '@@zeyadmohamed6315Fr, could be his mom, his dad, his future family, his kids.',
#        'textOriginal': '@@zeyadmohamed6315Fr, could be his mom, his dad, his future family, his kids.',
#        'parentId': 'UgzAHCdRbSSkzproJ1F4AaABAg',
#        'authorDisplayName': '@DayTripTookItTo10',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/CnbNwTj38nz1lMZJKnqSzo36AWSs3CZPmWL236FsivJl_Nt2FKF62MlvZwe_9luYUdna2JcE=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@DayTripTookItTo10',
#        'authorChannelId': {'value': 'UCh6kS-lowPa8-vRSmKHrafA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2024-06-13T07:58:48Z',
#        'updatedAt': '2024-06-13T07:58:48Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'fbAL1Uf47wKXWlmqDjGDJWLx_8g',
#    'id': 'UgyRg4V4ltvRkysqjQp4AaABAg',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'videoId': 'GIRkQQHzsxI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'OV73dVylyg8O5iYuWKoH3EllhwI',
#      'id': 'UgyRg4V4ltvRkysqjQp4AaABAg',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'The level of value this man provides is unmatched.',
#       'textOriginal': 'The level of value this man provides is unmatched.',
#       'authorDisplayName': '@ceowalid',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/TJAb-O8ASCDfvnIftWSkNNeHSRR6XY3A6NXYYTgK4A02lC6rrz9zFTjzPVVfFRTMJMbRocKXFA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@ceowalid',
#       'authorChannelId': {'value': 'UCrjqFjPA5szWtP5LUNbmGQw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 162,
#       'publishedAt': '2024-06-12T15:39:10Z',
#       'updatedAt': '2024-06-12T15:39:10Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'iIyx1NzE3NjxRWetUGxcnvYk7vA',
#    'id': 'UgzpPP0GvNzEHg4fhdB4AaABAg',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'videoId': 'GIRkQQHzsxI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'pPveXZCr8ohmA7kgp5yGP5FYU3Y',
#      'id': 'UgzpPP0GvNzEHg4fhdB4AaABAg',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'These simple videos with the white board and zero distracting noises or jump cuts are fantastic! I’m here to learn, not crank my dopamine!',
#       'textOriginal': 'These simple videos with the white board and zero distracting noises or jump cuts are fantastic! I’m here to learn, not crank my dopamine!',
#       'authorDisplayName': '@Johansebastion',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mhsmnYE8s43yKvrOUEuO15ubUhsinTg2sCvnzOqI9_bv10vBFKsBHnJGDP5ESWQFEWmg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Johansebastion',
#       'authorChannelId': {'value': 'UCu7YuhY5t00FRy8xAuGS61g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 9,
#       'publishedAt': '2024-06-13T07:44:30Z',
#       'updatedAt': '2024-06-13T07:44:30Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'mNhqa8-DsvJJgcCpuxV6H0fubHQ',
#    'id': 'Ugwz7aRF9tgtSE6m0Al4AaABAg',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'videoId': 'GIRkQQHzsxI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'SASq8JZ_cL7Y-IQXEYM6bR-HyLw',
#      'id': 'Ugwz7aRF9tgtSE6m0Al4AaABAg',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': "Takeaways:\n- Schedule meeting days\n- Jealously guard your time\n- Disinvite people from unproductive meetings and don't be afraid to cancel meetings that don't need to happen",
#       'textOriginal': "Takeaways:\n- Schedule meeting days\n- Jealously guard your time\n- Disinvite people from unproductive meetings and don't be afraid to cancel meetings that don't need to happen",
#       'authorDisplayName': '@garitboothe3413',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nGKlEnmGvQjg1zGNsnp5GCqD4EXC64KH8TjUA3Aw90sUg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@garitboothe3413',
#       'authorChannelId': {'value': 'UChsmOC9-UQyz6sEMEII_oPw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 22,
#       'publishedAt': '2024-06-12T22:19:09Z',
#       'updatedAt': '2024-06-12T22:19:09Z'}},
#     'canReply': True,
#     'totalReplyCount': 2,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'J6lVLVJgx3WwHbqyDv6pS7Q4B80',
#       'id': 'Ugwz7aRF9tgtSE6m0Al4AaABAg.A4ayAh9ETHGA4hDkEw6UHv',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': 'and this is supposed to help me get $100 million?',
#        'textOriginal': 'and this is supposed to help me get $100 million?',
#        'parentId': 'Ugwz7aRF9tgtSE6m0Al4AaABAg',
#        'authorDisplayName': '@PandaBoy-zi2hg',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/TYhlWho8wS4rOjs0zwgtCRu58jb6UJmLRZdB6RCuHrefiftaPgeTQua5DjFGDUIh_bzt_aZJTw=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@PandaBoy-zi2hg',
#        'authorChannelId': {'value': 'UCfvJ8ZAlJZNnXpI15NHwGAQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2024-06-15T08:39:23Z',
#        'updatedAt': '2024-06-15T08:39:23Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'g7BHw8zBhHK0lgX8KMU-0f7UHkE',
#       'id': 'Ugwz7aRF9tgtSE6m0Al4AaABAg.A4ayAh9ETHGA4i1k2golQi',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': "\u200b\u200b@@PandaBoy-zi2hgYes and to add to that if you only meet on Mondays and a potential client only meets on Tuesdays then they're not worth your time. Good luck making 100 million😂 caveat is I'm not a hater promise Alex has a lot of useful information but I suppose an exception to the rule is in order😊",
#        'textOriginal': "\u200b\u200b@@PandaBoy-zi2hgYes and to add to that if you only meet on Mondays and a potential client only meets on Tuesdays then they're not worth your time. Good luck making 100 million😂 caveat is I'm not a hater promise Alex has a lot of useful information but I suppose an exception to the rule is in order😊",
#        'parentId': 'Ugwz7aRF9tgtSE6m0Al4AaABAg',
#        'authorDisplayName': '@CinemaRaps',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_luR9A990DSEc4ktK6z93ar3XidI6w3rkdv82_BuX3MVhk=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@CinemaRaps',
#        'authorChannelId': {'value': 'UCgvm-noThpcnkfqjeWhmVDQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2024-06-15T16:13:45Z',
#        'updatedAt': '2024-06-15T16:14:17Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': '2F6k6_APGjYCfGRB3HOTDRcqHAc',
#    'id': 'UgwiH7FgVS8sPO1am4p4AaABAg',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'videoId': 'GIRkQQHzsxI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'VVCrOJTXZ_xVX2MjRAKckFMc-08',
#      'id': 'UgwiH7FgVS8sPO1am4p4AaABAg',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': "For those that don't get it yet, Alex decided to do summer school. It's going to be a few weeks of value nonstop, for free. Sharpen your pencils.",
#       'textOriginal': "For those that don't get it yet, Alex decided to do summer school. It's going to be a few weeks of value nonstop, for free. Sharpen your pencils.",
#       'authorDisplayName': '@Aedonius',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/WgtES-siWq5NZN-d2icYo7OXrw8PX8AMh1okiptl60fzBA9l1P2kn5SV6oTQGG2zW6DqIdSm=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Aedonius',
#       'authorChannelId': {'value': 'UCW_n3FiAu1KXTmB4FvmVuTw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 56,
#       'publishedAt': '2024-06-12T16:48:39Z',
#       'updatedAt': '2024-06-12T16:48:39Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'ak3uY7dwEWD2uhvJTzIV-BzNT-M',
#    'id': 'UgxbqBqEkAX6iiZMO4V4AaABAg',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'videoId': 'GIRkQQHzsxI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Cgwk11naQq_4dl-BEgOX85B0ntk',
#      'id': 'UgxbqBqEkAX6iiZMO4V4AaABAg',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'How the hell does he have the time to do soo much, evaluate and analyse it, break it down so clearly and deliver sooo much value every effin time !!?? 🤯 G.O.A.T',
#       'textOriginal': 'How the hell does he have the time to do soo much, evaluate and analyse it, break it down so clearly and deliver sooo much value every effin time !!?? 🤯 G.O.A.T',
#       'authorDisplayName': '@HarshalAgarwal1339',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nwdc8pVbx_IgdANAQVe7UgosYm0EjwG6eHjqk4J0iLNOU=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@HarshalAgarwal1339',
#       'authorChannelId': {'value': 'UCqH_yCutTFPThYwxZfEhrNA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 103,
#       'publishedAt': '2024-06-12T16:02:59Z',
#       'updatedAt': '2024-06-12T16:02:59Z'}},
#     'canReply': True,
#     'totalReplyCount': 6,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'dX22frhPt4GcZh2fHOBv9Lj1Ugg',
#       'id': 'UgxbqBqEkAX6iiZMO4V4AaABAg.A4aI7a2s1qFA4aOapN2iA9',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': 'Well he just explained his schedule.. plus from writing soooo much, he says he writes for hours daily',
#        'textOriginal': 'Well he just explained his schedule.. plus from writing soooo much, he says he writes for hours daily',
#        'parentId': 'UgxbqBqEkAX6iiZMO4V4AaABAg',
#        'authorDisplayName': '@kabewar77',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_ls05GlP4-DsvOy8revtK45pPgUL1kFgh4LGuYfvV-O3nyWoRp3CJzDqI8Ctf7Dywg_LQ=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@kabewar77',
#        'authorChannelId': {'value': 'UC6ycqkXYR7i7ibOZn_31YtA'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 8,
#        'publishedAt': '2024-06-12T16:59:32Z',
#        'updatedAt': '2024-06-12T16:59:32Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'mLzS6Lo_aMvTtP9kZz-LSjy9-UA',
#       'id': 'UgxbqBqEkAX6iiZMO4V4AaABAg.A4aI7a2s1qFA4aSoKeGgra',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': 'experience baby',
#        'textOriginal': 'experience baby',
#        'parentId': 'UgxbqBqEkAX6iiZMO4V4AaABAg',
#        'authorDisplayName': '@somratdutta',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/_DQlkniRtWUJ9ybRDiEZiqywifFnrpUn5U2oOHrVqtGqUxHCH5ZtmALfVfVnbNjusEsmm-BG=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@somratdutta',
#        'authorChannelId': {'value': 'UCPFtxlWW4dtXK9_r2TZqJ_Q'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 2,
#        'publishedAt': '2024-06-12T17:36:20Z',
#        'updatedAt': '2024-06-12T17:36:20Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'NJBb3MSlCZFpGe2OzH8b_JELrNk',
#       'id': 'UgxbqBqEkAX6iiZMO4V4AaABAg.A4aI7a2s1qFA4aVKoDXQ0W',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': "He has a team. You don't really think he does this all by himself, do you? He is all about optimization. Outsourcing to other folks is how it works.",
#        'textOriginal': "He has a team. You don't really think he does this all by himself, do you? He is all about optimization. Outsourcing to other folks is how it works.",
#        'parentId': 'UgxbqBqEkAX6iiZMO4V4AaABAg',
#        'authorDisplayName': '@apmartini70',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kAzhFZrZyRBEqcJt1_WMukJA7LwNWtZrERfOrp4Oh5z-I=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@apmartini70',
#        'authorChannelId': {'value': 'UC2CRn1659d5B3xXPhzyGJsg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 6,
#        'publishedAt': '2024-06-12T17:58:23Z',
#        'updatedAt': '2024-06-12T17:58:23Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'hStOB9AZhOt4pHwklQMFzUAdoA8',
#       'id': 'UgxbqBqEkAX6iiZMO4V4AaABAg.A4aI7a2s1qFA4akrd2Z6Ch',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': "In his other videos he tries to describe the difference between THINKING you're working and ACTUALLY working. That's what most videos like this are all about...shine a light in THIS corner of the difference, shine a light in THAT corner of the difference...one video at a time.",
#        'textOriginal': "In his other videos he tries to describe the difference between THINKING you're working and ACTUALLY working. That's what most videos like this are all about...shine a light in THIS corner of the difference, shine a light in THAT corner of the difference...one video at a time.",
#        'parentId': 'UgxbqBqEkAX6iiZMO4V4AaABAg',
#        'authorDisplayName': '@tonyrichmond9428',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lz-xjat4z2F3jXXGJsaQ27vxtI-QGXau1FGv6gmw=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@tonyrichmond9428',
#        'authorChannelId': {'value': 'UC_WipJNt2hSkWEH7v8_bZXQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 5,
#        'publishedAt': '2024-06-12T20:22:49Z',
#        'updatedAt': '2024-06-12T20:22:49Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'ImlDUEuR68RYxoO-qQhR5pmSoSk',
#       'id': 'UgxbqBqEkAX6iiZMO4V4AaABAg.A4aI7a2s1qFA4bf7mKIIrn',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': 'Great',
#        'textOriginal': 'Great',
#        'parentId': 'UgxbqBqEkAX6iiZMO4V4AaABAg',
#        'authorDisplayName': '@topogigio9421',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nVV36tbSHoYj311rs1KqkifxTMy5DOOw_z6tG8lq8=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@topogigio9421',
#        'authorChannelId': {'value': 'UCxrSJMCSF-M2_wKQCi6L1ig'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2024-06-13T04:51:58Z',
#        'updatedAt': '2024-06-13T04:51:58Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 's4H2UN59NvNgYzmT3zxAO2YF-DA',
#    'id': 'UgwQUH9Ko4kOSo9AEvF4AaABAg',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'videoId': 'GIRkQQHzsxI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'U_m92wh2TVcLBActTpd8OOklM_0',
#      'id': 'UgwQUH9Ko4kOSo9AEvF4AaABAg',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'Start early with diversified investments in stocks, bonds, and real estate. Maximize contributions to tax-advantaged accounts like 401(k)s and IRAs. Regularly review and adjust your strategy to ensure security.',
#       'textOriginal': 'Start early with diversified investments in stocks, bonds, and real estate. Maximize contributions to tax-advantaged accounts like 401(k)s and IRAs. Regularly review and adjust your strategy to ensure security.',
#       'authorDisplayName': '@icucmerc',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_m0Sa5Ay2bHi-yK2J6fxT2KCVM0UJjCemD_OhpICM6NFA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@icucmerc',
#       'authorChannelId': {'value': 'UCmVF0VfB4pMqTAXxOVfFUNQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 25,
#       'publishedAt': '2024-06-12T23:03:06Z',
#       'updatedAt': '2024-06-12T23:03:06Z'}},
#     'canReply': True,
#     'totalReplyCount': 15,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'KMgUNdrMeBTnzYEhp6BgNveuYpE',
#       'id': 'UgwQUH9Ko4kOSo9AEvF4AaABAg.A4b2CatexLEA4b6J5N6U4a',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': 'Very possible! especially at this moment. Profits can be made in many different ways, but such intricate transactions should only be handled by seasoned market professionals.',
#        'textOriginal': 'Very possible! especially at this moment. Profits can be made in many different ways, but such intricate transactions should only be handled by seasoned market professionals.',
#        'parentId': 'UgwQUH9Ko4kOSo9AEvF4AaABAg',
#        'authorDisplayName': '@vanillatgif',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mW_rdrqhzqKtiyaOmNGu9_My2wkyYAw1IMNHmq2rT3FQ=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@vanillatgif',
#        'authorChannelId': {'value': 'UCWmByUZNjy4O6nsuiT9iNNQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2024-06-12T23:38:56Z',
#        'updatedAt': '2024-06-12T23:38:56Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'j-YrPcTuLRpA2ehINa5ou9CKSso',
#       'id': 'UgwQUH9Ko4kOSo9AEvF4AaABAg.A4b2CatexLEA4b6d_bAeeW',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': "Some persons think inves'tin is all about buying stocks; I think going into the stock market without a good experience is a big risk, that's why I'm lucky to have seen someone like mr Brian C Nelson.",
#        'textOriginal': "Some persons think inves'tin is all about buying stocks; I think going into the stock market without a good experience is a big risk, that's why I'm lucky to have seen someone like mr Brian C Nelson.",
#        'parentId': 'UgwQUH9Ko4kOSo9AEvF4AaABAg',
#        'authorDisplayName': '@Faijan-zx5ov',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lRTWRoJ5Mm1J6dwSFwLZYO2tYqK3zKpN4VbdDGguTxhPP-sB_V7uVUqTAw-NzD5GCobQ=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@Faijan-zx5ov',
#        'authorChannelId': {'value': 'UC3hvv6usxlXWAwAjoRosgUw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2024-06-12T23:41:52Z',
#        'updatedAt': '2024-06-12T23:41:52Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'eiQ1M_KTghDRW6ng4vc5hCmGJnA',
#       'id': 'UgwQUH9Ko4kOSo9AEvF4AaABAg.A4b2CatexLEA4b7Sw1ykFE',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': 'Finding yourself a good broker is as same as finding a good wife, which you go less stress, you get just enough with so much little effort at things',
#        'textOriginal': 'Finding yourself a good broker is as same as finding a good wife, which you go less stress, you get just enough with so much little effort at things',
#        'parentId': 'UgwQUH9Ko4kOSo9AEvF4AaABAg',
#        'authorDisplayName': '@amytuttle1621',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_ld05STQ41AxCm520P8FMEmGBySxd7nUnf5rfrxym8=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@amytuttle1621',
#        'authorChannelId': {'value': 'UCdKNsfD1aeCVk0NjZ1znfQg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2024-06-12T23:49:01Z',
#        'updatedAt': '2024-06-12T23:49:01Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'i8wBaS89j1oGshFYa-qb1c_mbT8',
#       'id': 'UgwQUH9Ko4kOSo9AEvF4AaABAg.A4b2CatexLEA4b8ES2yS9v',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': 'Brian demonstrates an excellent understanding of market trends, making well informed decisions that leads to consistent profit',
#        'textOriginal': 'Brian demonstrates an excellent understanding of market trends, making well informed decisions that leads to consistent profit',
#        'parentId': 'UgwQUH9Ko4kOSo9AEvF4AaABAg',
#        'authorDisplayName': '@grizbaseball',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k7rre8HKx7_t2Emxa9KxE8BbNqH4DFU0zz5qY4kFAy4g=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@grizbaseball',
#        'authorChannelId': {'value': 'UCHicBrFsO8U39INRY_5MpNQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2024-06-12T23:55:47Z',
#        'updatedAt': '2024-06-12T23:55:47Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'X1gFk9HvBFlDDJiApcx15Snh-tI',
#       'id': 'UgwQUH9Ko4kOSo9AEvF4AaABAg.A4b2CatexLEA4b8j3tPSqP',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': "I'm surprised that you just mentioned and recommend Mr Brian Nelson. I met him at a conference in 2018 and we have been working together ever since.",
#        'textOriginal': "I'm surprised that you just mentioned and recommend Mr Brian Nelson. I met him at a conference in 2018 and we have been working together ever since.",
#        'parentId': 'UgwQUH9Ko4kOSo9AEvF4AaABAg',
#        'authorDisplayName': '@whitefearlytales',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nxOF3VG8qGUCCK2o-Mkv2FFPasz3fU9xNtxadIOiQ2qw=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@whitefearlytales',
# ...
#       'authorDisplayName': '@grasshopperweb',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/4vA0tRxyUn_LQ-qgP7q4yiIxKFD7Bwxa9vH93UUFeZDIo3aGQj4zkZZTa4VnKDs997e8lhIHCA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@grasshopperweb',
#       'authorChannelId': {'value': 'UCGemhQI79J3n4es7be1PBTw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 34,
#       'publishedAt': '2024-06-12T17:54:04Z',
#       'updatedAt': '2024-06-12T18:21:58Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'NfruX6FoCHbal_sl5cQT1I4nA6c',
#    'id': 'UgyQgUKlgP8Wf0WuheB4AaABAg',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'videoId': 'GIRkQQHzsxI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'M9FuX8nJ-rw93m-FfDmSN0eqfg4',
#      'id': 'UgyQgUKlgP8Wf0WuheB4AaABAg',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': "this video is underrated af. as someone who's a CEO and also full time artist/ music producer, nothing makes me happier than waking up and seeing no meetings on my calendar ha",
#       'textOriginal': "this video is underrated af. as someone who's a CEO and also full time artist/ music producer, nothing makes me happier than waking up and seeing no meetings on my calendar ha",
#       'authorDisplayName': '@seanferres',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/YaeXmDsH2pXJDVVpYnvF40Rw4BxBLt36i0IsVWhhZ_DK-Maa4R08XFzdexrz2XNwZQ6YoCWG_Q=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@seanferres',
#       'authorChannelId': {'value': 'UCZKNz8Az8AjgtYF-WFGkZkw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 12,
#       'publishedAt': '2024-06-13T15:10:09Z',
#       'updatedAt': '2024-06-13T15:10:09Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'jcMFf54-uX_Mh43v5EynnMYIX4M',
#       'id': 'UgyQgUKlgP8Wf0WuheB4AaABAg.A4clsW_NaX4A4fe1sgQWYe',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': 'It’s only been out for a day - I don’t think it’s underrated by anyone yet',
#        'textOriginal': 'It’s only been out for a day - I don’t think it’s underrated by anyone yet',
#        'parentId': 'UgyQgUKlgP8Wf0WuheB4AaABAg',
#        'authorDisplayName': '@stevebliss7042',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kpH-z5dP5E9EtU_vf5SgbZ5tM6Ko_v8NCr0lcbLp5GJ91g=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@stevebliss7042',
#        'authorChannelId': {'value': 'UCpW7TSz_H2mD38Qf8TcKCBg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2024-06-14T17:59:23Z',
#        'updatedAt': '2024-06-14T17:59:23Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'BVav_z61F01SJBhpONeK0wEr8yQ',
#    'id': 'Ugz_yFDtlgzizdmtqRV4AaABAg',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'videoId': 'GIRkQQHzsxI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'gH-mZAsFcKmUaMbSH_JnfXjEjuQ',
#      'id': 'Ugz_yFDtlgzizdmtqRV4AaABAg',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': "This is just gold. As a head teacher I fought for this without knowing these terms. My goal was to put all the meeting on one day and let the team do their job uninterrupted for the rest of the week. Unfortunately, our VP thought that the moment she stops looking over someone's shoulder they stop working.",
#       'textOriginal': "This is just gold. As a head teacher I fought for this without knowing these terms. My goal was to put all the meeting on one day and let the team do their job uninterrupted for the rest of the week. Unfortunately, our VP thought that the moment she stops looking over someone's shoulder they stop working.",
#       'authorDisplayName': '@warchefseed',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_m7tfLP-Wl0-6w78JScm7fSg19b2AmhffK2TzfkPWA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@warchefseed',
#       'authorChannelId': {'value': 'UCf86S20viS7QqdBzbBGWBig'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 5,
#       'publishedAt': '2024-06-13T06:19:03Z',
#       'updatedAt': '2024-06-13T06:19:03Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'qXlwlDdBJ-Kymj8tByaBI8nfvX4',
#    'id': 'UgzYhQ8PWQVLYMXxeb54AaABAg',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'videoId': 'GIRkQQHzsxI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'a4tqHR_5DwD13c8oxGvoOCEnfBk',
#      'id': 'UgzYhQ8PWQVLYMXxeb54AaABAg',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'ALEX HOW AM I SUPPOSED TO KEEP UP WITH ALL THIS VALUE??\n\nMY LIFE CAN ONLY GET SO MUCH BETTER AHHHHHHHH',
#       'textOriginal': 'ALEX HOW AM I SUPPOSED TO KEEP UP WITH ALL THIS VALUE??\n\nMY LIFE CAN ONLY GET SO MUCH BETTER AHHHHHHHH',
#       'authorDisplayName': '@Parqo',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/52Q1-sw4ptEj4AR8-XXThAWYSerJygI8n6E29sSqYrtO2k74yU6mpRpq7JdUZRInm1HLGv2H4w=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Parqo',
#       'authorChannelId': {'value': 'UCMuFQv8_YrNykin5GF1NXng'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 19,
#       'publishedAt': '2024-06-12T17:11:27Z',
#       'updatedAt': '2024-06-12T17:11:27Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'NHY4p9O3DN4kqaHI7m-2uKr2n7A',
#    'id': 'UgyQc_8HFq3JULvOUFd4AaABAg',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'videoId': 'GIRkQQHzsxI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '90syr9mn5eiVX1M_zESQovOZT6A',
#      'id': 'UgyQc_8HFq3JULvOUFd4AaABAg',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'You can tell Alex is a big Cal Newport fan',
#       'textOriginal': 'You can tell Alex is a big Cal Newport fan',
#       'authorDisplayName': '@raymondmuzembe1636',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lR_bZ5wjg-rZLG8oo-FtqrAQqddkr2aqGGznNOqMmk4A=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@raymondmuzembe1636',
#       'authorChannelId': {'value': 'UCHomMxTOPke6frrLz10AVlA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 33,
#       'publishedAt': '2024-06-12T15:58:53Z',
#       'updatedAt': '2024-06-12T15:58:53Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'hO1JIv49e76YaTcqaWeZ8DksSxY',
#       'id': 'UgyQc_8HFq3JULvOUFd4AaABAg.A4aHe_klz-hA4aXr694q8u',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': 'Deep work',
#        'textOriginal': 'Deep work',
#        'parentId': 'UgyQc_8HFq3JULvOUFd4AaABAg',
#        'authorDisplayName': '@DrHelenEmore',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_l_iS3zixCzeAePaBSnPYHClRmHsCIJGisH6u4gmg5fals=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@DrHelenEmore',
#        'authorChannelId': {'value': 'UCCK362OSGDX-g1LVjf5_3Cw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 2,
#        'publishedAt': '2024-06-12T18:20:24Z',
#        'updatedAt': '2024-06-12T18:20:24Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'ZNRtw6_WFuFUm9DXZ4Wby5c8ZRE',
#    'id': 'Ugx8O76_2J7oA2eUUSB4AaABAg',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'videoId': 'GIRkQQHzsxI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'm4Vixvjkhmo7WkTEdMdLyCSGBdA',
#      'id': 'Ugx8O76_2J7oA2eUUSB4AaABAg',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'This is just Alex complaining about being interrupted and its awesome!😄',
#       'textOriginal': 'This is just Alex complaining about being interrupted and its awesome!😄',
#       'authorDisplayName': '@MrCaptainSquibbles',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nCFpLPeJ07jTj56hk-pd91SdSPoHk7wnmiPfbT_AK8ag=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@MrCaptainSquibbles',
#       'authorChannelId': {'value': 'UChq-2Z7ZrEvu0YBIG_RzpAA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 11,
#       'publishedAt': '2024-06-12T20:09:53Z',
#       'updatedAt': '2024-06-12T20:09:53Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'otoa4FdCripOSfjxaDVJLZvPeFk',
#    'id': 'UgztpDXXTO4r69I6RH54AaABAg',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'videoId': 'GIRkQQHzsxI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'jOjP6i9FHJwN6MZnynVYYaJ-0yU',
#      'id': 'UgztpDXXTO4r69I6RH54AaABAg',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'Realizing my manager side kills my maker side fml Biggest thing I learned was to make sure to have my day cleared when creating a song. I used to pause creating a new song to do lessons and meetings and then try to go back to creating a song. That would never go well.',
#       'textOriginal': 'Realizing my manager side kills my maker side fml Biggest thing I learned was to make sure to have my day cleared when creating a song. I used to pause creating a new song to do lessons and meetings and then try to go back to creating a song. That would never go well.',
#       'authorDisplayName': '@Dicodec',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_l8Zz-E-XwLHZ8s650hwvMvDbc7hqIIit_EH9WZmIMVez0=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Dicodec',
#       'authorChannelId': {'value': 'UCcl6kGS8T1Sy9cAkQnffdMg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 20,
#       'publishedAt': '2024-06-12T17:37:14Z',
#       'updatedAt': '2024-06-12T18:11:48Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'YfX_Ws0vbgnShaVlBSLDIZQBg5o',
#       'id': 'UgztpDXXTO4r69I6RH54AaABAg.A4aSurV4PDwA4bxnXUgGsd',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': 'I think it’s incredible that a songwriter is getting this much value from a business centric video. Just proves that Alex is the goat.',
#        'textOriginal': 'I think it’s incredible that a songwriter is getting this much value from a business centric video. Just proves that Alex is the goat.',
#        'parentId': 'UgztpDXXTO4r69I6RH54AaABAg',
#        'authorDisplayName': '@ethannguyen5030',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k9ZOZhwGqOsWc3uy6QoCgGTcmURkBeAP80P0UQeQHztQ=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@ethannguyen5030',
#        'authorChannelId': {'value': 'UCA5gbsvFhQYT53dK8QQEuvQ'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2024-06-13T07:35:05Z',
#        'updatedAt': '2024-06-13T07:35:05Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'w8ZsDCZXUSfHHExYWZcDuenZV10',
#    'id': 'UgxkDmBRBWze9vfs0sZ4AaABAg',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'videoId': 'GIRkQQHzsxI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'zJB99eGCHGlleMyFv3PXwaSpxNs',
#      'id': 'UgxkDmBRBWze9vfs0sZ4AaABAg',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'Ok, you just climbed into my head, and made sense of what I have been trying to organize forever.  I am a small business owner, and I wear a lot of hats as a homeschooling mom, and business owner.   You ROCK!  This was so incredibly helpful.  Maker/Manager is brilliant!',
#       'textOriginal': 'Ok, you just climbed into my head, and made sense of what I have been trying to organize forever.  I am a small business owner, and I wear a lot of hats as a homeschooling mom, and business owner.   You ROCK!  This was so incredibly helpful.  Maker/Manager is brilliant!',
#       'authorDisplayName': '@diannad8905',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kPKtVFlLyhyTEJeNNoB1Qnu2sSR7M3r7QsgezwPSM=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@diannad8905',
#       'authorChannelId': {'value': 'UCqhnIK9u0eXNJeyoMUxHOhQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 2,
#       'publishedAt': '2024-06-14T16:14:10Z',
#       'updatedAt': '2024-06-14T16:14:10Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'RPrzGUBE2H3hsot-zVp8qKw2zP4',
#       'id': 'UgxkDmBRBWze9vfs0sZ4AaABAg.A4fT-AQFnddA4gfFfYRFx1',
#       'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#        'videoId': 'GIRkQQHzsxI',
#        'textDisplay': 'Hello My digits should be displayed on your notifications bar😊🎉🎉',
#        'textOriginal': 'Hello My digits should be displayed on your notifications bar😊🎉🎉',
#        'parentId': 'UgxkDmBRBWze9vfs0sZ4AaABAg',
#        'authorDisplayName': '@alexhormozi16-gmail.......k',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/DCqGmpNpsUNOXuivxhoGx66JzwbDexZR2aJEejSxVuzR6bV9oPAOEw6Tkio3XEQbYLjI1m-qkQ=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@alexhormozi16-gmail.......k',
#        'authorChannelId': {'value': 'UC7s0z428jBk0M4go2UVCszw'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2024-06-15T03:29:15Z',
#        'updatedAt': '2024-06-15T03:29:15Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'N4q0ouRBM7k5cTpuF1Ug-Gfaqms',
#    'id': 'UgzXMsdw8b2oUWzAUG14AaABAg',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'videoId': 'GIRkQQHzsxI',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'WBuQITlRyn_n0hdglzu6VsfJfJI',
#      'id': 'UgzXMsdw8b2oUWzAUG14AaABAg',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': "There  isn't a single business influencer that has ever offered more value than Alex. Every video gives me paradigm shifts that change the way i approach my time and direction.",
#       'textOriginal': "There  isn't a single business influencer that has ever offered more value than Alex. Every video gives me paradigm shifts that change the way i approach my time and direction.",
#       'authorDisplayName': '@NaphtaliRosenberg',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kCGpVhSlHvbxbRKVznIMFeZ9GUNSP1fUQ2qM3i6E2vPW8=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@NaphtaliRosenberg',
#       'authorChannelId': {'value': 'UCj_xMYkGKTvUl47l1XFxzcA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-06-13T06:14:23Z',
#       'updatedAt': '2024-06-13T06:14:23Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %% [markdown]
# ### **get_all_comments**
#
# ##### `get_all_comments(video_id: str, **kwargs)`
#
# The `get_all_comments` method retrieves all comments from a specified YouTube video.
#
# **Parameters:**
# - `video_id` (str): The ID of the YouTube video.
# - `**kwargs`: Additional parameters.
#
# **Returns:**
# - `list`: A list of dictionaries, each representing a comment.
#
# ##### **Example**

# %%
youtube.get_all_comments('GIRkQQHzsxI')
# Out:
# [{'kind': 'youtube#commentThread',
#   'etag': '863VnmLGSdJCz8tYyACkDufFQno',
#   'id': 'UgzmxQVvj6zVCjC4re54AaABAg',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'videoId': 'GIRkQQHzsxI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'jJ-YmFwQ76pxmEgRqvnvFhgYn7Y',
#     'id': 'UgzmxQVvj6zVCjC4re54AaABAg',
#     'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#      'videoId': 'GIRkQQHzsxI',
#      'textDisplay': 'Hope you get value from this framework ✊\n\nTo get this video in written form and signup for more articles like this: https://www.acquisition.com/mozi/money/minute',
#      'textOriginal': 'Hope you get value from this framework ✊\n\nTo get this video in written form and signup for more articles like this: https://www.acquisition.com/mozi/money/minute',
#      'authorDisplayName': '@AlexHormozi',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/7spVLsUWY48DEyACdgIMt8C_4v1QnAkhFtw40pl9c_ieUrQA-Q4gCw70Y2fvhyY707WX25WTyIo=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/@AlexHormozi',
#      'authorChannelId': {'value': 'UCUyDOdBWhC1MCxEjC46d-zw'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 114,
#      'publishedAt': '2024-06-12T18:11:21Z',
#      'updatedAt': '2024-06-12T18:11:21Z'}},
#    'canReply': True,
#    'totalReplyCount': 15,
#    'isPublic': True},
#   'replies': {'comments': [{'kind': 'youtube#comment',
#      'etag': 'W_w6YEoHEzwjvuKd975hdvoICYA',
#      'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4acG0wSpUO',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'This may be the most valuable video I’ve ever watched. \n\nThank you.',
#       'textOriginal': 'This may be the most valuable video I’ve ever watched. \n\nThank you.',
#       'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#       'authorDisplayName': '@bt5588',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_ntrXOigPPxuI78qT-oLy1X53AygsGz1gWYpqe2imY=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@bt5588',
#       'authorChannelId': {'value': 'UCBYyOjQJQWJxvOe15_XLKvw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 12,
#       'publishedAt': '2024-06-12T19:07:38Z',
#       'updatedAt': '2024-06-12T19:07:38Z'}},
#     {'kind': 'youtube#comment',
#      'etag': '_ItWU_LqsgGoKk71D981L6cUSD0',
#      'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4aexbvMD1Z',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'If  you manage to see this comment...make the time to stop watching the video, go get a pen, paper, or device and use this video as a tutorial....This is not a casual video where you usually sit and just listen to Alex and his Godlike beard, go make it happen!',
#       'textOriginal': 'If  you manage to see this comment...make the time to stop watching the video, go get a pen, paper, or device and use this video as a tutorial....This is not a casual video where you usually sit and just listen to Alex and his Godlike beard, go make it happen!',
#       'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#       'authorDisplayName': '@triniguy88',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k2UHB5Kgp8WdOeExC-gMcUyjlSXIUfKAXidKyeIiUdpKE=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@triniguy88',
#       'authorChannelId': {'value': 'UCqtx5eYhNmJQvG5YhOUlbmg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 4,
#       'publishedAt': '2024-06-12T19:31:12Z',
#       'updatedAt': '2024-06-12T19:31:12Z'}},
#     {'kind': 'youtube#comment',
#      'etag': '1c2_4ShxVT6IEhnJjJGtbDq58Dc',
#      'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4amux-FaRa',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': "Thanks , finally someone understand me.. I'm a maker.. and this is so true not only about business but everyday life too... Very often people don't understand that I need my time... to plan, to think, to find inspiration and to make... Thank you so much for this ❤",
#       'textOriginal': "Thanks , finally someone understand me.. I'm a maker.. and this is so true not only about business but everyday life too... Very often people don't understand that I need my time... to plan, to think, to find inspiration and to make... Thank you so much for this ❤",
#       'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#       'authorDisplayName': '@daccaippi',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nqZqOFHVGYfnzVGkWi2QxRd0Iov_eujxRXwreIcfE=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@daccaippi',
#       'authorChannelId': {'value': 'UCI_2NCxjxPr3xm7rUHT-pqg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 3,
#       'publishedAt': '2024-06-12T20:40:44Z',
#       'updatedAt': '2024-06-12T20:40:44Z'}},
#     {'kind': 'youtube#comment',
#      'etag': '1rKbjgnvK_uFN7RJ_HgaOetNNbk',
#      'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4arPpkVwl3',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'Thanks for your mail. Now I am here and listening at the end of my day to go sleep with you with new thoughts in mind and letting them work over the nigh. Thanks',
#       'textOriginal': 'Thanks for your mail. Now I am here and listening at the end of my day to go sleep with you with new thoughts in mind and letting them work over the nigh. Thanks',
#       'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#       'authorDisplayName': '@KarlaKolumna123',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mHVAbxVNIer4xu73wuUj0tIF4VbO0UYe8qpEmiarmHcGDb95odGAbtojSVFHuMn71Lij8=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@KarlaKolumna123',
#       'authorChannelId': {'value': 'UC0Vltp32XYKBS4Jq0kaRYgQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-06-12T21:20:03Z',
#       'updatedAt': '2024-06-12T21:20:03Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'rG0x4X9I85f1TpEOFO3sNvtLGdg',
#      'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4atM65OTTT',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': '@@bt5588are you a maker or a manager😂?',
#       'textOriginal': '@@bt5588are you a maker or a manager😂?',
#       'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#       'authorDisplayName': '@spontaneousmovement',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/n5NmAX6zoeMaZz__n2iNejSm0GhZOqlsyFTxUBH3LTQJqA2879-TcdrYjFlUrkRGt06dEEr76Q=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@spontaneousmovement',
#       'authorChannelId': {'value': 'UC0WrZ9FAvUK1DQZ4DyclxEQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-06-12T21:37:01Z',
#       'updatedAt': '2024-06-12T21:37:01Z'}}]}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'K8yIoJiXo-c5aSIC3LDRGK0Wcuo',
#   'id': 'UgzsT1mCsG2QnpKHl-R4AaABAg',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'videoId': 'GIRkQQHzsxI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'ZeBps-OlcEjgDxIY7CNf26__a1g',
#     'id': 'UgzsT1mCsG2QnpKHl-R4AaABAg',
#     'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#      'videoId': 'GIRkQQHzsxI',
#      'textDisplay': 'Alex …. bro, are you getting any sleep? \n\nIt’s the 50th upload this week, I’m all for it 😂',
#      'textOriginal': 'Alex …. bro, are you getting any sleep? \n\nIt’s the 50th upload this week, I’m all for it 😂',
#      'authorDisplayName': '@YasirKhanCoaching',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/KlQoDcwa91-jCa2-IOzXRlLP3VQO1YLKlXk_fudiDuzCdmS7QnLNWRrnA8U3kufGbGEx1y66FA=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/@YasirKhanCoaching',
#      'authorChannelId': {'value': 'UComhtcZ-SQ5rI3uwCk8JXmw'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 751,
#      'publishedAt': '2024-06-12T15:36:32Z',
#      'updatedAt': '2024-06-12T15:37:01Z'}},
#    'canReply': True,
#    'totalReplyCount': 23,
#    'isPublic': True},
#   'replies': {'comments': [{'kind': 'youtube#comment',
#      'etag': 'F-ivr0egapWtzl3nYcwXbZT8Ihw',
#      'id': 'UgzsT1mCsG2QnpKHl-R4AaABAg.A4aF5piAggaA4aGC-xAjg-',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': "It's all about productivity.",
#       'textOriginal': "It's all about productivity.",
#       'parentId': 'UgzsT1mCsG2QnpKHl-R4AaABAg',
#       'authorDisplayName': '@aexetan2769',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/8WDY7bjQAkSrfk7FNIaJaVvIq4UM8ST9cm04SjAcKWQmnnGcv6o1ioS_YQtNz7Rtl6XmzxsrgQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@aexetan2769',
#       'authorChannelId': {'value': 'UCfHnIrGCEn3Q8H9FKZ9CdJw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 37,
#       'publishedAt': '2024-06-12T15:46:06Z',
#       'updatedAt': '2024-06-12T15:46:06Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'm40ccDs1BWc0BFryJhQy4ft7lHI',
#      'id': 'UgzsT1mCsG2QnpKHl-R4AaABAg.A4aF5piAggaA4aGmB1rAcV',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'Too busy racing to $1B',
#       'textOriginal': 'Too busy racing to $1B',
#       'parentId': 'UgzsT1mCsG2QnpKHl-R4AaABAg',
#       'authorDisplayName': '@PerspicaciousMindset',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/D8RGxpaRRo0jNYOV4uFxQwOjAoqM8ZhTyjVsMNOyZ7LyidwqlO5Hm0gu9Vpk2CjQepwSMlGz-8g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@PerspicaciousMindset',
#       'authorChannelId': {'value': 'UC9IVuuK5HaJAASdUQc6QkNA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 31,
#       'publishedAt': '2024-06-12T15:51:11Z',
#       'updatedAt': '2024-06-12T15:51:11Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'bI8Yo1cfzbYDJ8T6io1sYHjCf_w',
#      'id': 'UgzsT1mCsG2QnpKHl-R4AaABAg.A4aF5piAggaA4aHim9qiOh',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': "Bro he's sleeping 10 hours a day, he said it before",
#       'textOriginal': "Bro he's sleeping 10 hours a day, he said it before",
#       'parentId': 'UgzsT1mCsG2QnpKHl-R4AaABAg',
#       'authorDisplayName': '@RedaMouhib-uv3gf',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nBiBza47xrVI22HQqbI5vVMSjOKCrypMV0wpODLhDTVe4Nl2G7EKpFmagMA2FW4bucAg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@RedaMouhib-uv3gf',
#       'authorChannelId': {'value': 'UCgidM-EiUJllqON0I3R10BA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 17,
#       'publishedAt': '2024-06-12T15:59:27Z',
#       'updatedAt': '2024-06-12T15:59:27Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'aMKndcoIedsMAydpJuYaLicNlPM',
#      'id': 'UgzsT1mCsG2QnpKHl-R4AaABAg.A4aF5piAggaA4aKZEQWPUg',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'A "I posted a gazillion videos on Youtube in a month and this is what happened" video coming soon probably.',
#       'textOriginal': 'A "I posted a gazillion videos on Youtube in a month and this is what happened" video coming soon probably.',
#       'parentId': 'UgzsT1mCsG2QnpKHl-R4AaABAg',
#       'authorDisplayName': '@aigarskluga7877',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lZSgtfj4tmKlAUx1LD8kldoDbh6RnR6vBJ5bUVhT8=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@aigarskluga7877',
#       'authorChannelId': {'value': 'UCZ-HGzfCseSi2nzjhwunX9A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 54,
#       'publishedAt': '2024-06-12T16:24:14Z',
#       'updatedAt': '2024-06-12T16:24:14Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'aifNNojXBKhiRXxLjI3-hVvxon0',
#      'id': 'UgzsT1mCsG2QnpKHl-R4AaABAg.A4aF5piAggaA4aM1iwKrRK',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'Hahahaha',
#       'textOriginal': 'Hahahaha',
#       'parentId': 'UgzsT1mCsG2QnpKHl-R4AaABAg',
#       'authorDisplayName': '@AlexMcDaniels',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/HigK6A4TRQ9YkCIRrVWBzyLM5F12T1B2PABapmmTkLiBxoptydMFTyqZ2YDgIIaDNhwJKaVICQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@AlexMcDaniels',
#       'authorChannelId': {'value': 'UCz7iY_iPsCsUK9Mjrh0TlFA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-06-12T16:37:08Z',
#       'updatedAt': '2024-06-12T16:37:08Z'}}]}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'dMJ3L_t-J8WT_MGAnIiqDuATpEY',
#   'id': 'UgzMgQbfI2grmjg4bdZ4AaABAg',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'videoId': 'GIRkQQHzsxI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'mUDfrLsjOwcD8-LjcRhlovra8Wg',
#     'id': 'UgzMgQbfI2grmjg4bdZ4AaABAg',
#     'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#      'videoId': 'GIRkQQHzsxI',
#      'textDisplay': "the pace of these videos is insane, it's been a video per day for weeks and they're all gold",
#      'textOriginal': "the pace of these videos is insane, it's been a video per day for weeks and they're all gold",
#      'authorDisplayName': '@OrnaSwanson',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/t5FEot-rGEuyEQrPP5vZMazQgIxJpaK8qCkpK_7giFa5s6SX6IYXXeJcHaEt7K2wAlgQs8h1=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/@OrnaSwanson',
#      'authorChannelId': {'value': 'UCyADn-aUo0XF8CSMQIoh83A'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 115,
#      'publishedAt': '2024-06-14T11:27:36Z',
#      'updatedAt': '2024-06-14T11:27:36Z'}},
#    'canReply': True,
#    'totalReplyCount': 1,
#    'isPublic': True},
#   'replies': {'comments': [{'kind': 'youtube#comment',
#      'etag': 'y8H85x0tTHpFn2iYtV7KgJHy5Lo',
#      'id': 'UgzMgQbfI2grmjg4bdZ4AaABAg.A4exCLhySgJA4gfeAeC6Nk',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'Hello My digits should be displayed on your notifications bar😊😊😊😊',
#       'textOriginal': 'Hello My digits should be displayed on your notifications bar😊😊😊😊',
#       'parentId': 'UgzMgQbfI2grmjg4bdZ4AaABAg',
#       'authorDisplayName': '@alexhormozi16-gmail.......k',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/DCqGmpNpsUNOXuivxhoGx66JzwbDexZR2aJEejSxVuzR6bV9oPAOEw6Tkio3XEQbYLjI1m-qkQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@alexhormozi16-gmail.......k',
#       'authorChannelId': {'value': 'UC7s0z428jBk0M4go2UVCszw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-06-15T03:32:44Z',
#       'updatedAt': '2024-06-15T03:32:44Z'}}]}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'GiFmWhpJZB3yk1FJnbEN2YdMjis',
#   'id': 'UgxBoqA6OK8dZRkqweJ4AaABAg',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'videoId': 'GIRkQQHzsxI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'LAyoTMOQVzUDRzLrmLXQODtwtf4',
#     'id': 'UgxBoqA6OK8dZRkqweJ4AaABAg',
#     'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#      'videoId': 'GIRkQQHzsxI',
#      'textDisplay': 'Alex\'s productivity summary: Say "NO" often and start working asap while eliminating all possible distractions during your workflow.',
#      'textOriginal': 'Alex\'s productivity summary: Say "NO" often and start working asap while eliminating all possible distractions during your workflow.',
#      'authorDisplayName': '@gjorgjicvetkovski2560',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/OCsrSHxiNI0DeGVz3qNJvFd9puxqbX6HfPzlISV-a3uWTkB9fllzBEwIEgdjF760pLlS920fQQ=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/@gjorgjicvetkovski2560',
#      'authorChannelId': {'value': 'UCwIfI5neF6LC-_o5fstAxpw'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 266,
#      'publishedAt': '2024-06-12T15:37:23Z',
#      'updatedAt': '2024-06-12T15:37:23Z'}},
#    'canReply': True,
#    'totalReplyCount': 4,
#    'isPublic': True},
#   'replies': {'comments': [{'kind': 'youtube#comment',
#      'etag': 'LH4G4DZWmHJq9xIk3iv92W2AAFc',
#      'id': 'UgxBoqA6OK8dZRkqweJ4AaABAg.A4aFC3MZsTQA4bQitq9G1-',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'No that is not the summary, you’re way too simplistic. You’re wrong.',
#       'textOriginal': 'No that is not the summary, you’re way too simplistic. You’re wrong.',
#       'parentId': 'UgxBoqA6OK8dZRkqweJ4AaABAg',
#       'authorDisplayName': '@SamuelGriffin',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kcM3xPL2DS19FGsi8h-hTJereuvUYFmluiSNDCJjo=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@SamuelGriffin',
#       'authorChannelId': {'value': 'UCQqDrp1gvDdDDFdN958f6gw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 3,
#       'publishedAt': '2024-06-13T02:37:22Z',
#       'updatedAt': '2024-06-13T02:37:22Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'qTF7PyO9qRvZ09-hwgED5elLdLE',
#      'id': 'UgxBoqA6OK8dZRkqweJ4AaABAg.A4aFC3MZsTQA4c82q7g5th',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': '@@SamuelGriffin Alex is wrong?',
#       'textOriginal': '@@SamuelGriffin Alex is wrong?',
#       'parentId': 'UgxBoqA6OK8dZRkqweJ4AaABAg',
#       'authorDisplayName': '@gjorgjicvetkovski2560',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/OCsrSHxiNI0DeGVz3qNJvFd9puxqbX6HfPzlISV-a3uWTkB9fllzBEwIEgdjF760pLlS920fQQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@gjorgjicvetkovski2560',
#       'authorChannelId': {'value': 'UCwIfI5neF6LC-_o5fstAxpw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-06-13T09:13:26Z',
#       'updatedAt': '2024-06-13T09:13:26Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'V8xBWygdXsKZv4G8MwgmGz0kW5w',
#      'id': 'UgxBoqA6OK8dZRkqweJ4AaABAg.A4aFC3MZsTQA4cZq35fjeb',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'These videos themselves could be a distraction haha',
#       'textOriginal': 'These videos themselves could be a distraction haha',
#       'parentId': 'UgxBoqA6OK8dZRkqweJ4AaABAg',
#       'authorDisplayName': '@williamjohnson1395',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mk3kd0o-3siBjeKwUDBHIZOVA-gJyZ_GVXVYPMEFQdwm4=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@williamjohnson1395',
#       'authorChannelId': {'value': 'UC-kzkJwzoCkNVbrmocP5Ngw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-06-13T13:16:13Z',
#       'updatedAt': '2024-06-13T13:16:13Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'gGHFYdVbp8v3Hwp22tuvsps-b98',
#      'id': 'UgxBoqA6OK8dZRkqweJ4AaABAg.A4aFC3MZsTQA4ce706JyWn',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': "@@williamjohnson1395 true... that's why I haven't watched the video yet. Maybe in my leisure time over the weekend.",
#       'textOriginal': "@@williamjohnson1395 true... that's why I haven't watched the video yet. Maybe in my leisure time over the weekend.",
#       'parentId': 'UgxBoqA6OK8dZRkqweJ4AaABAg',
#       'authorDisplayName': '@gjorgjicvetkovski2560',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/OCsrSHxiNI0DeGVz3qNJvFd9puxqbX6HfPzlISV-a3uWTkB9fllzBEwIEgdjF760pLlS920fQQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@gjorgjicvetkovski2560',
#       'authorChannelId': {'value': 'UCwIfI5neF6LC-_o5fstAxpw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-06-13T14:02:22Z',
#       'updatedAt': '2024-06-13T14:02:22Z'}}]}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'fG1vZtLkrdFrBNfC-lF20G3Rbow',
#   'id': 'UgzAHCdRbSSkzproJ1F4AaABAg',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'videoId': 'GIRkQQHzsxI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'pb-tGTqOx40K41EG26GtpayuUjg',
#     'id': 'UgzAHCdRbSSkzproJ1F4AaABAg',
#     'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#      'videoId': 'GIRkQQHzsxI',
#      'textDisplay': 'When I feel like I can’t keep on going I think to my self “ I can’t disappoint Alex”',
#      'textOriginal': 'When I feel like I can’t keep on going I think to my self “ I can’t disappoint Alex”',
#      'authorDisplayName': '@HDTRADING12',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/N51FEfk95VHl_uZ7VMUB18lypZkHMBGhlGPQWP5wcrnHTUen2oDw2V5sVKJQmjTutXMXOqahA5U=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/@HDTRADING12',
#      'authorChannelId': {'value': 'UCHGbMn9SoQYf4ulJqfqw7EA'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 164,
#      'publishedAt': '2024-06-12T17:16:34Z',
#      'updatedAt': '2024-06-12T17:16:34Z'}},
#    'canReply': True,
#    'totalReplyCount': 9,
#    'isPublic': True},
#   'replies': {'comments': [{'kind': 'youtube#comment',
#      'etag': '6z_Q-tvfePQpiidVGtI51xrChcA',
#      'id': 'UgzAHCdRbSSkzproJ1F4AaABAg.A4aQYZBJmBXA4b6B9vXTOl',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'that’s so corny bro. He don’t even know you 😂',
#       'textOriginal': 'that’s so corny bro. He don’t even know you 😂',
#       'parentId': 'UgzAHCdRbSSkzproJ1F4AaABAg',
#       'authorDisplayName': '@zeyadmohamed6315',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mUGBlBejAYRycsdd-bbUoCDSCyqDJMWbKHrBrEieA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@zeyadmohamed6315',
#       'authorChannelId': {'value': 'UCRWNg2DpQFYYaW4N0e2VDFg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 7,
#       'publishedAt': '2024-06-12T23:37:51Z',
#       'updatedAt': '2024-06-12T23:37:51Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'qYXzkVYqDYD81fq3cw5yrnEQhVQ',
#      'id': 'UgzAHCdRbSSkzproJ1F4AaABAg.A4aQYZBJmBXA4bCzgrvQzI',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': '\u200b@@zeyadmohamed6315 hey whatever works 💪 I used to imagine David Goggins screaming at me to get through my manual labor job sometimes 😅',
#       'textOriginal': '\u200b@@zeyadmohamed6315 hey whatever works 💪 I used to imagine David Goggins screaming at me to get through my manual labor job sometimes 😅',
#       'parentId': 'UgzAHCdRbSSkzproJ1F4AaABAg',
#       'authorDisplayName': '@Super_BeastGirl',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/Xhrr-0yBvkye1ffigkN7lwJehlVY61SClWO33_CepFHVlp8bTbygVhT8NSpg_1dP_eKKKI-s=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Super_BeastGirl',
#       'authorChannelId': {'value': 'UCsmpUrMoXrIiDAxPQ1RPqhA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-06-13T00:37:19Z',
#       'updatedAt': '2024-06-13T00:37:19Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'O24flp7pvkjtBcYXSvvCgIl9Wqo',
#      'id': 'UgzAHCdRbSSkzproJ1F4AaABAg.A4aQYZBJmBXA4bcF9OMDis',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': '❤',
#       'textOriginal': '❤',
#       'parentId': 'UgzAHCdRbSSkzproJ1F4AaABAg',
#       'authorDisplayName': '@sarsoura8289',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k7fcWHyzDXUpBBqi2tEOOegKdWlnxljA6rhsrhMntfXm4=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@sarsoura8289',
#       'authorChannelId': {'value': 'UCvDv6kL2EHOoI1ZMSgeyg4g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-06-13T04:26:45Z',
#       'updatedAt': '2024-06-13T04:26:45Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'ptSAPastJC2K7Sn6NGfDrRH7QAI',
#      'id': 'UgzAHCdRbSSkzproJ1F4AaABAg.A4aQYZBJmBXA4bwOJq_Dc6',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': "Don't disappoint yourself Son",
#       'textOriginal': "Don't disappoint yourself Son",
#       'parentId': 'UgzAHCdRbSSkzproJ1F4AaABAg',
#       'authorDisplayName': '@Michael-nf3vm',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/KfY_CNFm8pjGgWc8ZF3GN_I9KDUytjwZ18eoVfuwtjWH5BG8m_zGQCyen_d5CvLrXE2tieLJ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Michael-nf3vm',
#       'authorChannelId': {'value': 'UClVKwv3djmiZTDWNlffEXgg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 5,
#       'publishedAt': '2024-06-13T07:22:46Z',
#       'updatedAt': '2024-06-13T07:22:46Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'Ev9xKl0_uFBkhqwlmCQktghkkxU',
#      'id': 'UgzAHCdRbSSkzproJ1F4AaABAg.A4aQYZBJmBXA4c-WEtMKI7',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': '@@zeyadmohamed6315Fr, could be his mom, his dad, his future family, his kids.',
#       'textOriginal': '@@zeyadmohamed6315Fr, could be his mom, his dad, his future family, his kids.',
#       'parentId': 'UgzAHCdRbSSkzproJ1F4AaABAg',
#       'authorDisplayName': '@DayTripTookItTo10',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/CnbNwTj38nz1lMZJKnqSzo36AWSs3CZPmWL236FsivJl_Nt2FKF62MlvZwe_9luYUdna2JcE=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@DayTripTookItTo10',
#       'authorChannelId': {'value': 'UCh6kS-lowPa8-vRSmKHrafA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-06-13T07:58:48Z',
#       'updatedAt': '2024-06-13T07:58:48Z'}}]}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'fbAL1Uf47wKXWlmqDjGDJWLx_8g',
#   'id': 'UgyRg4V4ltvRkysqjQp4AaABAg',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'videoId': 'GIRkQQHzsxI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'OV73dVylyg8O5iYuWKoH3EllhwI',
#     'id': 'UgyRg4V4ltvRkysqjQp4AaABAg',
#     'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#      'videoId': 'GIRkQQHzsxI',
#      'textDisplay': 'The level of value this man provides is unmatched.',
#      'textOriginal': 'The level of value this man provides is unmatched.',
#      'authorDisplayName': '@ceowalid',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/TJAb-O8ASCDfvnIftWSkNNeHSRR6XY3A6NXYYTgK4A02lC6rrz9zFTjzPVVfFRTMJMbRocKXFA=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/@ceowalid',
#      'authorChannelId': {'value': 'UCrjqFjPA5szWtP5LUNbmGQw'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 162,
#      'publishedAt': '2024-06-12T15:39:10Z',
#      'updatedAt': '2024-06-12T15:39:10Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'iIyx1NzE3NjxRWetUGxcnvYk7vA',
#   'id': 'UgzpPP0GvNzEHg4fhdB4AaABAg',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'videoId': 'GIRkQQHzsxI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'pPveXZCr8ohmA7kgp5yGP5FYU3Y',
#     'id': 'UgzpPP0GvNzEHg4fhdB4AaABAg',
#     'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#      'videoId': 'GIRkQQHzsxI',
#      'textDisplay': 'These simple videos with the white board and zero distracting noises or jump cuts are fantastic! I’m here to learn, not crank my dopamine!',
#      'textOriginal': 'These simple videos with the white board and zero distracting noises or jump cuts are fantastic! I’m here to learn, not crank my dopamine!',
#      'authorDisplayName': '@Johansebastion',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mhsmnYE8s43yKvrOUEuO15ubUhsinTg2sCvnzOqI9_bv10vBFKsBHnJGDP5ESWQFEWmg=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/@Johansebastion',
#      'authorChannelId': {'value': 'UCu7YuhY5t00FRy8xAuGS61g'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 9,
#      'publishedAt': '2024-06-13T07:44:30Z',
#      'updatedAt': '2024-06-13T07:44:30Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'mNhqa8-DsvJJgcCpuxV6H0fubHQ',
#   'id': 'Ugwz7aRF9tgtSE6m0Al4AaABAg',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'videoId': 'GIRkQQHzsxI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'SASq8JZ_cL7Y-IQXEYM6bR-HyLw',
#     'id': 'Ugwz7aRF9tgtSE6m0Al4AaABAg',
#     'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#      'videoId': 'GIRkQQHzsxI',
#      'textDisplay': "Takeaways:\n- Schedule meeting days\n- Jealously guard your time\n- Disinvite people from unproductive meetings and don't be afraid to cancel meetings that don't need to happen",
#      'textOriginal': "Takeaways:\n- Schedule meeting days\n- Jealously guard your time\n- Disinvite people from unproductive meetings and don't be afraid to cancel meetings that don't need to happen",
#      'authorDisplayName': '@garitboothe3413',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nGKlEnmGvQjg1zGNsnp5GCqD4EXC64KH8TjUA3Aw90sUg=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/@garitboothe3413',
#      'authorChannelId': {'value': 'UChsmOC9-UQyz6sEMEII_oPw'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 22,
#      'publishedAt': '2024-06-12T22:19:09Z',
#      'updatedAt': '2024-06-12T22:19:09Z'}},
#    'canReply': True,
#    'totalReplyCount': 2,
#    'isPublic': True},
#   'replies': {'comments': [{'kind': 'youtube#comment',
#      'etag': 'J6lVLVJgx3WwHbqyDv6pS7Q4B80',
#      'id': 'Ugwz7aRF9tgtSE6m0Al4AaABAg.A4ayAh9ETHGA4hDkEw6UHv',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'and this is supposed to help me get $100 million?',
#       'textOriginal': 'and this is supposed to help me get $100 million?',
#       'parentId': 'Ugwz7aRF9tgtSE6m0Al4AaABAg',
#       'authorDisplayName': '@PandaBoy-zi2hg',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/TYhlWho8wS4rOjs0zwgtCRu58jb6UJmLRZdB6RCuHrefiftaPgeTQua5DjFGDUIh_bzt_aZJTw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@PandaBoy-zi2hg',
#       'authorChannelId': {'value': 'UCfvJ8ZAlJZNnXpI15NHwGAQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-06-15T08:39:23Z',
#       'updatedAt': '2024-06-15T08:39:23Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'g7BHw8zBhHK0lgX8KMU-0f7UHkE',
#      'id': 'Ugwz7aRF9tgtSE6m0Al4AaABAg.A4ayAh9ETHGA4i1k2golQi',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': "\u200b\u200b@@PandaBoy-zi2hgYes and to add to that if you only meet on Mondays and a potential client only meets on Tuesdays then they're not worth your time. Good luck making 100 million😂 caveat is I'm not a hater promise Alex has a lot of useful information but I suppose an exception to the rule is in order😊",
#       'textOriginal': "\u200b\u200b@@PandaBoy-zi2hgYes and to add to that if you only meet on Mondays and a potential client only meets on Tuesdays then they're not worth your time. Good luck making 100 million😂 caveat is I'm not a hater promise Alex has a lot of useful information but I suppose an exception to the rule is in order😊",
#       'parentId': 'Ugwz7aRF9tgtSE6m0Al4AaABAg',
#       'authorDisplayName': '@CinemaRaps',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_luR9A990DSEc4ktK6z93ar3XidI6w3rkdv82_BuX3MVhk=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@CinemaRaps',
#       'authorChannelId': {'value': 'UCgvm-noThpcnkfqjeWhmVDQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-06-15T16:13:45Z',
#       'updatedAt': '2024-06-15T16:14:17Z'}}]}},
#  {'kind': 'youtube#commentThread',
#   'etag': '2F6k6_APGjYCfGRB3HOTDRcqHAc',
#   'id': 'UgwiH7FgVS8sPO1am4p4AaABAg',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'videoId': 'GIRkQQHzsxI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'VVCrOJTXZ_xVX2MjRAKckFMc-08',
#     'id': 'UgwiH7FgVS8sPO1am4p4AaABAg',
#     'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#      'videoId': 'GIRkQQHzsxI',
#      'textDisplay': "For those that don't get it yet, Alex decided to do summer school. It's going to be a few weeks of value nonstop, for free. Sharpen your pencils.",
#      'textOriginal': "For those that don't get it yet, Alex decided to do summer school. It's going to be a few weeks of value nonstop, for free. Sharpen your pencils.",
#      'authorDisplayName': '@Aedonius',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/WgtES-siWq5NZN-d2icYo7OXrw8PX8AMh1okiptl60fzBA9l1P2kn5SV6oTQGG2zW6DqIdSm=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/@Aedonius',
#      'authorChannelId': {'value': 'UCW_n3FiAu1KXTmB4FvmVuTw'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 56,
#      'publishedAt': '2024-06-12T16:48:39Z',
#      'updatedAt': '2024-06-12T16:48:39Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'ak3uY7dwEWD2uhvJTzIV-BzNT-M',
#   'id': 'UgxbqBqEkAX6iiZMO4V4AaABAg',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'videoId': 'GIRkQQHzsxI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'Cgwk11naQq_4dl-BEgOX85B0ntk',
#     'id': 'UgxbqBqEkAX6iiZMO4V4AaABAg',
#     'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#      'videoId': 'GIRkQQHzsxI',
#      'textDisplay': 'How the hell does he have the time to do soo much, evaluate and analyse it, break it down so clearly and deliver sooo much value every effin time !!?? 🤯 G.O.A.T',
#      'textOriginal': 'How the hell does he have the time to do soo much, evaluate and analyse it, break it down so clearly and deliver sooo much value every effin time !!?? 🤯 G.O.A.T',
#      'authorDisplayName': '@HarshalAgarwal1339',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nwdc8pVbx_IgdANAQVe7UgosYm0EjwG6eHjqk4J0iLNOU=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/@HarshalAgarwal1339',
#      'authorChannelId': {'value': 'UCqH_yCutTFPThYwxZfEhrNA'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 103,
#      'publishedAt': '2024-06-12T16:02:59Z',
#      'updatedAt': '2024-06-12T16:02:59Z'}},
#    'canReply': True,
#    'totalReplyCount': 6,
#    'isPublic': True},
#   'replies': {'comments': [{'kind': 'youtube#comment',
#      'etag': 'dX22frhPt4GcZh2fHOBv9Lj1Ugg',
#      'id': 'UgxbqBqEkAX6iiZMO4V4AaABAg.A4aI7a2s1qFA4aOapN2iA9',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'Well he just explained his schedule.. plus from writing soooo much, he says he writes for hours daily',
#       'textOriginal': 'Well he just explained his schedule.. plus from writing soooo much, he says he writes for hours daily',
#       'parentId': 'UgxbqBqEkAX6iiZMO4V4AaABAg',
#       'authorDisplayName': '@kabewar77',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_ls05GlP4-DsvOy8revtK45pPgUL1kFgh4LGuYfvV-O3nyWoRp3CJzDqI8Ctf7Dywg_LQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@kabewar77',
#       'authorChannelId': {'value': 'UC6ycqkXYR7i7ibOZn_31YtA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 8,
#       'publishedAt': '2024-06-12T16:59:32Z',
#       'updatedAt': '2024-06-12T16:59:32Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'mLzS6Lo_aMvTtP9kZz-LSjy9-UA',
#      'id': 'UgxbqBqEkAX6iiZMO4V4AaABAg.A4aI7a2s1qFA4aSoKeGgra',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'experience baby',
#       'textOriginal': 'experience baby',
#       'parentId': 'UgxbqBqEkAX6iiZMO4V4AaABAg',
#       'authorDisplayName': '@somratdutta',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/_DQlkniRtWUJ9ybRDiEZiqywifFnrpUn5U2oOHrVqtGqUxHCH5ZtmALfVfVnbNjusEsmm-BG=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@somratdutta',
#       'authorChannelId': {'value': 'UCPFtxlWW4dtXK9_r2TZqJ_Q'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 2,
#       'publishedAt': '2024-06-12T17:36:20Z',
#       'updatedAt': '2024-06-12T17:36:20Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'NJBb3MSlCZFpGe2OzH8b_JELrNk',
#      'id': 'UgxbqBqEkAX6iiZMO4V4AaABAg.A4aI7a2s1qFA4aVKoDXQ0W',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': "He has a team. You don't really think he does this all by himself, do you? He is all about optimization. Outsourcing to other folks is how it works.",
#       'textOriginal': "He has a team. You don't really think he does this all by himself, do you? He is all about optimization. Outsourcing to other folks is how it works.",
#       'parentId': 'UgxbqBqEkAX6iiZMO4V4AaABAg',
#       'authorDisplayName': '@apmartini70',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kAzhFZrZyRBEqcJt1_WMukJA7LwNWtZrERfOrp4Oh5z-I=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@apmartini70',
#       'authorChannelId': {'value': 'UC2CRn1659d5B3xXPhzyGJsg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 6,
#       'publishedAt': '2024-06-12T17:58:23Z',
#       'updatedAt': '2024-06-12T17:58:23Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'hStOB9AZhOt4pHwklQMFzUAdoA8',
#      'id': 'UgxbqBqEkAX6iiZMO4V4AaABAg.A4aI7a2s1qFA4akrd2Z6Ch',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': "In his other videos he tries to describe the difference between THINKING you're working and ACTUALLY working. That's what most videos like this are all about...shine a light in THIS corner of the difference, shine a light in THAT corner of the difference...one video at a time.",
#       'textOriginal': "In his other videos he tries to describe the difference between THINKING you're working and ACTUALLY working. That's what most videos like this are all about...shine a light in THIS corner of the difference, shine a light in THAT corner of the difference...one video at a time.",
#       'parentId': 'UgxbqBqEkAX6iiZMO4V4AaABAg',
#       'authorDisplayName': '@tonyrichmond9428',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lz-xjat4z2F3jXXGJsaQ27vxtI-QGXau1FGv6gmw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@tonyrichmond9428',
#       'authorChannelId': {'value': 'UC_WipJNt2hSkWEH7v8_bZXQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 5,
#       'publishedAt': '2024-06-12T20:22:49Z',
#       'updatedAt': '2024-06-12T20:22:49Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'ImlDUEuR68RYxoO-qQhR5pmSoSk',
#      'id': 'UgxbqBqEkAX6iiZMO4V4AaABAg.A4aI7a2s1qFA4bf7mKIIrn',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'Great',
#       'textOriginal': 'Great',
#       'parentId': 'UgxbqBqEkAX6iiZMO4V4AaABAg',
#       'authorDisplayName': '@topogigio9421',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nVV36tbSHoYj311rs1KqkifxTMy5DOOw_z6tG8lq8=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@topogigio9421',
#       'authorChannelId': {'value': 'UCxrSJMCSF-M2_wKQCi6L1ig'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-06-13T04:51:58Z',
#       'updatedAt': '2024-06-13T04:51:58Z'}}]}},
#  {'kind': 'youtube#commentThread',
#   'etag': 's4H2UN59NvNgYzmT3zxAO2YF-DA',
#   'id': 'UgwQUH9Ko4kOSo9AEvF4AaABAg',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'videoId': 'GIRkQQHzsxI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'U_m92wh2TVcLBActTpd8OOklM_0',
#     'id': 'UgwQUH9Ko4kOSo9AEvF4AaABAg',
#     'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#      'videoId': 'GIRkQQHzsxI',
#      'textDisplay': 'Start early with diversified investments in stocks, bonds, and real estate. Maximize contributions to tax-advantaged accounts like 401(k)s and IRAs. Regularly review and adjust your strategy to ensure security.',
#      'textOriginal': 'Start early with diversified investments in stocks, bonds, and real estate. Maximize contributions to tax-advantaged accounts like 401(k)s and IRAs. Regularly review and adjust your strategy to ensure security.',
#      'authorDisplayName': '@icucmerc',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_m0Sa5Ay2bHi-yK2J6fxT2KCVM0UJjCemD_OhpICM6NFA=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/@icucmerc',
#      'authorChannelId': {'value': 'UCmVF0VfB4pMqTAXxOVfFUNQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 25,
#      'publishedAt': '2024-06-12T23:03:06Z',
#      'updatedAt': '2024-06-12T23:03:06Z'}},
#    'canReply': True,
#    'totalReplyCount': 15,
#    'isPublic': True},
#   'replies': {'comments': [{'kind': 'youtube#comment',
#      'etag': 'KMgUNdrMeBTnzYEhp6BgNveuYpE',
#      'id': 'UgwQUH9Ko4kOSo9AEvF4AaABAg.A4b2CatexLEA4b6J5N6U4a',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'Very possible! especially at this moment. Profits can be made in many different ways, but such intricate transactions should only be handled by seasoned market professionals.',
#       'textOriginal': 'Very possible! especially at this moment. Profits can be made in many different ways, but such intricate transactions should only be handled by seasoned market professionals.',
#       'parentId': 'UgwQUH9Ko4kOSo9AEvF4AaABAg',
#       'authorDisplayName': '@vanillatgif',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mW_rdrqhzqKtiyaOmNGu9_My2wkyYAw1IMNHmq2rT3FQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@vanillatgif',
#       'authorChannelId': {'value': 'UCWmByUZNjy4O6nsuiT9iNNQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-06-12T23:38:56Z',
#       'updatedAt': '2024-06-12T23:38:56Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'j-YrPcTuLRpA2ehINa5ou9CKSso',
#      'id': 'UgwQUH9Ko4kOSo9AEvF4AaABAg.A4b2CatexLEA4b6d_bAeeW',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': "Some persons think inves'tin is all about buying stocks; I think going into the stock market without a good experience is a big risk, that's why I'm lucky to have seen someone like mr Brian C Nelson.",
#       'textOriginal': "Some persons think inves'tin is all about buying stocks; I think going into the stock market without a good experience is a big risk, that's why I'm lucky to have seen someone like mr Brian C Nelson.",
#       'parentId': 'UgwQUH9Ko4kOSo9AEvF4AaABAg',
#       'authorDisplayName': '@Faijan-zx5ov',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lRTWRoJ5Mm1J6dwSFwLZYO2tYqK3zKpN4VbdDGguTxhPP-sB_V7uVUqTAw-NzD5GCobQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Faijan-zx5ov',
#       'authorChannelId': {'value': 'UC3hvv6usxlXWAwAjoRosgUw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-06-12T23:41:52Z',
#       'updatedAt': '2024-06-12T23:41:52Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'eiQ1M_KTghDRW6ng4vc5hCmGJnA',
#      'id': 'UgwQUH9Ko4kOSo9AEvF4AaABAg.A4b2CatexLEA4b7Sw1ykFE',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'Finding yourself a good broker is as same as finding a good wife, which you go less stress, you get just enough with so much little effort at things',
#       'textOriginal': 'Finding yourself a good broker is as same as finding a good wife, which you go less stress, you get just enough with so much little effort at things',
#       'parentId': 'UgwQUH9Ko4kOSo9AEvF4AaABAg',
#       'authorDisplayName': '@amytuttle1621',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_ld05STQ41AxCm520P8FMEmGBySxd7nUnf5rfrxym8=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@amytuttle1621',
#       'authorChannelId': {'value': 'UCdKNsfD1aeCVk0NjZ1znfQg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-06-12T23:49:01Z',
#       'updatedAt': '2024-06-12T23:49:01Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'i8wBaS89j1oGshFYa-qb1c_mbT8',
#      'id': 'UgwQUH9Ko4kOSo9AEvF4AaABAg.A4b2CatexLEA4b8ES2yS9v',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'Brian demonstrates an excellent understanding of market trends, making well informed decisions that leads to consistent profit',
#       'textOriginal': 'Brian demonstrates an excellent understanding of market trends, making well informed decisions that leads to consistent profit',
#       'parentId': 'UgwQUH9Ko4kOSo9AEvF4AaABAg',
#       'authorDisplayName': '@grizbaseball',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k7rre8HKx7_t2Emxa9KxE8BbNqH4DFU0zz5qY4kFAy4g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@grizbaseball',
#       'authorChannelId': {'value': 'UCHicBrFsO8U39INRY_5MpNQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-06-12T23:55:47Z',
#       'updatedAt': '2024-06-12T23:55:47Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'X1gFk9HvBFlDDJiApcx15Snh-tI',
#      'id': 'UgwQUH9Ko4kOSo9AEvF4AaABAg.A4b2CatexLEA4b8j3tPSqP',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': "I'm surprised that you just mentioned and recommend Mr Brian Nelson. I met him at a conference in 2018 and we have been working together ever since.",
#       'textOriginal': "I'm surprised that you just mentioned and recommend Mr Brian Nelson. I met him at a conference in 2018 and we have been working together ever since.",
#       'parentId': 'UgwQUH9Ko4kOSo9AEvF4AaABAg',
#       'authorDisplayName': '@whitefearlytales',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nxOF3VG8qGUCCK2o-Mkv2FFPasz3fU9xNtxadIOiQ2qw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@whitefearlytales',
#       'authorChannelId': {'value': 'UC1XGyYTLGUZEgOhqFLnu2kQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-06-13T00:00:06Z',
#       'updatedAt': '2024-06-13T00:00:06Z'}}]}},
#  {'kind': 'youtube#commentThread',
#   'etag': '9gOnZZDP9E7atrsGQ0tkV06_2lI',
#   'id': 'UgxefdckobjGAH7tRq14AaABAg',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'videoId': 'GIRkQQHzsxI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': '9ZtRI7eXLB3lQEytcbIvvxUon3U',
#     'id': 'UgxefdckobjGAH7tRq14AaABAg',
#     'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#      'videoId': 'GIRkQQHzsxI',
#      'textDisplay': '"I know what I need to do to make more money, and I just need to do that." \nAbsolute gold I\'ve only just begun to understand recently. Not only does it prevent nonsense meetings and nonsense projects in the name of humoring someone, it also makes me consume less learning material online once I\'ve got my game plan in place.',
# ...
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_n-TeQWMiGeGpJhfl31ANdpxTtL2FpACde7RpxS0-w=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/@rightdefensive3492',
#      'authorChannelId': {'value': 'UClBe-oHKBLrBu56l_-N7XzA'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2024-06-12T16:03:39Z',
#      'updatedAt': '2024-06-12T16:03:39Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'hTzT5OvW1kdoFEBAEECsuo0IaoY',
#   'id': 'UgwoMe1Cxfql4Q_MK_F4AaABAg',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'videoId': 'GIRkQQHzsxI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'iov7Q9pZ-p9o9f7qGec2bxlXdjk',
#     'id': 'UgwoMe1Cxfql4Q_MK_F4AaABAg',
#     'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#      'videoId': 'GIRkQQHzsxI',
#      'textDisplay': 'Anybody here in 2044 when I reach €100M ?',
#      'textOriginal': 'Anybody here in 2044 when I reach €100M ?',
#      'authorDisplayName': '@rubenhohls',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_klkHZc8Mo3Mak52gfOLtP-T_ILVdriXM0sCEl2H0wOmtbg=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/@rubenhohls',
#      'authorChannelId': {'value': 'UCSlVhj2zfrTG1HkiRlPikpQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 5,
#      'publishedAt': '2024-06-12T17:06:50Z',
#      'updatedAt': '2024-06-12T17:06:50Z'}},
#    'canReply': True,
#    'totalReplyCount': 3,
#    'isPublic': True},
#   'replies': {'comments': [{'kind': 'youtube#comment',
#      'etag': 'rU9tGI4kSypCEA3kxQgDJI2NDfc',
#      'id': 'UgwoMe1Cxfql4Q_MK_F4AaABAg.A4aPRBtsdsYA4b4KGA64CI',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'Enjoy that cup of coffee and a good medium bug steak. Back to work for the AI overlords tomorrow?',
#       'textOriginal': 'Enjoy that cup of coffee and a good medium bug steak. Back to work for the AI overlords tomorrow?',
#       'parentId': 'UgwoMe1Cxfql4Q_MK_F4AaABAg',
#       'authorDisplayName': '@snedzy1506',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lop7guZAXvEoc7I9n--rIx6IErjj4b3h6RSKOQ_F8=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@snedzy1506',
#       'authorChannelId': {'value': 'UCWS6oUgba4slWsWcj2tCY0w'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-06-12T23:21:37Z',
#       'updatedAt': '2024-06-12T23:21:37Z'}},
#     {'kind': 'youtube#comment',
#      'etag': '6ZtGmK2PZwGyWNRxTbsyM110aAo',
#      'id': 'UgwoMe1Cxfql4Q_MK_F4AaABAg.A4aPRBtsdsYA4b53J98NF9',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': '@@snedzy1506 my mentor Elizabeth Taylor does not approve of bug steak sorry.',
#       'textOriginal': '@@snedzy1506 my mentor Elizabeth Taylor does not approve of bug steak sorry.',
#       'parentId': 'UgwoMe1Cxfql4Q_MK_F4AaABAg',
#       'authorDisplayName': '@rubenhohls',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_klkHZc8Mo3Mak52gfOLtP-T_ILVdriXM0sCEl2H0wOmtbg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@rubenhohls',
#       'authorChannelId': {'value': 'UCSlVhj2zfrTG1HkiRlPikpQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-06-12T23:28:03Z',
#       'updatedAt': '2024-06-12T23:28:03Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'I5goAvyWIKr9sk7g-Oxq1c27NpE',
#      'id': 'UgwoMe1Cxfql4Q_MK_F4AaABAg.A4aPRBtsdsYA4cu0v8bQQU',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'I’ll be here for ya buddy ! See you in the long run',
#       'textOriginal': 'I’ll be here for ya buddy ! See you in the long run',
#       'parentId': 'UgwoMe1Cxfql4Q_MK_F4AaABAg',
#       'authorDisplayName': '@cameronmorris7176',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_l_wF0bZ9BOmt3xYmmjYk9oQ3TK0A8Tmgs84q3OLfZVn8Q=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@cameronmorris7176',
#       'authorChannelId': {'value': 'UCkrJq6jlagUL4kBKJY6X6TA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-06-13T16:21:20Z',
#       'updatedAt': '2024-06-13T16:21:20Z'}}]}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'MADykGvIHARtFXPSHBwlaVQQvU0',
#   'id': 'UgzF-6cgtT-zbNlmq_p4AaABAg',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'videoId': 'GIRkQQHzsxI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'm7XkIvzJ1f_NRzJCj9rKTdZodzs',
#     'id': 'UgzF-6cgtT-zbNlmq_p4AaABAg',
#     'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#      'videoId': 'GIRkQQHzsxI',
#      'textDisplay': 'that did not make you 100 million',
#      'textOriginal': 'that did not make you 100 million',
#      'authorDisplayName': '@criticalthinker-ys7vt',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nb3VezN7MzT_7FKtzv4E4kHkUN6Y3xRud-AhuR2qEO6Um7lPzPQnEZK0uYnh5C3usuJw=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/@criticalthinker-ys7vt',
#      'authorChannelId': {'value': 'UC9QsXnZ5ewcwMIJeVyNYVmQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2024-06-12T19:47:54Z',
#      'updatedAt': '2024-06-12T19:47:54Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'g9wlN1Xj3tJTjQhVZiZo2HVCr9E',
#   'id': 'Ugx0_65CK8iQ0xMLkc54AaABAg',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'videoId': 'GIRkQQHzsxI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'GltCZtHjmIhl1ZEWTSTqE7P9FhA',
#     'id': 'Ugx0_65CK8iQ0xMLkc54AaABAg',
#     'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#      'videoId': 'GIRkQQHzsxI',
#      'textDisplay': 'Büyük kolpa sıkıp videolardan para kazanıyon gibi geliyo semn bana dayı',
#      'textOriginal': 'Büyük kolpa sıkıp videolardan para kazanıyon gibi geliyo semn bana dayı',
#      'authorDisplayName': '@yasarsenol8046',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lHOzpfo1AaLsxx5Jz7gbqz2tmrYa4MKMhcX6uLx9LNFA=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/@yasarsenol8046',
#      'authorChannelId': {'value': 'UC9vO060EnXwVICVMxOp_A4w'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2024-06-15T03:13:20Z',
#      'updatedAt': '2024-06-15T03:13:20Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'cUJwEOrjkrGjMrGYjE6kI2KlfFo',
#   'id': 'UgxKpQa1JcwQ_CmVcXV4AaABAg',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'videoId': 'GIRkQQHzsxI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'bja1nhfy1Mzbo3RLsyej81ZDozc',
#     'id': 'UgxKpQa1JcwQ_CmVcXV4AaABAg',
#     'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#      'videoId': 'GIRkQQHzsxI',
#      'textDisplay': 'What a waste of time',
#      'textOriginal': 'What a waste of time',
#      'authorDisplayName': '@Nothing08643',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/cYaRZGfcaZmXogkmNTZPLWkKTNrn3sHAU5ozvO7VfgOvI5vZZGheceT7WzFl6V1cRwyN5xJ_Yg=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/@Nothing08643',
#      'authorChannelId': {'value': 'UCabPtEc6_BqVAFDlPcOwWKQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 1,
#      'publishedAt': '2024-06-12T17:52:35Z',
#      'updatedAt': '2024-06-12T17:52:35Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'insjTkynqimuhXev7xV3zck3lMA',
#   'id': 'UgyEKJHELnN5b0o9wA94AaABAg',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'videoId': 'GIRkQQHzsxI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'Tg80FMKgR33vcZm9nwoWGjrVeIw',
#     'id': 'UgyEKJHELnN5b0o9wA94AaABAg',
#     'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#      'videoId': 'GIRkQQHzsxI',
#      'textDisplay': 'First',
#      'textOriginal': 'First',
#      'authorDisplayName': '@olgafigueroa2909',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kig7EKhKApCcOLKAWFhxbF5-swBmVbRUmnmzOq6icKmmtH=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/@olgafigueroa2909',
#      'authorChannelId': {'value': 'UCjIUaVWXtQLx3KT3U9HS5Og'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2024-06-12T15:35:29Z',
#      'updatedAt': '2024-06-12T15:35:29Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'itWEiaQ_8fv0DRkvKAsuntchz6E',
#   'id': 'UgyCATC8ss07lQT0FJx4AaABAg',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'videoId': 'GIRkQQHzsxI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'baD9R1RJbcqCe67iwitwxVP1yAg',
#     'id': 'UgyCATC8ss07lQT0FJx4AaABAg',
#     'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#      'videoId': 'GIRkQQHzsxI',
#      'textDisplay': 'Do you have kids?',
#      'textOriginal': 'Do you have kids?',
#      'authorDisplayName': '@TheSilentWealth',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/u7JKmg5BPW04o39uVJ5_dz4FNO_iMDMgV7_v7Tz3LXi554nxHRjLH0at-GqSqj5ElB3LL8ZxSw=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/@TheSilentWealth',
#      'authorChannelId': {'value': 'UCuQsnZMZpb7H-Xi85-lLGWw'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2024-06-12T21:54:24Z',
#      'updatedAt': '2024-06-12T21:54:24Z'}},
#    'canReply': True,
#    'totalReplyCount': 1,
#    'isPublic': True},
#   'replies': {'comments': [{'kind': 'youtube#comment',
#      'etag': 'c2V7hUU0vU3hdsPHyw_vNuQ7UKo',
#      'id': 'UgyCATC8ss07lQT0FJx4AaABAg.A4avLQdSzGlA4awNVsMauY',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'No, he doesn’t.',
#       'textOriginal': 'No, he doesn’t.',
#       'parentId': 'UgyCATC8ss07lQT0FJx4AaABAg',
#       'authorDisplayName': '@IluvinortheIneffable',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kzC9dkG05HVnzZOm3B4ixSr0dKZZDXDRF4I86H3CKg5Os=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@IluvinortheIneffable',
#       'authorChannelId': {'value': 'UCvs6FpteCyUD2u-iJyzaDEw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-06-12T22:03:25Z',
#       'updatedAt': '2024-06-12T22:03:25Z'}}]}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'oweW-DKRfndNIFPcj8qugtHWv_c',
#   'id': 'UgwNbdfCkCpX04D1SbF4AaABAg',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'videoId': 'GIRkQQHzsxI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'jTKrCUhrKd5UdzAXhkQ_PGUWi4s',
#     'id': 'UgwNbdfCkCpX04D1SbF4AaABAg',
#     'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#      'videoId': 'GIRkQQHzsxI',
#      'textDisplay': 'If I could give you 1 like for every hour I lost due my manager "checking in" you wouldn\'t need other viewers',
#      'textOriginal': 'If I could give you 1 like for every hour I lost due my manager "checking in" you wouldn\'t need other viewers',
#      'authorDisplayName': '@firesmoker',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nZCDcxx-0EoQTSktgUdw8KXc5Tqj8K7IJffB-4DBI2Ew=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/@firesmoker',
#      'authorChannelId': {'value': 'UCuxxt0it-A-eLsmJt-eD_Ng'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2024-06-12T15:58:05Z',
#      'updatedAt': '2024-06-12T15:58:05Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'JAuSLkw9d2HuRhWJBSaXPt3hcGU',
#   'id': 'UgzkwQSzhtGZwz1sYe54AaABAg',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'videoId': 'GIRkQQHzsxI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'HWPc2b6Q2RC8uxb-1aYhbf_FYgM',
#     'id': 'UgzkwQSzhtGZwz1sYe54AaABAg',
#     'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#      'videoId': 'GIRkQQHzsxI',
#      'textDisplay': 'Th title of this video should be "Manager vs. Maker" and not the clickbait-y YoutTube algoritym title',
#      'textOriginal': 'Th title of this video should be "Manager vs. Maker" and not the clickbait-y YoutTube algoritym title',
#      'authorDisplayName': '@dylangeorge10',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nzzYLjdlXOySKaqjkXLZrjylrNof_0xTXzBK1We-V1c28=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/@dylangeorge10',
#      'authorChannelId': {'value': 'UCgSo2xefNXKtsTJgnON4qJQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 6,
#      'publishedAt': '2024-06-12T15:56:15Z',
#      'updatedAt': '2024-06-12T15:56:15Z'}},
#    'canReply': True,
#    'totalReplyCount': 3,
#    'isPublic': True},
#   'replies': {'comments': [{'kind': 'youtube#comment',
#      'etag': 'JLmrQazzQeJvp_kZjLA9TGNKMfo',
#      'id': 'UgzkwQSzhtGZwz1sYe54AaABAg.A4aHMISMObVA4aR1wFJARn',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': "The video is still valuable, so I don't really mind",
#       'textOriginal': "The video is still valuable, so I don't really mind",
#       'parentId': 'UgzkwQSzhtGZwz1sYe54AaABAg',
#       'authorDisplayName': '@jmc6326',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kq6YXb49jimZm2YludLYcB7k8cNgTm_4PC3ukkjBS36lsG88gBf4yVReewSB8_5Sc-1A=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@jmc6326',
#       'authorChannelId': {'value': 'UCxAJzJl0jSAW8I7-Cm4ky2A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-06-12T17:20:51Z',
#       'updatedAt': '2024-06-12T17:20:51Z'}},
#     {'kind': 'youtube#comment',
#      'etag': '9aU2oYlEt6vCfU34_2OPny35gtQ',
#      'id': 'UgzkwQSzhtGZwz1sYe54AaABAg.A4aHMISMObVA4aUGJegzUq',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'This comment is the depiction of what is wrong with the world.',
#       'textOriginal': 'This comment is the depiction of what is wrong with the world.',
#       'parentId': 'UgzkwQSzhtGZwz1sYe54AaABAg',
#       'authorDisplayName': '@MartijnVermeulen',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_n1E9fKPueq7847i-FXF_PbYz5mGSIEbcT02MmfsGSpEXU=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@MartijnVermeulen',
#       'authorChannelId': {'value': 'UCQZgospfaGrmINsF9wpfcdA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 2,
#       'publishedAt': '2024-06-12T17:49:02Z',
#       'updatedAt': '2024-06-12T17:49:02Z'}},
#     {'kind': 'youtube#comment',
#      'etag': '4bgDjoCG9fUGdQ32anfe_ElTvhg',
#      'id': 'UgzkwQSzhtGZwz1sYe54AaABAg.A4aHMISMObVA4aVP2UPcL4',
#      'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#       'videoId': 'GIRkQQHzsxI',
#       'textDisplay': 'Unless you actually want a bunch of people to see it.',
#       'textOriginal': 'Unless you actually want a bunch of people to see it.',
#       'parentId': 'UgzkwQSzhtGZwz1sYe54AaABAg',
#       'authorDisplayName': '@MelFinehout',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kIyeDmx7jJObjmL5Nju28m2ERhajXCiDrfdzxXRyg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@MelFinehout',
#       'authorChannelId': {'value': 'UCfbIhejT_tvMUQ2WfB5irtw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-06-12T17:58:58Z',
#       'updatedAt': '2024-06-12T17:58:58Z'}}]}}]

# %% [markdown]
# ### **get_comment_replies**
#
# ##### `get_comment_replies(comment_id: str, max_results: int = 20, **kwargs)`
#
# The `get_comment_replies` method retrieves replies to a specified YouTube comment.
#
# **Parameters:**
# - `comment_id` (str): The ID of the YouTube comment.
# - `max_results` (int, optional): The maximum number of replies to retrieve. Defaults to 20.
# - `**kwargs`: Additional parameters.
#
# **Returns:**
# - `dict`: A dictionary containing the replies.
#
# ##### **Example**

# %%
youtube.get_comment_replies('UgzmxQVvj6zVCjC4re54AaABAg')
# Out:
# {'kind': 'youtube#commentListResponse',
#  'etag': 'rPnJNyK16lyS1s-3Z-ABxa4VHlQ',
#  'pageInfo': {'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#comment',
#    'etag': '6MMAiuKkfIFnVPOp8CLvLbXCJIo',
#    'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4acG0wSpUO',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'textDisplay': 'This may be the most valuable video I’ve ever watched. <br><br>Thank you.',
#     'textOriginal': 'This may be the most valuable video I’ve ever watched. \n\nThank you.',
#     'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#     'authorDisplayName': '@bt5588',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_ntrXOigPPxuI78qT-oLy1X53AygsGz1gWYpqe2imY=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@bt5588',
#     'authorChannelId': {'value': 'UCBYyOjQJQWJxvOe15_XLKvw'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 12,
#     'publishedAt': '2024-06-12T19:07:38Z',
#     'updatedAt': '2024-06-12T19:07:38Z'}},
#   {'kind': 'youtube#comment',
#    'etag': 'Au1flwhzmIK7hVHHc_xWQOZ1zxQ',
#    'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4aexbvMD1Z',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'textDisplay': 'If  you manage to see this comment...make the time to stop watching the video, go get a pen, paper, or device and use this video as a tutorial....This is not a casual video where you usually sit and just listen to Alex and his Godlike beard, go make it happen!',
#     'textOriginal': 'If  you manage to see this comment...make the time to stop watching the video, go get a pen, paper, or device and use this video as a tutorial....This is not a casual video where you usually sit and just listen to Alex and his Godlike beard, go make it happen!',
#     'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#     'authorDisplayName': '@triniguy88',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k2UHB5Kgp8WdOeExC-gMcUyjlSXIUfKAXidKyeIiUdpKE=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@triniguy88',
#     'authorChannelId': {'value': 'UCqtx5eYhNmJQvG5YhOUlbmg'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 4,
#     'publishedAt': '2024-06-12T19:31:12Z',
#     'updatedAt': '2024-06-12T19:31:12Z'}},
#   {'kind': 'youtube#comment',
#    'etag': 'RR7hwca8tAJgFaVixOV5Vfqs98s',
#    'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4amux-FaRa',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'textDisplay': 'Thanks , finally someone understand me.. I&#39;m a maker.. and this is so true not only about business but everyday life too... Very often people don&#39;t understand that I need my time... to plan, to think, to find inspiration and to make... Thank you so much for this ❤',
#     'textOriginal': "Thanks , finally someone understand me.. I'm a maker.. and this is so true not only about business but everyday life too... Very often people don't understand that I need my time... to plan, to think, to find inspiration and to make... Thank you so much for this ❤",
#     'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#     'authorDisplayName': '@daccaippi',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nqZqOFHVGYfnzVGkWi2QxRd0Iov_eujxRXwreIcfE=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@daccaippi',
#     'authorChannelId': {'value': 'UCI_2NCxjxPr3xm7rUHT-pqg'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 3,
#     'publishedAt': '2024-06-12T20:40:44Z',
#     'updatedAt': '2024-06-12T20:40:44Z'}},
#   {'kind': 'youtube#comment',
#    'etag': 'IwOhSZYm5TmKErHwQ4rQRunzjCw',
#    'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4arPpkVwl3',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'textDisplay': 'Thanks for your mail. Now I am here and listening at the end of my day to go sleep with you with new thoughts in mind and letting them work over the nigh. Thanks',
#     'textOriginal': 'Thanks for your mail. Now I am here and listening at the end of my day to go sleep with you with new thoughts in mind and letting them work over the nigh. Thanks',
#     'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#     'authorDisplayName': '@KarlaKolumna123',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mHVAbxVNIer4xu73wuUj0tIF4VbO0UYe8qpEmiarmHcGDb95odGAbtojSVFHuMn71Lij8=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@KarlaKolumna123',
#     'authorChannelId': {'value': 'UC0Vltp32XYKBS4Jq0kaRYgQ'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 1,
#     'publishedAt': '2024-06-12T21:20:03Z',
#     'updatedAt': '2024-06-12T21:20:03Z'}},
#   {'kind': 'youtube#comment',
#    'etag': 'bBgGOAFJPu_TWY_hQGDBX3n5Mkw',
#    'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4atM65OTTT',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'textDisplay': '@@bt5588are you a maker or a manager😂?',
#     'textOriginal': '@@bt5588are you a maker or a manager😂?',
#     'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#     'authorDisplayName': '@spontaneousmovement',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/n5NmAX6zoeMaZz__n2iNejSm0GhZOqlsyFTxUBH3LTQJqA2879-TcdrYjFlUrkRGt06dEEr76Q=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@spontaneousmovement',
#     'authorChannelId': {'value': 'UC0WrZ9FAvUK1DQZ4DyclxEQ'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2024-06-12T21:37:01Z',
#     'updatedAt': '2024-06-12T21:37:01Z'}},
#   {'kind': 'youtube#comment',
#    'etag': 'vk8oETnFuibrhkRXM4R0rUDtEtM',
#    'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4axPIFOVym',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'textDisplay': 'Alex never stop putting out these videos!<br>I am learning a lot from you...',
#     'textOriginal': 'Alex never stop putting out these videos!\nI am learning a lot from you...',
#     'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#     'authorDisplayName': '@DKS_008',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/tIuCcx0CUB39oY9FDCRnCsSy9abtk4SXLJenLgi6A8nKbBpDcXwvOC8udvOV8o4A1aOl-oV30Q=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@DKS_008',
#     'authorChannelId': {'value': 'UCJNI-Sd_wIwb8UH8wVFoKBA'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 1,
#     'publishedAt': '2024-06-12T22:12:24Z',
#     'updatedAt': '2024-06-12T22:12:24Z'}},
#   {'kind': 'youtube#comment',
#    'etag': '-UxoYjCiXQEelNCX2TSjspsMPO4',
#    'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4b6PAXv5x2',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'textDisplay': 'EVERY FREAKING PERSON IN THE FREAKING WORLD IS TRYING TO STOP ME FROM ACCOMPLISHING ANYTHING AND AT SOME POINT IM GOING TO BURST',
#     'textOriginal': 'EVERY FREAKING PERSON IN THE FREAKING WORLD IS TRYING TO STOP ME FROM ACCOMPLISHING ANYTHING AND AT SOME POINT IM GOING TO BURST',
#     'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#     'authorDisplayName': '@SHE3e23',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/5rTB_mHDeFq4GGUCA-96ICjZqh-TSZ-YUtH5oQsrZCXQNPQt05wUQTvmRpk0DRZBsJ5NyZBsjA=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@SHE3e23',
#     'authorChannelId': {'value': 'UCkpUkY9g0xnC-YbttKVYqXw'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2024-06-12T23:39:46Z',
#     'updatedAt': '2024-06-12T23:39:46Z'}},
#   {'kind': 'youtube#comment',
#    'etag': 'KfoZ8mSro1v38k5nC9yHk6-ThcI',
#    'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4b7RRkBBKe',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'textDisplay': 'I’m gonna use this for the rest of my life, 100%',
#     'textOriginal': 'I’m gonna use this for the rest of my life, 100%',
#     'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#     'authorDisplayName': '@xavierjdeleon',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lpWxwhuWySDesNtZ6Q8-8I9jjYS45G5HxTQnRkuqb2Ins=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@xavierjdeleon',
#     'authorChannelId': {'value': 'UC9BmgMoUJyI9cu0lNLW5Z8A'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2024-06-12T23:48:49Z',
#     'updatedAt': '2024-06-12T23:48:49Z'}},
#   {'kind': 'youtube#comment',
#    'etag': 'ZtOIi0kwXZ1IZAGes2HyePpfy6M',
#    'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4bQsvSwaQa',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'textDisplay': 'This man just pointed out my biggest friction to my success in the past 15 years of my life... Forget making bad or good business decisions.. at any point in your journey... YOU HAVE BEEN RESPONSIBLE FOR THE USE OF YOUR TIME... Alex is literally crushing my business mentality to look at business with new eyes.',
#     'textOriginal': 'This man just pointed out my biggest friction to my success in the past 15 years of my life... Forget making bad or good business decisions.. at any point in your journey... YOU HAVE BEEN RESPONSIBLE FOR THE USE OF YOUR TIME... Alex is literally crushing my business mentality to look at business with new eyes.',
#     'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#     'authorDisplayName': '@kujengadigital1500',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_li8aTNt-5vo7gxynu0Inv_VbwFtZd_MyYQvJQQFovW2A=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@kujengadigital1500',
#     'authorChannelId': {'value': 'UC9sTCojuP3-fhWb0cW6hsOw'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2024-06-13T02:38:43Z',
#     'updatedAt': '2024-06-13T02:38:43Z'}},
#   {'kind': 'youtube#comment',
#    'etag': 'cYH7j0vjI3tbwCj1asDI7NGWtUY',
#    'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4bV114Wn__',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'textDisplay': '@alexhormozi please make shorter videos as people who are trying to build real business dont have time for long content consumption',
#     'textOriginal': '@alexhormozi please make shorter videos as people who are trying to build real business dont have time for long content consumption',
#     'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#     'authorDisplayName': '@WanderlustingCouple',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nkq0JMZ0lchZKe0d_DQUsyyAyTyQSJwOLkBhAY_2GYKA=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@WanderlustingCouple',
#     'authorChannelId': {'value': 'UC75NkUsm36QZUkDJ3r0wpTg'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 1,
#     'publishedAt': '2024-06-13T03:14:56Z',
#     'updatedAt': '2024-06-13T03:14:56Z'}},
#   {'kind': 'youtube#comment',
#    'etag': 'eGsERlorurC3bXuDRwk5COkHuGc',
#    'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4cTXm3H-WF',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'textDisplay': 'just pfffwow ❤',
#     'textOriginal': 'just pfffwow ❤',
#     'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#     'authorDisplayName': '@Gersende1975',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k1z8BNT4RUJgfBGpSU1mmgGSHkVlzwnzsikNSDFemVuG4=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@Gersende1975',
#     'authorChannelId': {'value': 'UCrdVRlYhew6AIGi-hwwohZg'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2024-06-13T12:21:10Z',
#     'updatedAt': '2024-06-13T12:21:10Z'}},
#   {'kind': 'youtube#comment',
#    'etag': 'EB7D-gLqFBeYSxyY8ep8z8Vnu6s',
#    'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4ebWnDMFh6',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'textDisplay': '💯!!!<br><br>Thank you soo much!',
#     'textOriginal': '💯!!!\n\nThank you soo much!',
#     'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#     'authorDisplayName': '@SnafuReady',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/zUuRePBY4TrwKcehHU3gCXGE5PGb0M34jhPf1AXv5FZs10_nYjVkVetHLS2akldEBYssoEkGd_8=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@SnafuReady',
#     'authorChannelId': {'value': 'UCV9fSQWjlI6nKonkhfa4OUQ'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2024-06-14T08:18:09Z',
#     'updatedAt': '2024-06-14T08:18:09Z'}},
#   {'kind': 'youtube#comment',
#    'etag': '7VpInOUL3MM0Z9_HYGCTtZ6ls1Q',
#    'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4fE9Qn0NEW',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'textDisplay': 'Alex, tienes este contenido en Español?',
#     'textOriginal': 'Alex, tienes este contenido en Español?',
#     'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#     'authorDisplayName': '@yosmeraguirre',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nQAiXOYtf9aL3re0XnQmLEwdFF47Dxm3IvoivoIBa0GCw=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@yosmeraguirre',
#     'authorChannelId': {'value': 'UCZYuNA8v95Qiy7pK0XGbewA'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2024-06-14T14:04:29Z',
#     'updatedAt': '2024-06-14T14:04:29Z'}},
#   {'kind': 'youtube#comment',
#    'etag': 'IsC0d2-Yr3phHZKyuOe-KLJSqdM',
#    'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4fEQjxYFwT',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'textDisplay': 'Dude, EVERY Product Manager should watch this video!  I&#39;ve seen Product Manager destroy developer productivity based on THIS dynamic alone!',
#     'textOriginal': "Dude, EVERY Product Manager should watch this video!  I've seen Product Manager destroy developer productivity based on THIS dynamic alone!",
#     'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#     'authorDisplayName': '@Michael-ne7eu',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_ksDT2IYToPQYFiIdjAfZLPaT3-alKbnNT56tQzRn3GM8vu=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@Michael-ne7eu',
#     'authorChannelId': {'value': 'UCUOfUHIn9Z7qWEBKD48-LPA'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2024-06-14T14:06:51Z',
#     'updatedAt': '2024-06-14T14:06:51Z'}},
#   {'kind': 'youtube#comment',
#    'etag': 'Esn2zrvuGK8BhqpJ5bvuRr4gGg0',
#    'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4gnImAOCEt',
#    'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#     'textDisplay': 'THANK YOU!!!!',
#     'textOriginal': 'THANK YOU!!!!',
#     'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#     'authorDisplayName': '@laurieellis1190',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k7WvGNLGpkVYgtd46uDfGmnYJR502rQQT1ZlA32EaTr-cj=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@laurieellis1190',
#     'authorChannelId': {'value': 'UCMCmygUldkUbIUHF1IFSTEA'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2024-06-15T04:39:35Z',
#     'updatedAt': '2024-06-15T04:39:35Z'}}]}

# %% [markdown]
# ### **get_all_comment_replies**
#
# ##### `get_all_comment_replies(comment_id: str, **kwargs)`
#
# The `get_all_comment_replies` method retrieves all replies to a specified YouTube comment.
#
# **Parameters:**
# - `comment_id` (str): The ID of the YouTube comment.
# - `**kwargs`: Additional parameters.
#
# **Returns:**
# - `list`: A list of dictionaries, each representing a reply.
#
# ##### **Example**

# %%
youtube.get_all_comment_replies('UgzmxQVvj6zVCjC4re54AaABAg')
# Out:
# [{'kind': 'youtube#comment',
#   'etag': '6MMAiuKkfIFnVPOp8CLvLbXCJIo',
#   'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4acG0wSpUO',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'textDisplay': 'This may be the most valuable video I’ve ever watched. <br><br>Thank you.',
#    'textOriginal': 'This may be the most valuable video I’ve ever watched. \n\nThank you.',
#    'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#    'authorDisplayName': '@bt5588',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_ntrXOigPPxuI78qT-oLy1X53AygsGz1gWYpqe2imY=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@bt5588',
#    'authorChannelId': {'value': 'UCBYyOjQJQWJxvOe15_XLKvw'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 12,
#    'publishedAt': '2024-06-12T19:07:38Z',
#    'updatedAt': '2024-06-12T19:07:38Z'}},
#  {'kind': 'youtube#comment',
#   'etag': 'Au1flwhzmIK7hVHHc_xWQOZ1zxQ',
#   'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4aexbvMD1Z',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'textDisplay': 'If  you manage to see this comment...make the time to stop watching the video, go get a pen, paper, or device and use this video as a tutorial....This is not a casual video where you usually sit and just listen to Alex and his Godlike beard, go make it happen!',
#    'textOriginal': 'If  you manage to see this comment...make the time to stop watching the video, go get a pen, paper, or device and use this video as a tutorial....This is not a casual video where you usually sit and just listen to Alex and his Godlike beard, go make it happen!',
#    'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#    'authorDisplayName': '@triniguy88',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k2UHB5Kgp8WdOeExC-gMcUyjlSXIUfKAXidKyeIiUdpKE=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@triniguy88',
#    'authorChannelId': {'value': 'UCqtx5eYhNmJQvG5YhOUlbmg'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 4,
#    'publishedAt': '2024-06-12T19:31:12Z',
#    'updatedAt': '2024-06-12T19:31:12Z'}},
#  {'kind': 'youtube#comment',
#   'etag': 'RR7hwca8tAJgFaVixOV5Vfqs98s',
#   'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4amux-FaRa',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'textDisplay': 'Thanks , finally someone understand me.. I&#39;m a maker.. and this is so true not only about business but everyday life too... Very often people don&#39;t understand that I need my time... to plan, to think, to find inspiration and to make... Thank you so much for this ❤',
#    'textOriginal': "Thanks , finally someone understand me.. I'm a maker.. and this is so true not only about business but everyday life too... Very often people don't understand that I need my time... to plan, to think, to find inspiration and to make... Thank you so much for this ❤",
#    'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#    'authorDisplayName': '@daccaippi',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nqZqOFHVGYfnzVGkWi2QxRd0Iov_eujxRXwreIcfE=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@daccaippi',
#    'authorChannelId': {'value': 'UCI_2NCxjxPr3xm7rUHT-pqg'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 3,
#    'publishedAt': '2024-06-12T20:40:44Z',
#    'updatedAt': '2024-06-12T20:40:44Z'}},
#  {'kind': 'youtube#comment',
#   'etag': 'IwOhSZYm5TmKErHwQ4rQRunzjCw',
#   'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4arPpkVwl3',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'textDisplay': 'Thanks for your mail. Now I am here and listening at the end of my day to go sleep with you with new thoughts in mind and letting them work over the nigh. Thanks',
#    'textOriginal': 'Thanks for your mail. Now I am here and listening at the end of my day to go sleep with you with new thoughts in mind and letting them work over the nigh. Thanks',
#    'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#    'authorDisplayName': '@KarlaKolumna123',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mHVAbxVNIer4xu73wuUj0tIF4VbO0UYe8qpEmiarmHcGDb95odGAbtojSVFHuMn71Lij8=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@KarlaKolumna123',
#    'authorChannelId': {'value': 'UC0Vltp32XYKBS4Jq0kaRYgQ'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 1,
#    'publishedAt': '2024-06-12T21:20:03Z',
#    'updatedAt': '2024-06-12T21:20:03Z'}},
#  {'kind': 'youtube#comment',
#   'etag': 'bBgGOAFJPu_TWY_hQGDBX3n5Mkw',
#   'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4atM65OTTT',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'textDisplay': '@@bt5588are you a maker or a manager😂?',
#    'textOriginal': '@@bt5588are you a maker or a manager😂?',
#    'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#    'authorDisplayName': '@spontaneousmovement',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/n5NmAX6zoeMaZz__n2iNejSm0GhZOqlsyFTxUBH3LTQJqA2879-TcdrYjFlUrkRGt06dEEr76Q=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@spontaneousmovement',
#    'authorChannelId': {'value': 'UC0WrZ9FAvUK1DQZ4DyclxEQ'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2024-06-12T21:37:01Z',
#    'updatedAt': '2024-06-12T21:37:01Z'}},
#  {'kind': 'youtube#comment',
#   'etag': 'vk8oETnFuibrhkRXM4R0rUDtEtM',
#   'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4axPIFOVym',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'textDisplay': 'Alex never stop putting out these videos!<br>I am learning a lot from you...',
#    'textOriginal': 'Alex never stop putting out these videos!\nI am learning a lot from you...',
#    'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#    'authorDisplayName': '@DKS_008',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/tIuCcx0CUB39oY9FDCRnCsSy9abtk4SXLJenLgi6A8nKbBpDcXwvOC8udvOV8o4A1aOl-oV30Q=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@DKS_008',
#    'authorChannelId': {'value': 'UCJNI-Sd_wIwb8UH8wVFoKBA'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 1,
#    'publishedAt': '2024-06-12T22:12:24Z',
#    'updatedAt': '2024-06-12T22:12:24Z'}},
#  {'kind': 'youtube#comment',
#   'etag': '-UxoYjCiXQEelNCX2TSjspsMPO4',
#   'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4b6PAXv5x2',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'textDisplay': 'EVERY FREAKING PERSON IN THE FREAKING WORLD IS TRYING TO STOP ME FROM ACCOMPLISHING ANYTHING AND AT SOME POINT IM GOING TO BURST',
#    'textOriginal': 'EVERY FREAKING PERSON IN THE FREAKING WORLD IS TRYING TO STOP ME FROM ACCOMPLISHING ANYTHING AND AT SOME POINT IM GOING TO BURST',
#    'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#    'authorDisplayName': '@SHE3e23',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/5rTB_mHDeFq4GGUCA-96ICjZqh-TSZ-YUtH5oQsrZCXQNPQt05wUQTvmRpk0DRZBsJ5NyZBsjA=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@SHE3e23',
#    'authorChannelId': {'value': 'UCkpUkY9g0xnC-YbttKVYqXw'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2024-06-12T23:39:46Z',
#    'updatedAt': '2024-06-12T23:39:46Z'}},
#  {'kind': 'youtube#comment',
#   'etag': 'KfoZ8mSro1v38k5nC9yHk6-ThcI',
#   'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4b7RRkBBKe',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'textDisplay': 'I’m gonna use this for the rest of my life, 100%',
#    'textOriginal': 'I’m gonna use this for the rest of my life, 100%',
#    'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#    'authorDisplayName': '@xavierjdeleon',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lpWxwhuWySDesNtZ6Q8-8I9jjYS45G5HxTQnRkuqb2Ins=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@xavierjdeleon',
#    'authorChannelId': {'value': 'UC9BmgMoUJyI9cu0lNLW5Z8A'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2024-06-12T23:48:49Z',
#    'updatedAt': '2024-06-12T23:48:49Z'}},
#  {'kind': 'youtube#comment',
#   'etag': 'ZtOIi0kwXZ1IZAGes2HyePpfy6M',
#   'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4bQsvSwaQa',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'textDisplay': 'This man just pointed out my biggest friction to my success in the past 15 years of my life... Forget making bad or good business decisions.. at any point in your journey... YOU HAVE BEEN RESPONSIBLE FOR THE USE OF YOUR TIME... Alex is literally crushing my business mentality to look at business with new eyes.',
#    'textOriginal': 'This man just pointed out my biggest friction to my success in the past 15 years of my life... Forget making bad or good business decisions.. at any point in your journey... YOU HAVE BEEN RESPONSIBLE FOR THE USE OF YOUR TIME... Alex is literally crushing my business mentality to look at business with new eyes.',
#    'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#    'authorDisplayName': '@kujengadigital1500',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_li8aTNt-5vo7gxynu0Inv_VbwFtZd_MyYQvJQQFovW2A=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@kujengadigital1500',
#    'authorChannelId': {'value': 'UC9sTCojuP3-fhWb0cW6hsOw'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2024-06-13T02:38:43Z',
#    'updatedAt': '2024-06-13T02:38:43Z'}},
#  {'kind': 'youtube#comment',
#   'etag': 'cYH7j0vjI3tbwCj1asDI7NGWtUY',
#   'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4bV114Wn__',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'textDisplay': '@alexhormozi please make shorter videos as people who are trying to build real business dont have time for long content consumption',
#    'textOriginal': '@alexhormozi please make shorter videos as people who are trying to build real business dont have time for long content consumption',
#    'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#    'authorDisplayName': '@WanderlustingCouple',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nkq0JMZ0lchZKe0d_DQUsyyAyTyQSJwOLkBhAY_2GYKA=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@WanderlustingCouple',
#    'authorChannelId': {'value': 'UC75NkUsm36QZUkDJ3r0wpTg'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 1,
#    'publishedAt': '2024-06-13T03:14:56Z',
#    'updatedAt': '2024-06-13T03:14:56Z'}},
#  {'kind': 'youtube#comment',
#   'etag': 'eGsERlorurC3bXuDRwk5COkHuGc',
#   'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4cTXm3H-WF',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'textDisplay': 'just pfffwow ❤',
#    'textOriginal': 'just pfffwow ❤',
#    'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#    'authorDisplayName': '@Gersende1975',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k1z8BNT4RUJgfBGpSU1mmgGSHkVlzwnzsikNSDFemVuG4=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@Gersende1975',
#    'authorChannelId': {'value': 'UCrdVRlYhew6AIGi-hwwohZg'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2024-06-13T12:21:10Z',
#    'updatedAt': '2024-06-13T12:21:10Z'}},
#  {'kind': 'youtube#comment',
#   'etag': 'EB7D-gLqFBeYSxyY8ep8z8Vnu6s',
#   'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4ebWnDMFh6',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'textDisplay': '💯!!!<br><br>Thank you soo much!',
#    'textOriginal': '💯!!!\n\nThank you soo much!',
#    'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#    'authorDisplayName': '@SnafuReady',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/zUuRePBY4TrwKcehHU3gCXGE5PGb0M34jhPf1AXv5FZs10_nYjVkVetHLS2akldEBYssoEkGd_8=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@SnafuReady',
#    'authorChannelId': {'value': 'UCV9fSQWjlI6nKonkhfa4OUQ'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2024-06-14T08:18:09Z',
#    'updatedAt': '2024-06-14T08:18:09Z'}},
#  {'kind': 'youtube#comment',
#   'etag': '7VpInOUL3MM0Z9_HYGCTtZ6ls1Q',
#   'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4fE9Qn0NEW',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'textDisplay': 'Alex, tienes este contenido en Español?',
#    'textOriginal': 'Alex, tienes este contenido en Español?',
#    'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#    'authorDisplayName': '@yosmeraguirre',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nQAiXOYtf9aL3re0XnQmLEwdFF47Dxm3IvoivoIBa0GCw=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@yosmeraguirre',
#    'authorChannelId': {'value': 'UCZYuNA8v95Qiy7pK0XGbewA'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2024-06-14T14:04:29Z',
#    'updatedAt': '2024-06-14T14:04:29Z'}},
#  {'kind': 'youtube#comment',
#   'etag': 'IsC0d2-Yr3phHZKyuOe-KLJSqdM',
#   'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4fEQjxYFwT',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'textDisplay': 'Dude, EVERY Product Manager should watch this video!  I&#39;ve seen Product Manager destroy developer productivity based on THIS dynamic alone!',
#    'textOriginal': "Dude, EVERY Product Manager should watch this video!  I've seen Product Manager destroy developer productivity based on THIS dynamic alone!",
#    'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#    'authorDisplayName': '@Michael-ne7eu',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_ksDT2IYToPQYFiIdjAfZLPaT3-alKbnNT56tQzRn3GM8vu=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@Michael-ne7eu',
#    'authorChannelId': {'value': 'UCUOfUHIn9Z7qWEBKD48-LPA'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2024-06-14T14:06:51Z',
#    'updatedAt': '2024-06-14T14:06:51Z'}},
#  {'kind': 'youtube#comment',
#   'etag': 'Esn2zrvuGK8BhqpJ5bvuRr4gGg0',
#   'id': 'UgzmxQVvj6zVCjC4re54AaABAg.A4aWoiekjQGA4gnImAOCEt',
#   'snippet': {'channelId': 'UCUyDOdBWhC1MCxEjC46d-zw',
#    'textDisplay': 'THANK YOU!!!!',
#    'textOriginal': 'THANK YOU!!!!',
#    'parentId': 'UgzmxQVvj6zVCjC4re54AaABAg',
#    'authorDisplayName': '@laurieellis1190',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k7WvGNLGpkVYgtd46uDfGmnYJR502rQQT1ZlA32EaTr-cj=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/@laurieellis1190',
#    'authorChannelId': {'value': 'UCMCmygUldkUbIUHF1IFSTEA'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2024-06-15T04:39:35Z',
#    'updatedAt': '2024-06-15T04:39:35Z'}}]
