# %% [markdown]
# ## **IndeedAPI**
#
# The `IndeedAPI` class is designed to interact with Indeed's job search functionality. It provides methods to construct job search URLs, send requests, and parse job postings data from Indeed.
#
# This class inherits from the `BaseSeleniumAPI` class, which provides methods for web scraping using Selenium to interact with a browser. Selenium is used because making calls with the `requests` library are blocked by the Indeed website, returning a `403 Forbidden` error.
#
# ### **get_job_postings_data**
#
# ##### `get_job_postings_data(search_query: str, location: str = 'United States', n_listings: int = 15, get_full_description: bool = False, close: bool = True, **kwargs)`
#
# The `get_job_postings_data` method retrieves a specified number of job postings from Indeed based on the search query and location. It uses Selenium to scrape the job postings data from the Indeed website.
#
# **Parameters:**
# - `search_query` (str): The search term for job titles or keywords.
# - `location` (str, optional): The geographical area to filter job postings. Defaults to 'United States'.
# - `n_listings` (int, optional): The number of job postings to retrieve. Defaults to 15.
# - `get_full_description` (bool, optional): If True, retrieves full job descriptions. Not implemented yet. Defaults to False.
# - `close` (bool, optional): If True, closes the Selenium WebDriver after fetching the data. Defaults to True.
# - `**kwargs`: Additional search parameters that will be passed to the `create_job_search_url` method to make the search more specific. These include:
#
#   - `days_ago` (int, optional): The number of days ago to filter job postings. Valid values are 0, 1, 3, 7, or 14.
#   - `pay` (int, optional): The minimum salary to filter job postings.
#   - `exp_level` (str, optional): The experience level (e.g., 'mid_level', 'entry_level', 'senior_level', 'no_exp').
#   - `work_type` (str, optional): The work type (e.g., 'hybrid', 'remote').
#   - `job_type` (str, optional): The type of job (e.g., 'fulltime', 'parttime', 'internship', 'temporary', 'contract').
#
# **Returns:**
# - `list`: A list of dictionaries, each representing a job posting with details such as job title, company name, location, snippet, date, and link.
#
# **Notes:**
# - This function uses pagination to fetch multiple pages if `n_listings` exceeds 15, which may trigger captchas or rate limits.
# - The function logs input and output data to JSON as part of its operation due to the `log_io_to_json` decorator.
#
# ## **Example**

# %%
from api_crawler import IndeedAPI

indeed_api = IndeedAPI()

job_posting_data = indeed_api.get_job_postings_data('Data Analyst', location='New York', days_ago=7)

job_posting_data
# Out:
# [{'job_title': 'Data Services Analyst',
#   'company_name': 'Candid',
#   'job_location': 'New York, NY 10001\xa0(Garment District area)',
#   'snippet': '\nThe Data Services Analyst will work with a team of data experts to deliver valuable data services, insights, and reporting about the social sector to a wide…\n',
#   'date': 'PostedToday',
#   'link': 'https://www.indeed.com/rc/clk?jk=194a821c73b1d099&bb=-4H4o66NnR4lHDyRsjqtYTYg83LV06A1ONCtKTA0Odn3kM_CpW5AeVb51gw3Is2tjNJXIKzvbhej03kv59mykqLhJ5G1sJHDH5D8ALKcU9zhRXBSimCTaoyQvSQwI1WL&xkcb=SoCn67M3A9F6_OTag50LbzkdCdPP&fccid=21c8d2c79c737096&vjs=3'},
#  {'job_title': 'Analyst, Strategy & Data Analytics',
#   'company_name': 'Wedbush Securities',
#   'job_location': 'New York, NY 10019\xa0(Midtown area)',
#   'snippet': '\nUtilize data-driven insights to drive strategic decision-making and enhance profitability.\nThe position is responsible for preparing data-driven insights and…\n',
#   'date': 'PostedPosted 3 days ago',
#   'link': 'https://www.indeed.com/rc/clk?jk=0e22d7ccb2a3494a&bb=-4H4o66NnR4lHDyRsjqtYVI-1e1skfprlfXH8Fzm8CR-n_oBWnCYHzX50AI2tUR_BXqKtetGlII-fn53WqxUnBOF3O3kC7h7FYJE-qkw2xhJFbFYZcuZ-xX4pKfLVaCI&xkcb=SoAT67M3A9F6_OTag50KbzkdCdPP&fccid=80ef378276ccd6eb&vjs=3'},
#  {'job_title': 'Data Analyst',
#   'company_name': 'Columbia University',
#   'job_location': 'New York, NY',
#   'snippet': '\nThe data analyst will support imaging-related research conducted by investigators in the Department of Radiology.\n',
#   'date': 'PostedPosted 7 days ago',
#   'link': 'https://www.indeed.com/rc/clk?jk=82b8918c011a655a&bb=-4H4o66NnR4lHDyRsjqtYa-yGj8h4f4FyVba4jYib8k9OeOHlNKTN62Rq1nhwKTrWlhv_ZLMdkmKpPDMdT4Vql0fCG_AuY9_3Mow-Wu9tjK2RxdJIG8inYTGmlYIBLoz&xkcb=SoCO67M3A9F6_OTag50JbzkdCdPP&fccid=bd976cc171c690e0&vjs=3'},
#  {'job_title': 'Data Analyst - Center for Patient Safety Science',
#   'company_name': 'Columbia University',
#   'job_location': 'New York, NY',
#   'snippet': '\nProvide data analyst support for CPSS projects.\nQuery the clinical data warehouse to obtain relevant data.\nPerform advanced data analysis under the guidance of…\n',
#   'date': 'PostedPosted 5 days ago',
#   'link': 'https://www.indeed.com/rc/clk?jk=201a875701c25609&bb=-4H4o66NnR4lHDyRsjqtYS21LBrO_H_6wRAo5gh3SjUPaX5T3c8G_wo93SpYqBZO12TT_L1bv2YNnmHQ9A8d3LH2eXgFtUm1_H6eVyZSn_vc8na4pJT4zKXWsHuu2vGz&xkcb=SoA667M3A9F6_OTag50IbzkdCdPP&fccid=bd976cc171c690e0&vjs=3'},
#  {'job_title': 'Research & Data Analyst',
#   'company_name': 'Bank Street College of Education',
#   'job_location': 'New York State',
#   'snippet': '\nAbility to work eﬀectively with data of varying levels of quality and validity; attention to detail and ability to identify issues and inconsistencies in data.\n',
#   'date': 'PostedPosted 2 days ago',
#   'link': 'https://www.indeed.com/rc/clk?jk=23810aaab6f07b4d&bb=-4H4o66NnR4lHDyRsjqtYRyxt515avT6jy36W9-rN5qExc2Sef0Iz3NssOyl-stmu19ltTarK3l7GhAVUTxn8dWQRqWfyECaj04du_wEtj3sl3D3oKJPAbkvmU3JLWwf&xkcb=SoC067M3A9F6_OTag50PbzkdCdPP&fccid=ed77a7fefd37f147&vjs=3'},
#  {'job_title': None,
#   'company_name': None,
#   'job_location': None,
#   'snippet': None,
#   'date': None,
#   'link': None},
#  {'job_title': 'Cybersecurity Strategic Data Visualization Analyst',
#   'company_name': 'M&T Bank',
#   'job_location': 'Buffalo, NY',
#   'snippet': '\nCertification in data storytelling and/or data visualization tools.\nBachelor’s degree and a minimum of 3 years of related experience, or in lieu of a degree, a…\n',
#   'date': 'PostedPosted 5 days ago',
#   'link': 'https://www.indeed.com/rc/clk?jk=67f2660b1ea8f9b4&bb=-4H4o66NnR4lHDyRsjqtYV_WSVjFJDtb4jEWusMC-d02jyhGw62CF7cnBoCYxLyA6_mM44FcoUzRNpi1OmHMrZAGCBsrLzHto7PPY92TX8D4PJN1l7XvhQ%3D%3D&xkcb=SoAA67M3A9F6_OTag50ObzkdCdPP&fccid=0e36880b18d20c75&vjs=3'},
#  {'job_title': 'Programmer / Data Analyst',
#   'company_name': 'Columbia University',
#   'job_location': 'New York, NY',
#   'snippet': '\nThe analyst will analyze data from large scale data sets as well as collect, enter and analyze clinical data using statistical software.\n',
#   'date': 'PostedPosted 4 days ago',
#   'link': 'https://www.indeed.com/rc/clk?jk=705e9a99bc15433d&bb=-4H4o66NnR4lHDyRsjqtYQZUgDaE3z6UVer3Ec7tDQmpMY3_ASO4LavwKtKn6ztvjkhyfJK7HKS6xLSbkWeoXUC9GV6F3mRDKG7LeLLJkp-gKVAnrcAihxMrZjyecsiY&xkcb=SoCd67M3A9F6_OTag50NbzkdCdPP&fccid=bd976cc171c690e0&vjs=3'},
#  {'job_title': 'Analyst - Corporate Card Member Marketing',
#   'company_name': 'Amex',
#   'job_location': 'Hybrid work in New York, NY',
#   'snippet': '\nAnalyze data to identify opportunity areas and deliver recommendations.\nStrong track record of driving results, analyzing data, reporting and trends.\n',
#   'date': 'PostedPosted 2 days ago',
#   'link': 'https://www.indeed.com/rc/clk?jk=802e8a9c44351869&bb=-4H4o66NnR4lHDyRsjqtYZN-wuwmTszvPXYe2b5NYvzzLCgFKQfUNxBtnkYh_g16yYsplvZL_nudF3dObLY2fbE2nj7mrW6rVDRvFqimVBZ1Zby3spw_zQ%3D%3D&xkcb=SoAp67M3A9F6_OTag50MbzkdCdPP&fccid=f057e04c37cca134&vjs=3'},
#  {'job_title': 'Catalog Data Analyst',
#   'company_name': 'Ampcus Incorporated',
#   'job_location': 'New York, NY',
#   'snippet': '\nMust be adept at making data useful and digestible by all parties involved.\nDemonstrable proficiency with Python and SQL Server and data mining skills.\n',
#   'date': 'PostedPosted 3 days ago',
#   'link': 'https://www.indeed.com/rc/clk?jk=8b02a9896bb8b00c&bb=-4H4o66NnR4lHDyRsjqtYVm1zS5ESk12sPGLTnb3aB6qfSvMXo3shNNXNv0rGZ_jbABmHzZlJnDL3sQk0QU4W3dL_iQlIFKaCMDT1lCWZoKWadzl_Qzd3zmJqXECxCJs&xkcb=SoDA67M3A9F6_OTag50DbzkdCdPP&fccid=cd6d2c9c59529b1c&vjs=3'},
#  {'job_title': 'Supply Chain Analyst',
#   'company_name': 'ITT, Inc.',
#   'job_location': 'Seneca Falls, NY 13148',
#   'snippet': '\nPerform quality assurance on data to determine potential data gaps.\nHandle data-related technical issues and support data infrastructure needs.\n',
#   'date': 'PostedPosted 1 day ago',
#   'link': 'https://www.indeed.com/rc/clk?jk=17f61ca2fd0435f7&bb=-4H4o66NnR4lHDyRsjqtYQDG1chwvshqg1eLdwpK5lmm1Dzu5Hh5_0G8cUD8WRAj_lQiJN_foBBo9sGpo7b-rV0eaL1ZbXXnat-LYgxe4Nd5c2aR6emItqpO0U1CBYb3&xkcb=SoB067M3A9F6_OTag50CbzkdCdPP&fccid=03a42a874282ff9c&vjs=3'},
#  {'job_title': None,
#   'company_name': None,
#   'job_location': None,
#   'snippet': None,
#   'date': None,
#   'link': None},
#  {'job_title': '2025 Innovation Development Summer Analyst Program',
#   'company_name': 'JPMorgan Chase & Co',
#   'job_location': 'New York, NY 10001\xa0(Chelsea area)',
#   'snippet': '\nAbility to think critically and analyze data.\nData, technology & systems: Leverage data and platforms to drive decision-making and improve business architecture…\n',
#   'date': 'PostedPosted 5 days ago',
#   'link': 'https://www.indeed.com/rc/clk?jk=93dc5c8bfdfa005e&bb=-4H4o66NnR4lHDyRsjqtYS5H9TnF3oUY0G4CCEBuVYRuM_eXSr1ugYqPBxa8QpeLogHRaVBr0L7-WilDBHSG9ei7O4FsV1g-rrVR8mbM2F6ZaqMG-ck_-w%3D%3D&xkcb=SoDp67M3A9F6_OTag50BbzkdCdPP&fccid=c46d0116f6e69eae&vjs=3'},
#  {'job_title': 'Asset Services Change Management Business Analyst',
#   'company_name': 'Bank of America',
#   'job_location': 'New York, NY',
#   'snippet': '\nThe Asset Services risk reduction program is seeking a change business analyst to deliver Asset Services front to back enhancements.\n',
#   'date': 'PostedToday',
#   'link': 'https://www.indeed.com/rc/clk?jk=7ddfa26879867d35&bb=-4H4o66NnR4lHDyRsjqtYahzqydEfa1X6NSlflqkKY-LYAMMORr0Cla5WbjxjTJqXRQ4jZDMNAYmxZbud5R-rjjIJmO2lmcUtESE-o4QPo4XLqs0Hd8Fxg%3D%3D&xkcb=SoBd67M3A9F6_OTag50AbzkdCdPP&fccid=5bd99dfa21c8a490&vjs=3'},
#  {'job_title': 'Data Analyst',
#   'company_name': 'NYC Careers',
#   'job_location': 'Manhattan, NY 10007\xa0(Financial District area)',
#   'snippet': '\nUse different coding and/or programming platforms, including the use of data management software such as SQL, Tableau, as well as Salesforce, to accurately…\n',
#   'date': 'PostedPosted 7 days ago',
#   'link': 'https://www.indeed.com/rc/clk?jk=b4b0f0cb627a319f&bb=-4H4o66NnR4lHDyRsjqtYbYf-3BwrzmRoDWMCGE_051wWU8wKwGHZ2cOpp7N6fP3YtZVhE5exlTYEE98VMLIsyZ8tEuxuST7PqekmXknSNRCyB6mFJ7Jn1xRRSec6PI7&xkcb=SoDT67M3A9F6_OTag50HbzkdCdPP&fccid=7d7b563c6a3a9653&vjs=3'}]
